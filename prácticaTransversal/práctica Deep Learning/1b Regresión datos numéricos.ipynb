# %% [markdown]
# **REGRESIÓN PARTIENDO DE DATOS NUMÉRICOS Y CATEGÓRICOS**
#
# En este notebook vamos a tratar de hacer una regresión para estimar el precio de un apartamento de alquiler.
# Dicha predicción se va a hacer a partir de los datos numéricos y categóricos que tenemos en el dataset de airbnb que venimos usando en las prácticas de este Bootcamp.
#
# En primer lugar nos descargamos el fichero de internet y lo copiamos en un directorio local de My Drive donde tenemos recogido todo el entorno de esta práctica.
# También montamos el google collab con My Drive para tenerlo vinculado.
#
# Estos pasos solo hay que realizarlos la primera vez, una vez que tenemos los ficheros en My Drive se pueden saltar y pasamos a cargar los datos directamente desde dicho directorio.

# %%
# nos descargamos el dataset de OpenDataSoft
# !wget -O "airbnb-listings.csv" "https://public.opendatasoft.com/explore/dataset/airbnb-listings/download/?format=csv&disjunctive.host_verifications=true&disjunctive.amenities=true&disjunctive.features=true&refine.country=Spain&q=Madrid&timezone=Europe/London&use_labels_for_header=true&csv_separator=%3B"

# !ls -lah
# Out:
# --2020-06-24 15:01:28--  https://public.opendatasoft.com/explore/dataset/airbnb-listings/download/?format=csv&disjunctive.host_verifications=true&disjunctive.amenities=true&disjunctive.features=true&refine.country=Spain&q=Madrid&timezone=Europe/London&use_labels_for_header=true&csv_separator=%3B
# Resolving public.opendatasoft.com (public.opendatasoft.com)... 34.248.20.69, 34.249.199.226
# Connecting to public.opendatasoft.com (public.opendatasoft.com)|34.248.20.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/csv]
# Saving to: ‘airbnb-listings.csv’
#
# airbnb-listings.csv     [         <=>        ]  54.19M  2.66MB/s    in 37s
#
# 2020-06-24 15:02:15 (1.46 MB/s) - ‘airbnb-listings.csv’ saved [56826824]
#
# total 55M
# drwxr-xr-x 1 root root 4.0K Jun 24 15:01 .
# drwxr-xr-x 1 root root 4.0K Jun 24 14:57 ..
# -rw-r--r-- 1 root root  55M Jun 24 15:02 airbnb-listings.csv
# drwxr-xr-x 1 root root 4.0K Jun 19 16:15 .config
# drwx------ 4 root root 4.0K Jun 24 15:00 drive
# drwxr-xr-x 1 root root 4.0K Jun 17 16:18 sample_data

# %%
# !ls -lah
# Out:
# total 55M
# drwxr-xr-x 1 root root 4.0K Jun 24 15:01 .
# drwxr-xr-x 1 root root 4.0K Jun 24 14:57 ..
# -rw-r--r-- 1 root root  55M Jun 24 15:02 airbnb-listings.csv
# drwxr-xr-x 1 root root 4.0K Jun 19 16:15 .config
# drwx------ 4 root root 4.0K Jun 24 15:00 drive
# drwxr-xr-x 1 root root 4.0K Jun 17 16:18 sample_data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !cp airbnb-listings.csv "drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning"

# %% [markdown]
# Esta parte de descarga, montado y copiado solo hace falta ejecutarla la primera vez. Una vez que lo tenemos almacenado en My Drive solo necesitamos cargarlo directamente.
#
# A partir de aquí empieza nuestro ejercicio de regresión.
#
# Como hábito de buena costumbre, para no incurrir en errores involuntarios, en primer lugar se va a dividir el dataset original en train, validation y test.
#
# Se trabaja únicamente con el de train con el objetivo de elegir un modelo. Eso se verifica con el conjunto de validation y finalmente se aplica ese "entrenamiento" al bloque de test.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error



full_df = pd.read_csv('drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning/airbnb-listings.csv', sep=';', decimal='.')
full_train, test = train_test_split(full_df, test_size=0.2, shuffle=True, random_state=0)
train, val = train_test_split(full_train, test_size=0.2, shuffle=True, random_state=0)

print(f'Dimensiones del dataset de training: {train.shape}')
print(f'Dimensiones del dataset de validación: {val.shape}')
print(f'Dimensiones del dataset de test: {test.shape}')

# Guardamos
train.to_csv('./train.csv', sep=';', decimal='.', index=True)
val.to_csv('./val.csv', sep=';', decimal='.', index=True)
test.to_csv('./test.csv', sep=';', decimal='.', index=True)
# Out:
# Dimensiones del dataset de training: (8960, 89)
# Dimensiones del dataset de validación: (2240, 89)
# Dimensiones del dataset de test: (2801, 89)

# %% [markdown]
# El preprocesado es similar al que hemos usado en el ejercicio de clasificación con la diferencia que aquí no categorizamos la variable Price.

# %%
# A partir de este momento cargamos el dataset de train y trabajamos ÚNICAMENTE con él. 
df_train = pd.read_csv('./train.csv', sep=';', decimal='.')
df_val = pd.read_csv('./val.csv', sep=';', decimal='.')
df_test = pd.read_csv('./test.csv', sep=';', decimal='.')

def preprocesado(train, val, test):
  #Nos quedamos solo con las filas que pertenecen a la ciudad de Madrid
  indexNames = train[ train['City'] != 'Madrid' ].index
  train.drop(indexNames , inplace=True)
  train.drop(['City'], axis=1, inplace=True)

  indexNames = val[ val['City'] != 'Madrid' ].index
  val.drop(indexNames , inplace=True)
  val.drop(['City'], axis=1, inplace=True)

  indexNames = test[ test['City'] != 'Madrid' ].index
  test.drop(indexNames , inplace=True)
  test.drop(['City'], axis=1, inplace=True)

  #eliminamos las columnas que no aportan
  train.drop(['ID','Scrape ID','Last Scraped','Host ID','Calendar last Scraped','Listing Url','Thumbnail Url',
         'Medium Url','Picture Url','XL Picture Url','Host URL','Host Thumbnail Url','Host Picture Url',
        'Name','Summary','Space','Description','Neighborhood Overview','Notes','Transit','Access',
         'Interaction','House Rules','Host Name','Host About','Street','Host Location','State','Market',
         'Smart Location','Country Code','Country','Geolocation','Weekly Price','Monthly Price',
         'Host Acceptance Rate','Experiences Offered','Has Availability','License','Jurisdiction Names','Square Feet'], 
        axis=1, inplace=True)
  val.drop(['ID','Scrape ID','Last Scraped','Host ID','Calendar last Scraped','Listing Url','Thumbnail Url',
         'Medium Url','Picture Url','XL Picture Url','Host URL','Host Thumbnail Url','Host Picture Url',
        'Name','Summary','Space','Description','Neighborhood Overview','Notes','Transit','Access',
         'Interaction','House Rules','Host Name','Host About','Street','Host Location','State','Market',
         'Smart Location','Country Code','Country','Geolocation','Weekly Price','Monthly Price',
         'Host Acceptance Rate','Experiences Offered','Has Availability','License','Jurisdiction Names','Square Feet'], 
        axis=1, inplace=True)
  test.drop(['ID','Scrape ID','Last Scraped','Host ID','Calendar last Scraped','Listing Url','Thumbnail Url',
         'Medium Url','Picture Url','XL Picture Url','Host URL','Host Thumbnail Url','Host Picture Url',
        'Name','Summary','Space','Description','Neighborhood Overview','Notes','Transit','Access',
         'Interaction','House Rules','Host Name','Host About','Street','Host Location','State','Market',
         'Smart Location','Country Code','Country','Geolocation','Weekly Price','Monthly Price',
         'Host Acceptance Rate','Experiences Offered','Has Availability','License','Jurisdiction Names','Square Feet'], 
        axis=1, inplace=True)
  
  #nueva variable --> en DL no lo uso (esta variable viene de ML) porque hemos visto que nos baja el accuracy
  #train['Bed_Bath_Rooms'] = train['Bedrooms']*train['Bathrooms']
  #val['Bed_Bath_Rooms'] = val['Bedrooms']*val['Bathrooms']
  #test['Bed_Bath_Rooms'] = test['Bedrooms']*test['Bathrooms']
  
  #PRICE
  #imputamos valores vacíos con la media de train
  MeanPriceTrain = train['Price'].mean()
  train['Price'].fillna(MeanPriceTrain, inplace=True)
  val['Price'].fillna(MeanPriceTrain, inplace=True)
  test['Price'].fillna(MeanPriceTrain, inplace=True)
  #definimos outlier >400€
  Price_filter = train['Price'] <= 400
  filtered_train = train[Price_filter]
  Price_filter = val['Price'] <= 400
  filtered_val = val[Price_filter]
  Price_filter = test['Price'] <= 400
  filtered_test = test[Price_filter]
  #transformamos variable Price a gausiana
  filtered_train['Price'] = filtered_train['Price'].apply(lambda x: np.log10(x))
  filtered_val['Price'] = filtered_val['Price'].apply(lambda x: np.log10(x))
  filtered_test['Price'] = filtered_test['Price'].apply(lambda x: np.log10(x))
    
  
  #FECHAS
  filtered_train['Host Since'] = pd.to_datetime(filtered_train['Host Since'], format="%Y-%m-%d")
  filtered_train['First Review'] = pd.to_datetime(filtered_train['First Review'], format="%Y-%m-%d")
  filtered_train['Last Review'] = pd.to_datetime(filtered_train['Last Review'], format="%Y-%m-%d")
  filtered_train['Host Since'] = filtered_train['Host Since'].apply(lambda x: 2017 - x.year)
  filtered_train['First Review'] = filtered_train['First Review'].apply(lambda x: 2017 - x.year)
  filtered_train['Last Review'] = filtered_train['Last Review'].apply(lambda x: 2017 - x.year)

  filtered_val['Host Since'] = pd.to_datetime(filtered_val['Host Since'], format="%Y-%m-%d")
  filtered_val['First Review'] = pd.to_datetime(filtered_val['First Review'], format="%Y-%m-%d")
  filtered_val['Last Review'] = pd.to_datetime(filtered_val['Last Review'], format="%Y-%m-%d")
  filtered_val['Host Since'] = filtered_val['Host Since'].apply(lambda x: 2017 - x.year)
  filtered_val['First Review'] = filtered_val['First Review'].apply(lambda x: 2017 - x.year)
  filtered_val['Last Review'] = filtered_val['Last Review'].apply(lambda x: 2017 - x.year)

  filtered_test['Host Since'] = pd.to_datetime(filtered_test['Host Since'], format="%Y-%m-%d")
  filtered_test['First Review'] = pd.to_datetime(filtered_test['First Review'], format="%Y-%m-%d")
  filtered_test['Last Review'] = pd.to_datetime(filtered_test['Last Review'], format="%Y-%m-%d")
  filtered_test['Host Since'] = filtered_test['Host Since'].apply(lambda x: 2017 - x.year)
  filtered_test['First Review'] = filtered_test['First Review'].apply(lambda x: 2017 - x.year)
  filtered_test['Last Review'] = filtered_test['Last Review'].apply(lambda x: 2017 - x.year)

  #Imputamos valores en variables categóricas donde tomamos la moda para los valores que faltan.
  #Lo extraemos en una variable disinta para cada columna con la intención de aplicar el mismo valor en val y test
  ModeHSTrain = filtered_train['Host Since'].mode()[0]
  ModeHLCTrain = filtered_train['Host Listings Count'].mode()[0]
  ModeHTLCTrain = filtered_train['Host Total Listings Count'].mode()[0]
  ModeBathroomsTrain = filtered_train['Bathrooms'].mode()[0]
  ModeBedroomsTrain = filtered_train['Bedrooms'].mode()[0]
  ModeBedsTrain = filtered_train['Beds'].mode()[0]

  filtered_train['Host Since'].fillna(ModeHSTrain, inplace=True)
  filtered_train['Host Listings Count'].fillna(ModeHLCTrain, inplace=True)
  filtered_train['Host Total Listings Count'].fillna(ModeHTLCTrain, inplace=True)
  filtered_train['Bathrooms'].fillna(ModeBathroomsTrain, inplace=True)
  filtered_train['Bedrooms'].fillna(ModeBedroomsTrain, inplace=True)
  filtered_train['Beds'].fillna(ModeBedsTrain, inplace=True)

  filtered_val['Host Since'].fillna(ModeHSTrain, inplace=True)
  filtered_val['Host Listings Count'].fillna(ModeHLCTrain, inplace=True)
  filtered_val['Host Total Listings Count'].fillna(ModeHTLCTrain, inplace=True)
  filtered_val['Bathrooms'].fillna(ModeBathroomsTrain, inplace=True)
  filtered_val['Bedrooms'].fillna(ModeBedroomsTrain, inplace=True)
  filtered_val['Beds'].fillna(ModeBedsTrain, inplace=True)
  filtered_test['Host Since'].fillna(ModeHSTrain, inplace=True)
  filtered_test['Host Listings Count'].fillna(ModeHLCTrain, inplace=True)
  filtered_test['Host Total Listings Count'].fillna(ModeHTLCTrain, inplace=True)
  filtered_test['Bathrooms'].fillna(ModeBathroomsTrain, inplace=True)
  filtered_test['Bedrooms'].fillna(ModeBedroomsTrain, inplace=True)
  filtered_test['Beds'].fillna(ModeBedsTrain, inplace=True)

  #Imputamos valores en variables lineales donde tomamos la media para los valores que faltan
  #Lo extraemos en una variable disinta para cada columna con la intención de aplicar el mismo valor en val y test
  MeanRSRatingTrain = filtered_train['Review Scores Rating'].mean()
  MeanRSAccuracyTrain = filtered_train['Review Scores Accuracy'].mean()
  MeanRSCleanlinessTrain = filtered_train['Review Scores Cleanliness'].mean()
  MeanRSCheckinTrain = filtered_train['Review Scores Checkin'].mean()
  MeanRSCommunicationTrain = filtered_train['Review Scores Communication'].mean()
  MeanRSLocationTrain = filtered_train['Review Scores Location'].mean()
  MeanRSValueTrain = filtered_train['Review Scores Value'].mean()

  filtered_train['Review Scores Rating'].fillna(MeanRSRatingTrain, inplace=True)
  filtered_train['Review Scores Accuracy'].fillna(MeanRSAccuracyTrain, inplace=True)
  filtered_train['Review Scores Cleanliness'].fillna(MeanRSCleanlinessTrain, inplace=True)
  filtered_train['Review Scores Checkin'].fillna(MeanRSCheckinTrain, inplace=True)
  filtered_train['Review Scores Communication'].fillna(MeanRSCommunicationTrain, inplace=True)
  filtered_train['Review Scores Location'].fillna(MeanRSLocationTrain, inplace=True)
  filtered_train['Review Scores Value'].fillna(MeanRSValueTrain, inplace=True)
  filtered_val['Review Scores Rating'].fillna(MeanRSRatingTrain, inplace=True)
  filtered_val['Review Scores Accuracy'].fillna(MeanRSAccuracyTrain, inplace=True)
  filtered_val['Review Scores Cleanliness'].fillna(MeanRSCleanlinessTrain, inplace=True)
  filtered_val['Review Scores Checkin'].fillna(MeanRSCheckinTrain, inplace=True)
  filtered_val['Review Scores Communication'].fillna(MeanRSCommunicationTrain, inplace=True)
  filtered_val['Review Scores Location'].fillna(MeanRSLocationTrain, inplace=True)
  filtered_val['Review Scores Value'].fillna(MeanRSValueTrain, inplace=True)
  filtered_test['Review Scores Rating'].fillna(MeanRSRatingTrain, inplace=True)
  filtered_test['Review Scores Accuracy'].fillna(MeanRSAccuracyTrain, inplace=True)
  filtered_test['Review Scores Cleanliness'].fillna(MeanRSCleanlinessTrain, inplace=True)
  filtered_test['Review Scores Checkin'].fillna(MeanRSCheckinTrain, inplace=True)
  filtered_test['Review Scores Communication'].fillna(MeanRSCommunicationTrain, inplace=True)
  filtered_test['Review Scores Location'].fillna(MeanRSLocationTrain, inplace=True)
  filtered_test['Review Scores Value'].fillna(MeanRSValueTrain, inplace=True)

  #los vacíos los consideramos como desconocidos
  filtered_train['Host Neighbourhood'].fillna('Unknown', inplace=True)
  filtered_train['Host Verifications'].fillna('Unknown', inplace=True)
  filtered_train['Neighbourhood'].fillna('Unknown', inplace=True)
  filtered_train['Zipcode'].fillna('Unknown', inplace=True)
  filtered_train['Amenities'].fillna('Unknown', inplace=True)
  filtered_train['First Review'].fillna('Unknown', inplace=True)
  filtered_train['Last Review'].fillna('Unknown', inplace=True)
  filtered_val['Host Neighbourhood'].fillna('Unknown', inplace=True)
  filtered_val['Host Verifications'].fillna('Unknown', inplace=True)
  filtered_val['Neighbourhood'].fillna('Unknown', inplace=True)
  filtered_val['Zipcode'].fillna('Unknown', inplace=True)
  filtered_val['Amenities'].fillna('Unknown', inplace=True)
  filtered_val['First Review'].fillna('Unknown', inplace=True)
  filtered_val['Last Review'].fillna('Unknown', inplace=True)
  filtered_test['Host Neighbourhood'].fillna('Unknown', inplace=True)
  filtered_test['Host Verifications'].fillna('Unknown', inplace=True)
  filtered_test['Neighbourhood'].fillna('Unknown', inplace=True)
  filtered_test['Zipcode'].fillna('Unknown', inplace=True)
  filtered_test['Amenities'].fillna('Unknown', inplace=True)
  filtered_test['First Review'].fillna('Unknown', inplace=True)
  filtered_test['Last Review'].fillna('Unknown', inplace=True)

  #consideramos que donde falta un valor es porque no existe, es decir, no hay respuesta o la tasa es 0€
  filtered_train['Host Response Time'].fillna('No response', inplace=True)
  filtered_train['Host Response Rate'].fillna(0, inplace=True)
  filtered_train['Security Deposit'].fillna(0, inplace=True)
  filtered_train['Cleaning Fee'].fillna(0, inplace=True)
  filtered_train['Reviews per Month'].fillna(0, inplace=True)
  filtered_val['Host Response Time'].fillna('No response', inplace=True)
  filtered_val['Host Response Rate'].fillna(0, inplace=True)
  filtered_val['Security Deposit'].fillna(0, inplace=True)
  filtered_val['Cleaning Fee'].fillna(0, inplace=True)
  filtered_val['Reviews per Month'].fillna(0, inplace=True)
  filtered_test['Host Response Time'].fillna('No response', inplace=True)
  filtered_test['Host Response Rate'].fillna(0, inplace=True)
  filtered_test['Security Deposit'].fillna(0, inplace=True)
  filtered_test['Cleaning Fee'].fillna(0, inplace=True)
  filtered_test['Reviews per Month'].fillna(0, inplace=True)

  #transformaciones contando palabras. es algo muy sencillo, queda pendiente mejorarlo con técnicas NLP en el futuro
  filtered_train['Amenities'] = filtered_train['Amenities'].apply(lambda x: len(str(x).split(',')))
  filtered_train['Host Verifications'] = filtered_train['Host Verifications'].apply(lambda x: len(str(x).split(',')))
  filtered_train['Features'] = filtered_train['Features'].apply(lambda x: len(str(x).split(',')))
  filtered_val['Amenities'] = filtered_val['Amenities'].apply(lambda x: len(str(x).split(',')))
  filtered_val['Host Verifications'] = filtered_val['Host Verifications'].apply(lambda x: len(str(x).split(',')))
  filtered_val['Features'] = filtered_val['Features'].apply(lambda x: len(str(x).split(',')))
  filtered_test['Amenities'] = filtered_test['Amenities'].apply(lambda x: len(str(x).split(',')))
  filtered_test['Host Verifications'] = filtered_test['Host Verifications'].apply(lambda x: len(str(x).split(',')))
  filtered_test['Features'] = filtered_test['Features'].apply(lambda x: len(str(x).split(',')))

  #MeanEncoder
  categorical = ['Host Response Time', 'Host Neighbourhood', 'Neighbourhood','Neighbourhood Cleansed',
               'Neighbourhood Group Cleansed','Zipcode','Property Type','Room Type','Bed Type',
               'Calendar Updated','First Review','Last Review','Cancellation Policy']
  # En train creamos un dict para usarlo después en val y test
  mean_map = {}
  for c in categorical:
      mean = filtered_train.groupby(c)['Price'].mean()
      filtered_train[c] = filtered_train[c].map(mean)    
      mean_map[c] = mean
  for c in categorical:
    filtered_val[c] = filtered_val[c].map(mean_map[c])
  for c in categorical:
    filtered_test[c] = filtered_test[c].map(mean_map[c])
 #los valores vacíos de test los completo con la moda de train
  for c in categorical:
    filtered_val[c].fillna(filtered_train[c].mode()[0], inplace=True)
  for c in categorical:
    filtered_test[c].fillna(filtered_train[c].mode()[0], inplace=True)

  #extraemos la variable objetivo
  Ytrain = filtered_train['Price']
  Yval = filtered_val['Price']
  Ytest = filtered_test['Price']
  #eliminamos la variable Price
  filtered_train.drop(['Price'],axis=1, inplace=True)
  filtered_val.drop(['Price'],axis=1, inplace=True)
  filtered_test.drop(['Price'],axis=1, inplace=True)

  #escalamos los valores de entrada
  cs = MinMaxScaler()
  Xtrain_Scaled = cs.fit_transform(filtered_train)
  Xval_Scaled = cs.transform(filtered_val)
  Xtest_Scaled = cs. transform(filtered_test)



  return (Xtrain_Scaled, Xval_Scaled, Xtest_Scaled, Ytrain, Yval, Ytest)

# %% [markdown]
# Usamos la función definida previamente para obtener nuestros conjuntos de datos y la variable objetivo.

# %%
(Xtrain, Xval, Xtest, ytrain, yval, ytest) = preprocesado(df_train, df_val, df_test)

# %% [markdown]
# Ahora vamos a definir los modelos con los que vamos a trabajar y que iremos comparando. Son muy parecidos a los usados en el notebook de clasificación. La principal diferencia está en la última capa, que al tratarse de una regresión tendrá solo una neurona y sin activación (es lineal).

# %%
# import the necessary packages
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Dropout, Dense, Flatten, Input

#creamos una primera red muy sencilla igual que en clasificación pero con 1 sola neurona en la capa de salida y sin activación (lineal)
def MiRedReg1(dim):
  model = Sequential()
  model.add(Dense(8, input_dim=dim, activation="relu"))
  model.add(Dense(4, activation="relu"))
  model.add(Dense(1, activation="linear"))

  return model

#creamos una red un poco más compleja con más capas ocultas
def MiRedReg2(dim):
  model = Sequential()
  model.add(Dense(64, input_dim=dim, activation="relu"))
  model.add(Dense(32, activation="relu"))
  model.add(Dense(16, activation="relu"))
  model.add(Dense(8, activation="relu"))
  model.add(Dense(4, activation="relu"))
  model.add(Dense(1, activation="linear"))

  return model

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import to_categorical
from keras.optimizers import Adam

model = MiRedReg1(Xtrain.shape[1])
opt = Adam(lr=1e-2, decay=1e-3 / 200)

#compilamos el modelo
model.compile(loss="mse",
              optimizer=opt,
							metrics=[tf.keras.metrics.RootMeanSquaredError()])

# entrenamos el modelo
print("[INFO] training model...")
model.fit(x=Xtrain, y=ytrain, 
	validation_data=(Xval, yval),
	epochs=200, batch_size=8)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Using TensorFlow backend.
# [INFO] training model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 8412 samples, validate on 2100 samples
# Epoch 1/200
# 8412/8412 [==============================] - 5s 623us/step - loss: 0.0369 - root_mean_squared_error: 0.2452 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1883
# Epoch 2/200
# 8412/8412 [==============================] - 3s 400us/step - loss: 0.0256 - root_mean_squared_error: 0.1780 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1733
# Epoch 3/200
# 8412/8412 [==============================] - 3s 375us/step - loss: 0.0248 - root_mean_squared_error: 0.1702 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1676
# Epoch 4/200
# 8412/8412 [==============================] - 3s 377us/step - loss: 0.0243 - root_mean_squared_error: 0.1657 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1644
# Epoch 5/200
# 8412/8412 [==============================] - 3s 365us/step - loss: 0.0239 - root_mean_squared_error: 0.1634 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1623
# Epoch 6/200
# 8412/8412 [==============================] - 3s 360us/step - loss: 0.0243 - root_mean_squared_error: 0.1616 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1609
# Epoch 7/200
# 8412/8412 [==============================] - 3s 371us/step - loss: 0.0236 - root_mean_squared_error: 0.1602 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1597
# Epoch 8/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0235 - root_mean_squared_error: 0.1592 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1588
# Epoch 9/200
# 8412/8412 [==============================] - 3s 395us/step - loss: 0.0239 - root_mean_squared_error: 0.1585 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1582
# Epoch 10/200
# 8412/8412 [==============================] - 3s 406us/step - loss: 0.0238 - root_mean_squared_error: 0.1579 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1577
# Epoch 11/200
# 8412/8412 [==============================] - 3s 398us/step - loss: 0.0233 - root_mean_squared_error: 0.1574 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1572
# Epoch 12/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0232 - root_mean_squared_error: 0.1568 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1567
# Epoch 13/200
# 8412/8412 [==============================] - 3s 360us/step - loss: 0.0233 - root_mean_squared_error: 0.1564 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1563
# Epoch 14/200
# 8412/8412 [==============================] - 3s 397us/step - loss: 0.0231 - root_mean_squared_error: 0.1560 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1559
# Epoch 15/200
# 8412/8412 [==============================] - 3s 368us/step - loss: 0.0233 - root_mean_squared_error: 0.1557 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1556
# Epoch 16/200
# 8412/8412 [==============================] - 3s 392us/step - loss: 0.0228 - root_mean_squared_error: 0.1555 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1553
# Epoch 17/200
# 8412/8412 [==============================] - 3s 352us/step - loss: 0.0224 - root_mean_squared_error: 0.1552 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1550
# Epoch 18/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0225 - root_mean_squared_error: 0.1548 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1547
# Epoch 19/200
# 8412/8412 [==============================] - 3s 398us/step - loss: 0.0226 - root_mean_squared_error: 0.1546 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1544
# Epoch 20/200
# 8412/8412 [==============================] - 3s 393us/step - loss: 0.0224 - root_mean_squared_error: 0.1543 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1542
# Epoch 21/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0226 - root_mean_squared_error: 0.1541 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1540
# Epoch 22/200
# 8412/8412 [==============================] - 3s 384us/step - loss: 0.0222 - root_mean_squared_error: 0.1539 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1538
# Epoch 23/200
# 8412/8412 [==============================] - 3s 381us/step - loss: 0.0223 - root_mean_squared_error: 0.1537 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1536
# Epoch 24/200
# 8412/8412 [==============================] - 3s 379us/step - loss: 0.0223 - root_mean_squared_error: 0.1535 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1534
# Epoch 25/200
# 8412/8412 [==============================] - 3s 351us/step - loss: 0.0221 - root_mean_squared_error: 0.1533 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1532
# Epoch 26/200
# 8412/8412 [==============================] - 3s 409us/step - loss: 0.0221 - root_mean_squared_error: 0.1532 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1531
# Epoch 27/200
# 8412/8412 [==============================] - 3s 365us/step - loss: 0.0218 - root_mean_squared_error: 0.1530 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1529
# Epoch 28/200
# 8412/8412 [==============================] - 3s 393us/step - loss: 0.0217 - root_mean_squared_error: 0.1528 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1527
# Epoch 29/200
# 8412/8412 [==============================] - 3s 411us/step - loss: 0.0219 - root_mean_squared_error: 0.1526 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1526
# Epoch 30/200
# 8412/8412 [==============================] - 3s 398us/step - loss: 0.0218 - root_mean_squared_error: 0.1525 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1524
# Epoch 31/200
# 8412/8412 [==============================] - 3s 362us/step - loss: 0.0217 - root_mean_squared_error: 0.1523 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1522
# Epoch 32/200
# 8412/8412 [==============================] - 3s 383us/step - loss: 0.0221 - root_mean_squared_error: 0.1522 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1521
# Epoch 33/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0215 - root_mean_squared_error: 0.1521 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1520
# Epoch 34/200
# 8412/8412 [==============================] - 3s 383us/step - loss: 0.0217 - root_mean_squared_error: 0.1519 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1518
# Epoch 35/200
# 8412/8412 [==============================] - 3s 408us/step - loss: 0.0215 - root_mean_squared_error: 0.1517 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1517
# Epoch 36/200
# 8412/8412 [==============================] - 3s 380us/step - loss: 0.0214 - root_mean_squared_error: 0.1516 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1515
# Epoch 37/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0214 - root_mean_squared_error: 0.1515 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1514
# Epoch 38/200
# 8412/8412 [==============================] - 3s 361us/step - loss: 0.0215 - root_mean_squared_error: 0.1513 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1513
# Epoch 39/200
# 8412/8412 [==============================] - 3s 346us/step - loss: 0.0212 - root_mean_squared_error: 0.1512 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1511
# Epoch 40/200
# 8412/8412 [==============================] - 3s 354us/step - loss: 0.0215 - root_mean_squared_error: 0.1511 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1510
# Epoch 41/200
# 8412/8412 [==============================] - 3s 399us/step - loss: 0.0213 - root_mean_squared_error: 0.1510 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1509
# Epoch 42/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0212 - root_mean_squared_error: 0.1509 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1508
# Epoch 43/200
# 8412/8412 [==============================] - 3s 348us/step - loss: 0.0212 - root_mean_squared_error: 0.1508 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1507
# Epoch 44/200
# 8412/8412 [==============================] - 3s 381us/step - loss: 0.0213 - root_mean_squared_error: 0.1507 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1506
# Epoch 45/200
# 8412/8412 [==============================] - 3s 370us/step - loss: 0.0211 - root_mean_squared_error: 0.1506 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1505
# Epoch 46/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0211 - root_mean_squared_error: 0.1504 - val_loss: 0.0283 - val_root_mean_squared_error: 0.1504
# Epoch 47/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0213 - root_mean_squared_error: 0.1504 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1504
# Epoch 48/200
# 8412/8412 [==============================] - 3s 348us/step - loss: 0.0211 - root_mean_squared_error: 0.1503 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1503
# Epoch 49/200
# 8412/8412 [==============================] - 3s 367us/step - loss: 0.0208 - root_mean_squared_error: 0.1503 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1502
# Epoch 50/200
# 8412/8412 [==============================] - 3s 363us/step - loss: 0.0213 - root_mean_squared_error: 0.1502 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1501
# Epoch 51/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0210 - root_mean_squared_error: 0.1501 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1501
# Epoch 52/200
# 8412/8412 [==============================] - 3s 382us/step - loss: 0.0210 - root_mean_squared_error: 0.1500 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1500
# Epoch 53/200
# 8412/8412 [==============================] - 4s 428us/step - loss: 0.0209 - root_mean_squared_error: 0.1499 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1499
# Epoch 54/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0210 - root_mean_squared_error: 0.1499 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1498
# Epoch 55/200
# 8412/8412 [==============================] - 3s 384us/step - loss: 0.0208 - root_mean_squared_error: 0.1498 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1497
# Epoch 56/200
# 8412/8412 [==============================] - 3s 356us/step - loss: 0.0208 - root_mean_squared_error: 0.1497 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1496
# Epoch 57/200
# 8412/8412 [==============================] - 3s 400us/step - loss: 0.0208 - root_mean_squared_error: 0.1496 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1496
# Epoch 58/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0207 - root_mean_squared_error: 0.1495 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1495
# Epoch 59/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0206 - root_mean_squared_error: 0.1494 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1494
# Epoch 60/200
# 8412/8412 [==============================] - 3s 367us/step - loss: 0.0207 - root_mean_squared_error: 0.1494 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1493
# Epoch 61/200
# 8412/8412 [==============================] - 4s 422us/step - loss: 0.0207 - root_mean_squared_error: 0.1493 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1493
# Epoch 62/200
# 8412/8412 [==============================] - 3s 369us/step - loss: 0.0206 - root_mean_squared_error: 0.1492 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1492
# Epoch 63/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0208 - root_mean_squared_error: 0.1491 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1491
# Epoch 64/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0205 - root_mean_squared_error: 0.1491 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1490
# Epoch 65/200
# 8412/8412 [==============================] - 3s 387us/step - loss: 0.0208 - root_mean_squared_error: 0.1490 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1489
# Epoch 66/200
# 8412/8412 [==============================] - 3s 408us/step - loss: 0.0206 - root_mean_squared_error: 0.1489 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1489
# Epoch 67/200
# 8412/8412 [==============================] - 3s 372us/step - loss: 0.0206 - root_mean_squared_error: 0.1489 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1489
# Epoch 68/200
# 8412/8412 [==============================] - 3s 363us/step - loss: 0.0203 - root_mean_squared_error: 0.1489 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1488
# Epoch 69/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0205 - root_mean_squared_error: 0.1488 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1487
# Epoch 70/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0205 - root_mean_squared_error: 0.1487 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1487
# Epoch 71/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0203 - root_mean_squared_error: 0.1486 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1486
# Epoch 72/200
# 8412/8412 [==============================] - 3s 396us/step - loss: 0.0202 - root_mean_squared_error: 0.1486 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1485
# Epoch 73/200
# 8412/8412 [==============================] - 3s 393us/step - loss: 0.0205 - root_mean_squared_error: 0.1485 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1485
# Epoch 74/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0205 - root_mean_squared_error: 0.1484 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1484
# Epoch 75/200
# 8412/8412 [==============================] - 3s 360us/step - loss: 0.0205 - root_mean_squared_error: 0.1484 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1483
# Epoch 76/200
# 8412/8412 [==============================] - 3s 389us/step - loss: 0.0203 - root_mean_squared_error: 0.1483 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1483
# Epoch 77/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0201 - root_mean_squared_error: 0.1483 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1482
# Epoch 78/200
# 8412/8412 [==============================] - 3s 398us/step - loss: 0.0203 - root_mean_squared_error: 0.1482 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1482
# Epoch 79/200
# 8412/8412 [==============================] - 3s 372us/step - loss: 0.0200 - root_mean_squared_error: 0.1481 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1481
# Epoch 80/200
# 8412/8412 [==============================] - 3s 377us/step - loss: 0.0202 - root_mean_squared_error: 0.1481 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1480
# Epoch 81/200
# 8412/8412 [==============================] - 3s 352us/step - loss: 0.0204 - root_mean_squared_error: 0.1480 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1480
# Epoch 82/200
# 8412/8412 [==============================] - 3s 347us/step - loss: 0.0202 - root_mean_squared_error: 0.1480 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1479
# Epoch 83/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0201 - root_mean_squared_error: 0.1479 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1479
# Epoch 84/200
# 8412/8412 [==============================] - 3s 374us/step - loss: 0.0199 - root_mean_squared_error: 0.1479 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1478
# Epoch 85/200
# 8412/8412 [==============================] - 3s 370us/step - loss: 0.0202 - root_mean_squared_error: 0.1478 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1478
# Epoch 86/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0200 - root_mean_squared_error: 0.1477 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1477
# Epoch 87/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0202 - root_mean_squared_error: 0.1477 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1477
# Epoch 88/200
# 8412/8412 [==============================] - 3s 371us/step - loss: 0.0200 - root_mean_squared_error: 0.1476 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1476
# Epoch 89/200
# 8412/8412 [==============================] - 3s 396us/step - loss: 0.0200 - root_mean_squared_error: 0.1476 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1475
# Epoch 90/200
# 8412/8412 [==============================] - 3s 406us/step - loss: 0.0201 - root_mean_squared_error: 0.1475 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1475
# Epoch 91/200
# 8412/8412 [==============================] - 3s 381us/step - loss: 0.0200 - root_mean_squared_error: 0.1475 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1475
# Epoch 92/200
# 8412/8412 [==============================] - 3s 382us/step - loss: 0.0203 - root_mean_squared_error: 0.1474 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1474
# Epoch 93/200
# 8412/8412 [==============================] - 3s 361us/step - loss: 0.0201 - root_mean_squared_error: 0.1474 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1474
# Epoch 94/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0200 - root_mean_squared_error: 0.1474 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1474
# Epoch 95/200
# 8412/8412 [==============================] - 3s 370us/step - loss: 0.0201 - root_mean_squared_error: 0.1473 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1473
# Epoch 96/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0200 - root_mean_squared_error: 0.1473 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1473
# Epoch 97/200
# 8412/8412 [==============================] - 4s 435us/step - loss: 0.0199 - root_mean_squared_error: 0.1472 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1472
# Epoch 98/200
# 8412/8412 [==============================] - 3s 399us/step - loss: 0.0199 - root_mean_squared_error: 0.1472 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1472
# Epoch 99/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0199 - root_mean_squared_error: 0.1472 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1471
# Epoch 100/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0201 - root_mean_squared_error: 0.1471 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1471
# Epoch 101/200
# 8412/8412 [==============================] - 3s 376us/step - loss: 0.0201 - root_mean_squared_error: 0.1471 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1470
# Epoch 102/200
# 8412/8412 [==============================] - 3s 354us/step - loss: 0.0198 - root_mean_squared_error: 0.1470 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1470
# Epoch 103/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0197 - root_mean_squared_error: 0.1470 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1469
# Epoch 104/200
# 8412/8412 [==============================] - 3s 365us/step - loss: 0.0199 - root_mean_squared_error: 0.1469 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1469
# Epoch 105/200
# 8412/8412 [==============================] - 3s 362us/step - loss: 0.0198 - root_mean_squared_error: 0.1469 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1468
# Epoch 106/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0199 - root_mean_squared_error: 0.1468 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1468
# Epoch 107/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0199 - root_mean_squared_error: 0.1468 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1468
# Epoch 108/200
# 8412/8412 [==============================] - 3s 384us/step - loss: 0.0199 - root_mean_squared_error: 0.1467 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1467
# Epoch 109/200
# 8412/8412 [==============================] - 3s 368us/step - loss: 0.0199 - root_mean_squared_error: 0.1467 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1467
# Epoch 110/200
# 8412/8412 [==============================] - 3s 354us/step - loss: 0.0199 - root_mean_squared_error: 0.1467 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1466
# Epoch 111/200
# 8412/8412 [==============================] - 4s 416us/step - loss: 0.0198 - root_mean_squared_error: 0.1466 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1466
# Epoch 112/200
# 8412/8412 [==============================] - 3s 365us/step - loss: 0.0198 - root_mean_squared_error: 0.1466 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1465
# Epoch 113/200
# 8412/8412 [==============================] - 3s 375us/step - loss: 0.0199 - root_mean_squared_error: 0.1465 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1465
# Epoch 114/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0199 - root_mean_squared_error: 0.1465 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1465
# Epoch 115/200
# 8412/8412 [==============================] - 3s 374us/step - loss: 0.0197 - root_mean_squared_error: 0.1464 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1464
# Epoch 116/200
# 8412/8412 [==============================] - 3s 372us/step - loss: 0.0200 - root_mean_squared_error: 0.1464 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1464
# Epoch 117/200
# 8412/8412 [==============================] - 3s 374us/step - loss: 0.0198 - root_mean_squared_error: 0.1464 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1464
# Epoch 118/200
# 8412/8412 [==============================] - 3s 376us/step - loss: 0.0200 - root_mean_squared_error: 0.1463 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1463
# Epoch 119/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0198 - root_mean_squared_error: 0.1463 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1463
# Epoch 120/200
# 8412/8412 [==============================] - 3s 399us/step - loss: 0.0200 - root_mean_squared_error: 0.1463 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1463
# Epoch 121/200
# 8412/8412 [==============================] - 3s 367us/step - loss: 0.0197 - root_mean_squared_error: 0.1463 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1462
# Epoch 122/200
# 8412/8412 [==============================] - 3s 348us/step - loss: 0.0200 - root_mean_squared_error: 0.1462 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1462
# Epoch 123/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0197 - root_mean_squared_error: 0.1462 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1462
# Epoch 124/200
# 8412/8412 [==============================] - 3s 385us/step - loss: 0.0196 - root_mean_squared_error: 0.1462 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1462
# Epoch 125/200
# 8412/8412 [==============================] - 3s 370us/step - loss: 0.0198 - root_mean_squared_error: 0.1461 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1461
# Epoch 126/200
# 8412/8412 [==============================] - 3s 389us/step - loss: 0.0198 - root_mean_squared_error: 0.1461 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1461
# Epoch 127/200
# 8412/8412 [==============================] - 3s 401us/step - loss: 0.0197 - root_mean_squared_error: 0.1461 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1461
# Epoch 128/200
# 8412/8412 [==============================] - 3s 404us/step - loss: 0.0197 - root_mean_squared_error: 0.1461 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1460
# Epoch 129/200
# 8412/8412 [==============================] - 3s 356us/step - loss: 0.0200 - root_mean_squared_error: 0.1460 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1460
# Epoch 130/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0196 - root_mean_squared_error: 0.1460 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1460
# Epoch 131/200
# 8412/8412 [==============================] - 3s 382us/step - loss: 0.0196 - root_mean_squared_error: 0.1460 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1460
# Epoch 132/200
# 8412/8412 [==============================] - 3s 376us/step - loss: 0.0200 - root_mean_squared_error: 0.1460 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1460
# Epoch 133/200
# 8412/8412 [==============================] - 3s 377us/step - loss: 0.0195 - root_mean_squared_error: 0.1460 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1459
# Epoch 134/200
# 8412/8412 [==============================] - 3s 349us/step - loss: 0.0198 - root_mean_squared_error: 0.1459 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1459
# Epoch 135/200
# 8412/8412 [==============================] - 3s 398us/step - loss: 0.0198 - root_mean_squared_error: 0.1459 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1459
# Epoch 136/200
# 8412/8412 [==============================] - 3s 372us/step - loss: 0.0197 - root_mean_squared_error: 0.1459 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1458
# Epoch 137/200
# 8412/8412 [==============================] - 3s 361us/step - loss: 0.0199 - root_mean_squared_error: 0.1458 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1458
# Epoch 138/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0198 - root_mean_squared_error: 0.1458 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1458
# Epoch 139/200
# 8412/8412 [==============================] - 3s 375us/step - loss: 0.0196 - root_mean_squared_error: 0.1458 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1458
# Epoch 140/200
# 8412/8412 [==============================] - 3s 368us/step - loss: 0.0199 - root_mean_squared_error: 0.1458 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1457
# Epoch 141/200
# 8412/8412 [==============================] - 3s 379us/step - loss: 0.0197 - root_mean_squared_error: 0.1457 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1457
# Epoch 142/200
# 8412/8412 [==============================] - 3s 376us/step - loss: 0.0196 - root_mean_squared_error: 0.1457 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1457
# Epoch 143/200
# 8412/8412 [==============================] - 3s 388us/step - loss: 0.0198 - root_mean_squared_error: 0.1457 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1456
# Epoch 144/200
# 8412/8412 [==============================] - 3s 371us/step - loss: 0.0194 - root_mean_squared_error: 0.1456 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1456
# Epoch 145/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0195 - root_mean_squared_error: 0.1456 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1456
# Epoch 146/200
# 8412/8412 [==============================] - 3s 348us/step - loss: 0.0196 - root_mean_squared_error: 0.1456 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1456
# Epoch 147/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0196 - root_mean_squared_error: 0.1455 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1455
# Epoch 148/200
# 8412/8412 [==============================] - 3s 381us/step - loss: 0.0196 - root_mean_squared_error: 0.1455 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1455
# Epoch 149/200
# 8412/8412 [==============================] - 3s 409us/step - loss: 0.0195 - root_mean_squared_error: 0.1455 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1455
# Epoch 150/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0196 - root_mean_squared_error: 0.1455 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1455
# Epoch 151/200
# 8412/8412 [==============================] - 3s 373us/step - loss: 0.0196 - root_mean_squared_error: 0.1454 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1454
# Epoch 152/200
# 8412/8412 [==============================] - 3s 351us/step - loss: 0.0199 - root_mean_squared_error: 0.1454 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1454
# Epoch 153/200
# 8412/8412 [==============================] - 3s 401us/step - loss: 0.0196 - root_mean_squared_error: 0.1454 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1454
# Epoch 154/200
# 8412/8412 [==============================] - 3s 382us/step - loss: 0.0196 - root_mean_squared_error: 0.1454 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1454
# Epoch 155/200
# 8412/8412 [==============================] - 3s 383us/step - loss: 0.0198 - root_mean_squared_error: 0.1454 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1453
# Epoch 156/200
# 8412/8412 [==============================] - 3s 401us/step - loss: 0.0195 - root_mean_squared_error: 0.1453 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1453
# Epoch 157/200
# 8412/8412 [==============================] - 3s 409us/step - loss: 0.0195 - root_mean_squared_error: 0.1453 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1453
# Epoch 158/200
# 8412/8412 [==============================] - 3s 380us/step - loss: 0.0194 - root_mean_squared_error: 0.1453 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1453
# Epoch 159/200
# 8412/8412 [==============================] - 3s 358us/step - loss: 0.0194 - root_mean_squared_error: 0.1452 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1452
# Epoch 160/200
# 8412/8412 [==============================] - 3s 376us/step - loss: 0.0197 - root_mean_squared_error: 0.1452 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1452
# Epoch 161/200
# 8412/8412 [==============================] - 3s 398us/step - loss: 0.0197 - root_mean_squared_error: 0.1452 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1452
# Epoch 162/200
# 8412/8412 [==============================] - 3s 366us/step - loss: 0.0196 - root_mean_squared_error: 0.1452 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1452
# Epoch 163/200
# 8412/8412 [==============================] - 3s 367us/step - loss: 0.0195 - root_mean_squared_error: 0.1451 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1451
# Epoch 164/200
# 8412/8412 [==============================] - 3s 380us/step - loss: 0.0196 - root_mean_squared_error: 0.1451 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1451
# Epoch 165/200
# 8412/8412 [==============================] - 3s 410us/step - loss: 0.0196 - root_mean_squared_error: 0.1451 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1451
# Epoch 166/200
# 8412/8412 [==============================] - 3s 392us/step - loss: 0.0196 - root_mean_squared_error: 0.1451 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1451
# Epoch 167/200
# 8412/8412 [==============================] - 3s 403us/step - loss: 0.0197 - root_mean_squared_error: 0.1450 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1450
# Epoch 168/200
# 8412/8412 [==============================] - 3s 356us/step - loss: 0.0197 - root_mean_squared_error: 0.1450 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1450
# Epoch 169/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0193 - root_mean_squared_error: 0.1450 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1450
# Epoch 170/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0195 - root_mean_squared_error: 0.1450 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1450
# Epoch 171/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0196 - root_mean_squared_error: 0.1450 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1450
# Epoch 172/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0192 - root_mean_squared_error: 0.1449 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1449
# Epoch 173/200
# 8412/8412 [==============================] - 3s 373us/step - loss: 0.0197 - root_mean_squared_error: 0.1449 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1449
# Epoch 174/200
# 8412/8412 [==============================] - 3s 400us/step - loss: 0.0197 - root_mean_squared_error: 0.1449 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1449
# Epoch 175/200
# 8412/8412 [==============================] - 3s 378us/step - loss: 0.0196 - root_mean_squared_error: 0.1449 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1449
# Epoch 176/200
# 8412/8412 [==============================] - 3s 352us/step - loss: 0.0196 - root_mean_squared_error: 0.1449 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1449
# Epoch 177/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0195 - root_mean_squared_error: 0.1449 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1448
# Epoch 178/200
# 8412/8412 [==============================] - 3s 349us/step - loss: 0.0193 - root_mean_squared_error: 0.1448 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 179/200
# 8412/8412 [==============================] - 3s 356us/step - loss: 0.0193 - root_mean_squared_error: 0.1448 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1448
# Epoch 180/200
# 8412/8412 [==============================] - 3s 357us/step - loss: 0.0195 - root_mean_squared_error: 0.1448 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 181/200
# 8412/8412 [==============================] - 3s 396us/step - loss: 0.0193 - root_mean_squared_error: 0.1448 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1447
# Epoch 182/200
# 8412/8412 [==============================] - 3s 381us/step - loss: 0.0195 - root_mean_squared_error: 0.1447 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1447
# Epoch 183/200
# 8412/8412 [==============================] - 3s 354us/step - loss: 0.0194 - root_mean_squared_error: 0.1447 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1447
# Epoch 184/200
# 8412/8412 [==============================] - 3s 362us/step - loss: 0.0195 - root_mean_squared_error: 0.1447 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1447
# Epoch 185/200
# 8412/8412 [==============================] - 3s 376us/step - loss: 0.0194 - root_mean_squared_error: 0.1447 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1446
# Epoch 186/200
# 8412/8412 [==============================] - 4s 419us/step - loss: 0.0195 - root_mean_squared_error: 0.1446 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1446
# Epoch 187/200
# 8412/8412 [==============================] - 3s 371us/step - loss: 0.0194 - root_mean_squared_error: 0.1446 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1446
# Epoch 188/200
# 8412/8412 [==============================] - 3s 348us/step - loss: 0.0194 - root_mean_squared_error: 0.1446 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1446
# Epoch 189/200
# 8412/8412 [==============================] - 3s 347us/step - loss: 0.0194 - root_mean_squared_error: 0.1446 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1446
# Epoch 190/200
# 8412/8412 [==============================] - 3s 363us/step - loss: 0.0196 - root_mean_squared_error: 0.1446 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1446
# Epoch 191/200
# 8412/8412 [==============================] - 3s 414us/step - loss: 0.0194 - root_mean_squared_error: 0.1445 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1445
# Epoch 192/200
# 8412/8412 [==============================] - 3s 345us/step - loss: 0.0193 - root_mean_squared_error: 0.1445 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1445
# Epoch 193/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0194 - root_mean_squared_error: 0.1445 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1445
# Epoch 194/200
# 8412/8412 [==============================] - 3s 359us/step - loss: 0.0195 - root_mean_squared_error: 0.1445 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1445
# Epoch 195/200
# 8412/8412 [==============================] - 3s 350us/step - loss: 0.0193 - root_mean_squared_error: 0.1445 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1445
# Epoch 196/200
# 8412/8412 [==============================] - 3s 375us/step - loss: 0.0195 - root_mean_squared_error: 0.1444 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1444
# Epoch 197/200
# 8412/8412 [==============================] - 3s 393us/step - loss: 0.0194 - root_mean_squared_error: 0.1444 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1444
# Epoch 198/200
# 8412/8412 [==============================] - 3s 353us/step - loss: 0.0194 - root_mean_squared_error: 0.1444 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1444
# Epoch 199/200
# 8412/8412 [==============================] - 3s 367us/step - loss: 0.0195 - root_mean_squared_error: 0.1444 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1444
# Epoch 200/200
# 8412/8412 [==============================] - 3s 355us/step - loss: 0.0195 - root_mean_squared_error: 0.1444 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1444

# %% [markdown]
# En el ejercicio de regresión vamos a usar el RMSE para comparar la precisión de los modelos. Este valor es la raiz cuadrada del error cuadrático medio, así que realmente se puede interpretar como la cantidad de euros que nos estamos desviando en la predicción.
#
# Para hacerlo de forma correcta hay que deshacer la transformación logarítmica que aplicábamos a la variable Price para convertirla en gaussiana.

# %%
predTrain = model.predict(Xtrain)
predVal = model.predict(Xval)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predVal_Eur = pd.DataFrame(predVal).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseValModel = mean_squared_error(Yval_Eur,predVal_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (val) : %0.3g' % mseValModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel))
# Out:
# MSE (train): 706
# MSE (val) : 947
# RMSE (train): 26.6
# RMSE (val) : 30.8

# %%
model2 = MiRedReg2(Xtrain.shape[1])
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model2.compile(loss="mse", optimizer=opt, metrics=[tf.keras.metrics.RootMeanSquaredError()])

# train the model
print("[INFO] training model...")
model2.fit(x=Xtrain, y=ytrain, 
	validation_data=(Xval, yval),
	epochs=200, batch_size=8)
# Out:
# [INFO] training model...
# Train on 8412 samples, validate on 2100 samples
# Epoch 1/200
# 8412/8412 [==============================] - 5s 552us/step - loss: 0.2100 - root_mean_squared_error: 0.7667 - val_loss: 0.0243 - val_root_mean_squared_error: 0.4357
# Epoch 2/200
# 8412/8412 [==============================] - 4s 515us/step - loss: 0.0243 - root_mean_squared_error: 0.3645 - val_loss: 0.0219 - val_root_mean_squared_error: 0.3201
# Epoch 3/200
# 8412/8412 [==============================] - 4s 524us/step - loss: 0.0235 - root_mean_squared_error: 0.2938 - val_loss: 0.0233 - val_root_mean_squared_error: 0.2741
# Epoch 4/200
# 8412/8412 [==============================] - 4s 492us/step - loss: 0.0228 - root_mean_squared_error: 0.2601 - val_loss: 0.0210 - val_root_mean_squared_error: 0.2483
# Epoch 5/200
# 8412/8412 [==============================] - 5s 561us/step - loss: 0.0222 - root_mean_squared_error: 0.2393 - val_loss: 0.0216 - val_root_mean_squared_error: 0.2315
# Epoch 6/200
# 8412/8412 [==============================] - 4s 518us/step - loss: 0.0216 - root_mean_squared_error: 0.2251 - val_loss: 0.0218 - val_root_mean_squared_error: 0.2194
# Epoch 7/200
# 8412/8412 [==============================] - 4s 518us/step - loss: 0.0214 - root_mean_squared_error: 0.2148 - val_loss: 0.0207 - val_root_mean_squared_error: 0.2104
# Epoch 8/200
# 8412/8412 [==============================] - 4s 507us/step - loss: 0.0206 - root_mean_squared_error: 0.2067 - val_loss: 0.0199 - val_root_mean_squared_error: 0.2032
# Epoch 9/200
# 8412/8412 [==============================] - 4s 507us/step - loss: 0.0205 - root_mean_squared_error: 0.2001 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1973
# Epoch 10/200
# 8412/8412 [==============================] - 4s 525us/step - loss: 0.0203 - root_mean_squared_error: 0.1947 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1925
# Epoch 11/200
# 8412/8412 [==============================] - 4s 478us/step - loss: 0.0200 - root_mean_squared_error: 0.1904 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1884
# Epoch 12/200
# 8412/8412 [==============================] - 4s 502us/step - loss: 0.0200 - root_mean_squared_error: 0.1867 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1849
# Epoch 13/200
# 8412/8412 [==============================] - 4s 495us/step - loss: 0.0197 - root_mean_squared_error: 0.1834 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1820
# Epoch 14/200
# 8412/8412 [==============================] - 4s 521us/step - loss: 0.0194 - root_mean_squared_error: 0.1806 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1793
# Epoch 15/200
# 8412/8412 [==============================] - 4s 534us/step - loss: 0.0195 - root_mean_squared_error: 0.1780 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1769
# Epoch 16/200
# 8412/8412 [==============================] - 4s 493us/step - loss: 0.0190 - root_mean_squared_error: 0.1758 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1748
# Epoch 17/200
# 8412/8412 [==============================] - 4s 484us/step - loss: 0.0193 - root_mean_squared_error: 0.1738 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1729
# Epoch 18/200
# 8412/8412 [==============================] - 4s 520us/step - loss: 0.0188 - root_mean_squared_error: 0.1720 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1711
# Epoch 19/200
# 8412/8412 [==============================] - 4s 528us/step - loss: 0.0184 - root_mean_squared_error: 0.1703 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1696
# Epoch 20/200
# 8412/8412 [==============================] - 4s 488us/step - loss: 0.0187 - root_mean_squared_error: 0.1689 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1682
# Epoch 21/200
# 8412/8412 [==============================] - 4s 485us/step - loss: 0.0181 - root_mean_squared_error: 0.1675 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1668
# Epoch 22/200
# 8412/8412 [==============================] - 4s 514us/step - loss: 0.0182 - root_mean_squared_error: 0.1661 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1655
# Epoch 23/200
# 8412/8412 [==============================] - 5s 548us/step - loss: 0.0179 - root_mean_squared_error: 0.1648 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1642
# Epoch 24/200
# 8412/8412 [==============================] - 4s 528us/step - loss: 0.0176 - root_mean_squared_error: 0.1636 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1631
# Epoch 25/200
# 8412/8412 [==============================] - 4s 534us/step - loss: 0.0177 - root_mean_squared_error: 0.1625 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1620
# Epoch 26/200
# 8412/8412 [==============================] - 4s 525us/step - loss: 0.0177 - root_mean_squared_error: 0.1615 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1610
# Epoch 27/200
# 8412/8412 [==============================] - 4s 504us/step - loss: 0.0176 - root_mean_squared_error: 0.1606 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1601
# Epoch 28/200
# 8412/8412 [==============================] - 5s 548us/step - loss: 0.0172 - root_mean_squared_error: 0.1596 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1592
# Epoch 29/200
# 8412/8412 [==============================] - 4s 484us/step - loss: 0.0173 - root_mean_squared_error: 0.1587 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1583
# Epoch 30/200
# 8412/8412 [==============================] - 4s 496us/step - loss: 0.0170 - root_mean_squared_error: 0.1579 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1575
# Epoch 31/200
# 8412/8412 [==============================] - 4s 485us/step - loss: 0.0170 - root_mean_squared_error: 0.1571 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1568
# Epoch 32/200
# 8412/8412 [==============================] - 4s 528us/step - loss: 0.0170 - root_mean_squared_error: 0.1565 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1561
# Epoch 33/200
# 8412/8412 [==============================] - 5s 556us/step - loss: 0.0170 - root_mean_squared_error: 0.1557 - val_loss: 0.0191 - val_root_mean_squared_error: 0.1554
# Epoch 34/200
# 8412/8412 [==============================] - 4s 495us/step - loss: 0.0168 - root_mean_squared_error: 0.1551 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1547
# Epoch 35/200
# 8412/8412 [==============================] - 4s 494us/step - loss: 0.0165 - root_mean_squared_error: 0.1544 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1541
# Epoch 36/200
# 8412/8412 [==============================] - 5s 561us/step - loss: 0.0167 - root_mean_squared_error: 0.1538 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1535
# Epoch 37/200
# 8412/8412 [==============================] - 4s 517us/step - loss: 0.0164 - root_mean_squared_error: 0.1532 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1529
# Epoch 38/200
# 8412/8412 [==============================] - 4s 510us/step - loss: 0.0165 - root_mean_squared_error: 0.1526 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1523
# Epoch 39/200
# 8412/8412 [==============================] - 4s 520us/step - loss: 0.0163 - root_mean_squared_error: 0.1520 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1517
# Epoch 40/200
# 8412/8412 [==============================] - 4s 510us/step - loss: 0.0162 - root_mean_squared_error: 0.1515 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1512
# Epoch 41/200
# 8412/8412 [==============================] - 4s 535us/step - loss: 0.0163 - root_mean_squared_error: 0.1509 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1507
# Epoch 42/200
# 8412/8412 [==============================] - 4s 502us/step - loss: 0.0161 - root_mean_squared_error: 0.1504 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1502
# Epoch 43/200
# 8412/8412 [==============================] - 4s 492us/step - loss: 0.0160 - root_mean_squared_error: 0.1499 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1497
# Epoch 44/200
# 8412/8412 [==============================] - 5s 535us/step - loss: 0.0159 - root_mean_squared_error: 0.1495 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1493
# Epoch 45/200
# 8412/8412 [==============================] - 4s 483us/step - loss: 0.0158 - root_mean_squared_error: 0.1490 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1488
# Epoch 46/200
# 8412/8412 [==============================] - 5s 559us/step - loss: 0.0155 - root_mean_squared_error: 0.1486 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1483
# Epoch 47/200
# 8412/8412 [==============================] - 4s 488us/step - loss: 0.0158 - root_mean_squared_error: 0.1481 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1479
# Epoch 48/200
# 8412/8412 [==============================] - 4s 497us/step - loss: 0.0154 - root_mean_squared_error: 0.1477 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1475
# Epoch 49/200
# 8412/8412 [==============================] - 4s 527us/step - loss: 0.0157 - root_mean_squared_error: 0.1473 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1471
# Epoch 50/200
# 8412/8412 [==============================] - 4s 524us/step - loss: 0.0155 - root_mean_squared_error: 0.1469 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1467
# Epoch 51/200
# 8412/8412 [==============================] - 4s 497us/step - loss: 0.0154 - root_mean_squared_error: 0.1465 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1463
# Epoch 52/200
# 8412/8412 [==============================] - 4s 522us/step - loss: 0.0155 - root_mean_squared_error: 0.1462 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1460
# Epoch 53/200
# 8412/8412 [==============================] - 4s 507us/step - loss: 0.0152 - root_mean_squared_error: 0.1458 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1456
# Epoch 54/200
# 8412/8412 [==============================] - 4s 497us/step - loss: 0.0154 - root_mean_squared_error: 0.1454 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1453
# Epoch 55/200
# 8412/8412 [==============================] - 4s 485us/step - loss: 0.0152 - root_mean_squared_error: 0.1451 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1449
# Epoch 56/200
# 8412/8412 [==============================] - 4s 533us/step - loss: 0.0153 - root_mean_squared_error: 0.1448 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1446
# Epoch 57/200
# 8412/8412 [==============================] - 4s 474us/step - loss: 0.0150 - root_mean_squared_error: 0.1444 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1443
# Epoch 58/200
# 8412/8412 [==============================] - 4s 523us/step - loss: 0.0150 - root_mean_squared_error: 0.1441 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1439
# Epoch 59/200
# 8412/8412 [==============================] - 5s 546us/step - loss: 0.0152 - root_mean_squared_error: 0.1438 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1436
# Epoch 60/200
# 8412/8412 [==============================] - 4s 503us/step - loss: 0.0150 - root_mean_squared_error: 0.1435 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1433
# Epoch 61/200
# 8412/8412 [==============================] - 4s 526us/step - loss: 0.0149 - root_mean_squared_error: 0.1432 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1430
# Epoch 62/200
# 8412/8412 [==============================] - 4s 523us/step - loss: 0.0147 - root_mean_squared_error: 0.1429 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1427
# Epoch 63/200
# 8412/8412 [==============================] - 5s 556us/step - loss: 0.0147 - root_mean_squared_error: 0.1426 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1424
# Epoch 64/200
# 8412/8412 [==============================] - 4s 516us/step - loss: 0.0147 - root_mean_squared_error: 0.1423 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1422
# Epoch 65/200
# 8412/8412 [==============================] - 4s 513us/step - loss: 0.0147 - root_mean_squared_error: 0.1420 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1419
# Epoch 66/200
# 8412/8412 [==============================] - 5s 542us/step - loss: 0.0148 - root_mean_squared_error: 0.1418 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1416
# Epoch 67/200
# 8412/8412 [==============================] - 4s 497us/step - loss: 0.0145 - root_mean_squared_error: 0.1415 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1414
# Epoch 68/200
# 8412/8412 [==============================] - 5s 540us/step - loss: 0.0146 - root_mean_squared_error: 0.1413 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1411
# Epoch 69/200
# 8412/8412 [==============================] - 4s 485us/step - loss: 0.0143 - root_mean_squared_error: 0.1410 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1409
# Epoch 70/200
# 8412/8412 [==============================] - 4s 487us/step - loss: 0.0144 - root_mean_squared_error: 0.1407 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1406
# Epoch 71/200
# 8412/8412 [==============================] - 4s 472us/step - loss: 0.0144 - root_mean_squared_error: 0.1405 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1404
# Epoch 72/200
# 8412/8412 [==============================] - 4s 498us/step - loss: 0.0145 - root_mean_squared_error: 0.1403 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1402
# Epoch 73/200
# 8412/8412 [==============================] - 4s 483us/step - loss: 0.0144 - root_mean_squared_error: 0.1400 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1399
# Epoch 74/200
# 8412/8412 [==============================] - 4s 493us/step - loss: 0.0142 - root_mean_squared_error: 0.1398 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1397
# Epoch 75/200
# 8412/8412 [==============================] - 4s 503us/step - loss: 0.0141 - root_mean_squared_error: 0.1396 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1395
# Epoch 76/200
# 8412/8412 [==============================] - 4s 532us/step - loss: 0.0143 - root_mean_squared_error: 0.1394 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1393
# Epoch 77/200
# 8412/8412 [==============================] - 4s 482us/step - loss: 0.0141 - root_mean_squared_error: 0.1392 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1390
# Epoch 78/200
# 8412/8412 [==============================] - 4s 519us/step - loss: 0.0142 - root_mean_squared_error: 0.1389 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1388
# Epoch 79/200
# 8412/8412 [==============================] - 4s 489us/step - loss: 0.0142 - root_mean_squared_error: 0.1387 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1386
# Epoch 80/200
# 8412/8412 [==============================] - 5s 545us/step - loss: 0.0141 - root_mean_squared_error: 0.1385 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1384
# Epoch 81/200
# 8412/8412 [==============================] - 5s 542us/step - loss: 0.0140 - root_mean_squared_error: 0.1383 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1382
# Epoch 82/200
# 8412/8412 [==============================] - 5s 538us/step - loss: 0.0140 - root_mean_squared_error: 0.1381 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1380
# Epoch 83/200
# 8412/8412 [==============================] - 4s 491us/step - loss: 0.0141 - root_mean_squared_error: 0.1379 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1378
# Epoch 84/200
# 8412/8412 [==============================] - 4s 515us/step - loss: 0.0139 - root_mean_squared_error: 0.1377 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1376
# Epoch 85/200
# 8412/8412 [==============================] - 4s 507us/step - loss: 0.0138 - root_mean_squared_error: 0.1375 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1375
# Epoch 86/200
# 8412/8412 [==============================] - 5s 548us/step - loss: 0.0140 - root_mean_squared_error: 0.1374 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1373
# Epoch 87/200
# 8412/8412 [==============================] - 4s 516us/step - loss: 0.0138 - root_mean_squared_error: 0.1372 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1371
# Epoch 88/200
# 8412/8412 [==============================] - 5s 561us/step - loss: 0.0137 - root_mean_squared_error: 0.1370 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1369
# Epoch 89/200
# 8412/8412 [==============================] - 5s 537us/step - loss: 0.0139 - root_mean_squared_error: 0.1368 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1368
# Epoch 90/200
# 8412/8412 [==============================] - 4s 503us/step - loss: 0.0138 - root_mean_squared_error: 0.1367 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1366
# Epoch 91/200
# 8412/8412 [==============================] - 4s 534us/step - loss: 0.0137 - root_mean_squared_error: 0.1365 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1364
# Epoch 92/200
# 8412/8412 [==============================] - 5s 574us/step - loss: 0.0138 - root_mean_squared_error: 0.1363 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1362
# Epoch 93/200
# 8412/8412 [==============================] - 5s 548us/step - loss: 0.0137 - root_mean_squared_error: 0.1362 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1361
# Epoch 94/200
# 8412/8412 [==============================] - 5s 567us/step - loss: 0.0135 - root_mean_squared_error: 0.1360 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1359
# Epoch 95/200
# 8412/8412 [==============================] - 5s 570us/step - loss: 0.0135 - root_mean_squared_error: 0.1358 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1357
# Epoch 96/200
# 8412/8412 [==============================] - 5s 591us/step - loss: 0.0134 - root_mean_squared_error: 0.1357 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1356
# Epoch 97/200
# 8412/8412 [==============================] - 4s 525us/step - loss: 0.0135 - root_mean_squared_error: 0.1355 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1354
# Epoch 98/200
# 8412/8412 [==============================] - 4s 533us/step - loss: 0.0134 - root_mean_squared_error: 0.1353 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1353
# Epoch 99/200
# 8412/8412 [==============================] - 4s 514us/step - loss: 0.0134 - root_mean_squared_error: 0.1352 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1351
# Epoch 100/200
# 8412/8412 [==============================] - 4s 516us/step - loss: 0.0134 - root_mean_squared_error: 0.1350 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1350
# Epoch 101/200
# 8412/8412 [==============================] - 5s 570us/step - loss: 0.0133 - root_mean_squared_error: 0.1349 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1348
# Epoch 102/200
# 8412/8412 [==============================] - 5s 590us/step - loss: 0.0133 - root_mean_squared_error: 0.1347 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1347
# Epoch 103/200
# 8412/8412 [==============================] - 5s 538us/step - loss: 0.0133 - root_mean_squared_error: 0.1346 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1345
# Epoch 104/200
# 8412/8412 [==============================] - 5s 560us/step - loss: 0.0132 - root_mean_squared_error: 0.1344 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1344
# Epoch 105/200
# 8412/8412 [==============================] - 4s 518us/step - loss: 0.0132 - root_mean_squared_error: 0.1343 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1342
# Epoch 106/200
# 8412/8412 [==============================] - 5s 536us/step - loss: 0.0131 - root_mean_squared_error: 0.1342 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1341
# Epoch 107/200
# 8412/8412 [==============================] - 4s 526us/step - loss: 0.0132 - root_mean_squared_error: 0.1340 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1339
# Epoch 108/200
# 8412/8412 [==============================] - 5s 565us/step - loss: 0.0132 - root_mean_squared_error: 0.1339 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1338
# Epoch 109/200
# 8412/8412 [==============================] - 5s 555us/step - loss: 0.0130 - root_mean_squared_error: 0.1337 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1337
# Epoch 110/200
# 8412/8412 [==============================] - 4s 524us/step - loss: 0.0130 - root_mean_squared_error: 0.1336 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1335
# Epoch 111/200
# 8412/8412 [==============================] - 4s 516us/step - loss: 0.0130 - root_mean_squared_error: 0.1335 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1334
# Epoch 112/200
# 8412/8412 [==============================] - 5s 644us/step - loss: 0.0129 - root_mean_squared_error: 0.1334 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1333
# Epoch 113/200
# 8412/8412 [==============================] - 4s 524us/step - loss: 0.0129 - root_mean_squared_error: 0.1332 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1332
# Epoch 114/200
# 8412/8412 [==============================] - 5s 558us/step - loss: 0.0130 - root_mean_squared_error: 0.1331 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1330
# Epoch 115/200
# 8412/8412 [==============================] - 5s 569us/step - loss: 0.0130 - root_mean_squared_error: 0.1330 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1329
# Epoch 116/200
# 8412/8412 [==============================] - 5s 550us/step - loss: 0.0131 - root_mean_squared_error: 0.1328 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1328
# Epoch 117/200
# 8412/8412 [==============================] - 4s 533us/step - loss: 0.0129 - root_mean_squared_error: 0.1327 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1327
# Epoch 118/200
# 8412/8412 [==============================] - 5s 557us/step - loss: 0.0128 - root_mean_squared_error: 0.1326 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1326
# Epoch 119/200
# 8412/8412 [==============================] - 5s 555us/step - loss: 0.0128 - root_mean_squared_error: 0.1325 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1324
# Epoch 120/200
# 8412/8412 [==============================] - 4s 526us/step - loss: 0.0128 - root_mean_squared_error: 0.1324 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1323
# Epoch 121/200
# 8412/8412 [==============================] - 5s 544us/step - loss: 0.0128 - root_mean_squared_error: 0.1322 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1322
# Epoch 122/200
# 8412/8412 [==============================] - 5s 588us/step - loss: 0.0129 - root_mean_squared_error: 0.1321 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1321
# Epoch 123/200
# 8412/8412 [==============================] - 5s 561us/step - loss: 0.0127 - root_mean_squared_error: 0.1320 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1320
# Epoch 124/200
# 8412/8412 [==============================] - 5s 603us/step - loss: 0.0125 - root_mean_squared_error: 0.1319 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1318
# Epoch 125/200
# 8412/8412 [==============================] - 5s 543us/step - loss: 0.0126 - root_mean_squared_error: 0.1318 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1317
# Epoch 126/200
# 8412/8412 [==============================] - 4s 518us/step - loss: 0.0126 - root_mean_squared_error: 0.1317 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1316
# Epoch 127/200
# 8412/8412 [==============================] - 4s 512us/step - loss: 0.0126 - root_mean_squared_error: 0.1316 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1315
# Epoch 128/200
# 8412/8412 [==============================] - 5s 542us/step - loss: 0.0126 - root_mean_squared_error: 0.1314 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1314
# Epoch 129/200
# 8412/8412 [==============================] - 5s 550us/step - loss: 0.0126 - root_mean_squared_error: 0.1313 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1313
# Epoch 130/200
# 8412/8412 [==============================] - 4s 518us/step - loss: 0.0125 - root_mean_squared_error: 0.1312 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1312
# Epoch 131/200
# 8412/8412 [==============================] - 5s 563us/step - loss: 0.0124 - root_mean_squared_error: 0.1311 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1311
# Epoch 132/200
# 8412/8412 [==============================] - 5s 589us/step - loss: 0.0125 - root_mean_squared_error: 0.1310 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1310
# Epoch 133/200
# 8412/8412 [==============================] - 5s 589us/step - loss: 0.0124 - root_mean_squared_error: 0.1309 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1309
# Epoch 134/200
# 8412/8412 [==============================] - 5s 614us/step - loss: 0.0123 - root_mean_squared_error: 0.1308 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1308
# Epoch 135/200
# 8412/8412 [==============================] - 5s 557us/step - loss: 0.0123 - root_mean_squared_error: 0.1307 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1306
# Epoch 136/200
# 8412/8412 [==============================] - 5s 551us/step - loss: 0.0123 - root_mean_squared_error: 0.1306 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1305
# Epoch 137/200
# 8412/8412 [==============================] - 4s 523us/step - loss: 0.0123 - root_mean_squared_error: 0.1305 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1304
# Epoch 138/200
# 8412/8412 [==============================] - 5s 544us/step - loss: 0.0123 - root_mean_squared_error: 0.1304 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1303
# Epoch 139/200
# 8412/8412 [==============================] - 4s 526us/step - loss: 0.0123 - root_mean_squared_error: 0.1303 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1303
# Epoch 140/200
# 8412/8412 [==============================] - 5s 569us/step - loss: 0.0122 - root_mean_squared_error: 0.1302 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1302
# Epoch 141/200
# 8412/8412 [==============================] - 5s 542us/step - loss: 0.0122 - root_mean_squared_error: 0.1301 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1301
# Epoch 142/200
# 8412/8412 [==============================] - 5s 543us/step - loss: 0.0122 - root_mean_squared_error: 0.1300 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1300
# Epoch 143/200
# 8412/8412 [==============================] - 5s 579us/step - loss: 0.0122 - root_mean_squared_error: 0.1299 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1299
# Epoch 144/200
# 8412/8412 [==============================] - 5s 550us/step - loss: 0.0121 - root_mean_squared_error: 0.1298 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1298
# Epoch 145/200
# 8412/8412 [==============================] - 5s 542us/step - loss: 0.0122 - root_mean_squared_error: 0.1297 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1297
# Epoch 146/200
# 8412/8412 [==============================] - 5s 564us/step - loss: 0.0121 - root_mean_squared_error: 0.1297 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1296
# Epoch 147/200
# 8412/8412 [==============================] - 4s 531us/step - loss: 0.0120 - root_mean_squared_error: 0.1296 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1295
# Epoch 148/200
# 8412/8412 [==============================] - 5s 565us/step - loss: 0.0120 - root_mean_squared_error: 0.1295 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1294
# Epoch 149/200
# 8412/8412 [==============================] - 5s 602us/step - loss: 0.0121 - root_mean_squared_error: 0.1294 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1293
# Epoch 150/200
# 8412/8412 [==============================] - 5s 565us/step - loss: 0.0120 - root_mean_squared_error: 0.1293 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1292
# Epoch 151/200
# 8412/8412 [==============================] - 5s 574us/step - loss: 0.0120 - root_mean_squared_error: 0.1292 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1292
# Epoch 152/200
# 8412/8412 [==============================] - 4s 514us/step - loss: 0.0119 - root_mean_squared_error: 0.1291 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1291
# Epoch 153/200
# 8412/8412 [==============================] - 5s 543us/step - loss: 0.0119 - root_mean_squared_error: 0.1290 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1290
# Epoch 154/200
# 8412/8412 [==============================] - 5s 543us/step - loss: 0.0118 - root_mean_squared_error: 0.1289 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1289
# Epoch 155/200
# 8412/8412 [==============================] - 5s 564us/step - loss: 0.0120 - root_mean_squared_error: 0.1288 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1288
# Epoch 156/200
# 8412/8412 [==============================] - 5s 541us/step - loss: 0.0121 - root_mean_squared_error: 0.1288 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1287
# Epoch 157/200
# 8412/8412 [==============================] - 5s 537us/step - loss: 0.0119 - root_mean_squared_error: 0.1287 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1286
# Epoch 158/200
# 8412/8412 [==============================] - 5s 562us/step - loss: 0.0119 - root_mean_squared_error: 0.1286 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1286
# Epoch 159/200
# 8412/8412 [==============================] - 5s 553us/step - loss: 0.0116 - root_mean_squared_error: 0.1285 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1285
# Epoch 160/200
# 8412/8412 [==============================] - 4s 515us/step - loss: 0.0117 - root_mean_squared_error: 0.1284 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1284
# Epoch 161/200
# 8412/8412 [==============================] - 5s 576us/step - loss: 0.0117 - root_mean_squared_error: 0.1283 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1283
# Epoch 162/200
# 8412/8412 [==============================] - 5s 588us/step - loss: 0.0118 - root_mean_squared_error: 0.1283 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1282
# Epoch 163/200
# 8412/8412 [==============================] - 5s 544us/step - loss: 0.0118 - root_mean_squared_error: 0.1282 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1281
# Epoch 164/200
# 8412/8412 [==============================] - 5s 549us/step - loss: 0.0117 - root_mean_squared_error: 0.1281 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1281
# Epoch 165/200
# 8412/8412 [==============================] - 4s 527us/step - loss: 0.0118 - root_mean_squared_error: 0.1280 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1280
# Epoch 166/200
# 8412/8412 [==============================] - 5s 557us/step - loss: 0.0117 - root_mean_squared_error: 0.1279 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1279
# Epoch 167/200
# 8412/8412 [==============================] - 5s 566us/step - loss: 0.0118 - root_mean_squared_error: 0.1279 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1278
# Epoch 168/200
# 8412/8412 [==============================] - 5s 570us/step - loss: 0.0117 - root_mean_squared_error: 0.1278 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1278
# Epoch 169/200
# 8412/8412 [==============================] - 5s 558us/step - loss: 0.0115 - root_mean_squared_error: 0.1277 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1277
# Epoch 170/200
# 8412/8412 [==============================] - 5s 559us/step - loss: 0.0116 - root_mean_squared_error: 0.1276 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1276
# Epoch 171/200
# 8412/8412 [==============================] - 5s 539us/step - loss: 0.0116 - root_mean_squared_error: 0.1275 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1275
# Epoch 172/200
# 8412/8412 [==============================] - 4s 522us/step - loss: 0.0116 - root_mean_squared_error: 0.1275 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1274
# Epoch 173/200
# 8412/8412 [==============================] - 4s 531us/step - loss: 0.0116 - root_mean_squared_error: 0.1274 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1274
# Epoch 174/200
# 8412/8412 [==============================] - 4s 510us/step - loss: 0.0115 - root_mean_squared_error: 0.1273 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1273
# Epoch 175/200
# 8412/8412 [==============================] - 4s 516us/step - loss: 0.0116 - root_mean_squared_error: 0.1272 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1272
# Epoch 176/200
# 8412/8412 [==============================] - 5s 620us/step - loss: 0.0116 - root_mean_squared_error: 0.1272 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1271
# Epoch 177/200
# 8412/8412 [==============================] - 5s 547us/step - loss: 0.0116 - root_mean_squared_error: 0.1271 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1271
# Epoch 178/200
# 8412/8412 [==============================] - 4s 518us/step - loss: 0.0115 - root_mean_squared_error: 0.1270 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1270
# Epoch 179/200
# 8412/8412 [==============================] - 5s 543us/step - loss: 0.0114 - root_mean_squared_error: 0.1269 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1269
# Epoch 180/200
# 8412/8412 [==============================] - 5s 572us/step - loss: 0.0114 - root_mean_squared_error: 0.1269 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1268
# Epoch 181/200
# 8412/8412 [==============================] - 4s 527us/step - loss: 0.0113 - root_mean_squared_error: 0.1268 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1267
# Epoch 182/200
# 8412/8412 [==============================] - 4s 525us/step - loss: 0.0113 - root_mean_squared_error: 0.1267 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1267
# Epoch 183/200
# 8412/8412 [==============================] - 5s 593us/step - loss: 0.0114 - root_mean_squared_error: 0.1266 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1266
# Epoch 184/200
# 8412/8412 [==============================] - 4s 529us/step - loss: 0.0113 - root_mean_squared_error: 0.1266 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1265
# Epoch 185/200
# 8412/8412 [==============================] - 4s 527us/step - loss: 0.0114 - root_mean_squared_error: 0.1265 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1265
# Epoch 186/200
# 8412/8412 [==============================] - 5s 605us/step - loss: 0.0113 - root_mean_squared_error: 0.1264 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1264
# Epoch 187/200
# 8412/8412 [==============================] - 4s 529us/step - loss: 0.0113 - root_mean_squared_error: 0.1264 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1263
# Epoch 188/200
# 8412/8412 [==============================] - 4s 516us/step - loss: 0.0114 - root_mean_squared_error: 0.1263 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1263
# Epoch 189/200
# 8412/8412 [==============================] - 5s 576us/step - loss: 0.0114 - root_mean_squared_error: 0.1262 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1262
# Epoch 190/200
# 8412/8412 [==============================] - 5s 541us/step - loss: 0.0111 - root_mean_squared_error: 0.1262 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1261
# Epoch 191/200
# 8412/8412 [==============================] - 5s 540us/step - loss: 0.0113 - root_mean_squared_error: 0.1261 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1261
# Epoch 192/200
# 8412/8412 [==============================] - 5s 549us/step - loss: 0.0111 - root_mean_squared_error: 0.1260 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1260
# Epoch 193/200
# 8412/8412 [==============================] - 4s 526us/step - loss: 0.0112 - root_mean_squared_error: 0.1260 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1259
# Epoch 194/200
# 8412/8412 [==============================] - 5s 560us/step - loss: 0.0111 - root_mean_squared_error: 0.1259 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1259
# Epoch 195/200
# 8412/8412 [==============================] - 5s 544us/step - loss: 0.0112 - root_mean_squared_error: 0.1258 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1258
# Epoch 196/200
# 8412/8412 [==============================] - 5s 539us/step - loss: 0.0112 - root_mean_squared_error: 0.1258 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1257
# Epoch 197/200
# 8412/8412 [==============================] - 4s 524us/step - loss: 0.0112 - root_mean_squared_error: 0.1257 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1257
# Epoch 198/200
# 8412/8412 [==============================] - 5s 546us/step - loss: 0.0111 - root_mean_squared_error: 0.1256 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1256
# Epoch 199/200
# 8412/8412 [==============================] - 5s 564us/step - loss: 0.0111 - root_mean_squared_error: 0.1256 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1255
# Epoch 200/200
# 8412/8412 [==============================] - 5s 581us/step - loss: 0.0111 - root_mean_squared_error: 0.1255 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1255

# %%
predTrainM2 = model2.predict(Xtrain)
predValM2 = model2.predict(Xval)

#deshacemos la transformación logarítmica
predTrainM2_Eur = pd.DataFrame(predTrainM2).apply(lambda x: 10**(x))
predValM2_Eur = pd.DataFrame(predValM2).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel2 = mean_squared_error(Ytrain_Eur,predTrainM2_Eur)
mseValModel2 = mean_squared_error(Yval_Eur,predValM2_Eur)

print('MSE (train): %0.3g' % mseTrainModel2)
print('MSE (val) : %0.3g' % mseValModel2)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel2))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel2))
# Out:
# MSE (train): 367
# MSE (val) : 629
# RMSE (train): 19.2
# RMSE (val) : 25.1

# %% [markdown]
# Analizando los resultados podemos destacar los siguientes aspectos:
#
# Igual que en el ejercicio de clasificación el modelo 2 presenta algo de overfitting y además es más lento, por lo que nos decantamos por el modelo 1.
#
# Otra cosa a tener en cuenta es que en este ejercicio de regresión hemos usado más épocas. Esto se debe a que se puede observar como el RMSE sigue bajando a pesar de ejecutar más épocas. Esto significa que la red todavía no ha convergido al 100% y sigue aprendiendo. He probado a aumentar el learning rate, para que la red convergiera más rápido, pero se sigue dando la misma situación que estamos comentando. Por tanto, en este caso, por falta de tiempo lo hemos dejado así, pero se podría entrenar durante más tiempo y es muy probable que los resultados mejoraran algo.

# %%
# Evaluamos el modelo
scores = model.evaluate(Xtest, ytest)

print('Loss: %.3f' % scores[0])
print('RMSE: %.3f' % scores[1])
# Out:
# 2642/2642 [==============================] - 0s 50us/step
# Loss: 0.020
# RMSE: 0.144

# %%
predTrain = model.predict(Xtrain)
predTest = model.predict(Xtest)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predTest_Eur = pd.DataFrame(predTest).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(ytrain).apply(lambda x: 10**(x))
Ytest_Eur = pd.DataFrame(ytest).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseTestModel = mean_squared_error(Ytest_Eur,predTest_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (test) : %0.3g' % mseTestModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (test) : %0.3g' % np.sqrt(mseTestModel))
# Out:
# MSE (train): 706
# MSE (test) : 868
# RMSE (train): 26.6
# RMSE (test) : 29.5
