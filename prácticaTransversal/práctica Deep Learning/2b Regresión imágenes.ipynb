# %% [markdown]
# **REGRESIÓN PARTIENDO DE IMÁGENES**
#
# En este notebook vamos a tratar de hacer una regresión para estimar el precio de un apartamento de alquiler.
# Dicha predicción se va a hacer a partir de las imágenes que nos descargamos del dataset de airbnb que venimos usando en las prácticas de este Bootcamp.
#
# En primer lugar nos descargamos el fichero de internet y lo copiamos en un directorio local de My Drive donde tenemos recogido todo el entorno de esta práctica.
# A continuación hacemos lo mismo con las imágenes de cada una de las entradas. Usamos la vista en miniatura que sacamos de la URL de dicho fichero.
#
# También montamos el google collab con My Drive para tenerlo vinculado.
#
# Estos pasos solo hay que realizarlos la primera vez, una vez que tenemos los ficheros en My Drive se pueden saltar y pasamos a cargar los datos directamente desde dicho directorio.

# %%
# nos descargamos el dataset de OpenDataSoft
# !wget -O "airbnb-listings.csv" "https://public.opendatasoft.com/explore/dataset/airbnb-listings/download/?format=csv&disjunctive.host_verifications=true&disjunctive.amenities=true&disjunctive.features=true&refine.country=Spain&q=Madrid&timezone=Europe/London&use_labels_for_header=true&csv_separator=%3B"

# !ls -lah
# Out:
# --2020-06-25 06:01:03--  https://public.opendatasoft.com/explore/dataset/airbnb-listings/download/?format=csv&disjunctive.host_verifications=true&disjunctive.amenities=true&disjunctive.features=true&refine.country=Spain&q=Madrid&timezone=Europe/London&use_labels_for_header=true&csv_separator=%3B
# Resolving public.opendatasoft.com (public.opendatasoft.com)... 34.249.199.226, 34.248.20.69
# Connecting to public.opendatasoft.com (public.opendatasoft.com)|34.249.199.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/csv]
# Saving to: ‘airbnb-listings.csv’
#
# airbnb-listings.csv     [  <=>               ]  54.19M  2.77MB/s    in 50s
#
# 2020-06-25 06:02:01 (1.09 MB/s) - ‘airbnb-listings.csv’ saved [56826824]
#
# total 55M
# drwxr-xr-x 1 root root 4.0K Jun 25 06:01 .
# drwxr-xr-x 1 root root 4.0K Jun 25 05:59 ..
# -rw-r--r-- 1 root root  55M Jun 25 06:02 airbnb-listings.csv
# drwxr-xr-x 1 root root 4.0K Jun 19 16:15 .config
# drwx------ 4 root root 4.0K Jun 25 06:00 drive
# drwxr-xr-x 1 root root 4.0K Jun 17 16:18 sample_data

# %%
# !ls -lah
# Out:
# total 16K
# drwxr-xr-x 1 root root 4.0K Jun 17 16:18 .
# drwxr-xr-x 1 root root 4.0K Jun 26 05:15 ..
# drwxr-xr-x 1 root root 4.0K Jun 19 16:15 .config
# drwxr-xr-x 1 root root 4.0K Jun 17 16:18 sample_data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !cp airbnb-listings.csv "drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning"

# %%
# aquí creamos nuestra estructura de datos, que va a consistir en la url de la
# imagen y un índice para saber donde insertarla en nuestro array
images_paths = [[i, img_url] for i, img_url in enumerate(full_df['Thumbnail Url'])]
images_paths[:5]
# Out:
# [[0,
#   'https://a0.muscache.com/im/pictures/cffe393a-0d84-4fd5-ab4c-a62e067c1b0d.jpg?aki_policy=small'],
#  [1,
#   'https://a0.muscache.com/im/pictures/ea919e56-aa99-4d5d-a129-1edf0d117d6a.jpg?aki_policy=small'],
#  [2,
#   'https://a0.muscache.com/im/pictures/57011236/eea5c213_original.jpg?aki_policy=small'],
#  [3,
#   'https://a0.muscache.com/im/pictures/974f0245-55c2-4e8c-b9bf-14c1c975c798.jpg?aki_policy=small'],
#  [4,
#   'https://a0.muscache.com/im/pictures/c2dde263-20dd-43af-8c6b-be636c2c0ce1.jpg?aki_policy=small']]

# %%
import imageio as io
import cv2

# esta es la función que se descargará la imagen y devolverá la imagen y el 
# índice indicando la posición donde se incrustará la imagen en nuestro array
def get_image(data_url, target_size=(224, 224)):
    idx, url = data_url
    try:
        img = io.imread(url)
        # hay alguna imagen en blanco y negro y daría error al incluirla en 
        # nuestro array de imagenes que tiene 3 canales, así que convertimos
        # todas las imágenes que tengan menos de 3 dimensiones a color
        if img.ndim < 3:
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        img = cv2.resize(img, dsize=target_size)
        return img, idx
    except IOError as err:
        return (None, idx)

# %%
import numpy as np

# en este array iremos incrustando las imágenes conforme las vayamos obteniendo
loaded_images = np.zeros((len(images_paths), 224, 224, 3), dtype=np.uint8)

# y en este array llevaremos un control de cuales se han cargado correctamente
# y cuales no
was_loaded = np.zeros(len(images_paths))

# %%
import concurrent
from tqdm import tqdm

# creamos un pool de procesos que se irán descargando las imágenes
# por defecto, se crearán tantos como CPUs tenga vuestra máquina
with concurrent.futures.ProcessPoolExecutor() as executor:
    # procesamos la lista de urls de imágenes paralelizandola con el pool de procesos
    for (img, idx) in tqdm(executor.map(get_image, images_paths), total=len(images_paths)):
        # metemos la imagen en nuestro array
        if img is not None:
            loaded_images[idx] = img
            was_loaded[idx] = 1
        else:
            was_loaded[idx] = 0

print('Terminado!')
print(f'Total de imágenes recuperadas correctamente: {sum(was_loaded)}/{len(images_paths)}')
# Out:
# 100%|██████████| 14001/14001 [08:14<00:00, 28.29it/s]
# Terminado!
# Total de imágenes recuperadas correctamente: 11271.0/14001

# %%
# guardamos las imágenes (y yo os recomiendo que os lo guardéis en GDrive para evitar tener que repetir esto)
np.save('images.npy', loaded_images)
np.save('was_loaded.npy', was_loaded)

# %%
# almacenamos las imagenes en nuestro drive
# !cp images.npy "drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning"
# !cp was_loaded.npy "drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning"

# %% [markdown]
# Esta parte de descarga, montado y copiado solo hace falta ejecutarla la primera vez. Una vez que lo tenemos almacenado en My Drive solo necesitamos cargarlo directamente.
#
# A partir de aquí empieza nuestro ejercicio de regresión.
#
# Como hábito de buena costumbre, para no incurrir en errores involuntarios, en primer lugar se va a dividir el dataset original en train, validation y test.
#
# Se trabaja únicamente con el de train con el objetivo de elegir un modelo. Eso se verifica con el conjunto de validation y finalmente se aplica ese "entrenamiento" al bloque de test.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error


#hacemos la divisón en train, val y test
full_df = pd.read_csv('drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning/airbnb-listings.csv', sep=';', decimal='.')
full_train, test = train_test_split(full_df, test_size=0.2, shuffle=True, random_state=0)
train, val = train_test_split(full_train, test_size=0.2, shuffle=True, random_state=0)

print(f'Dimensiones del dataset de training: {train.shape}')
print(f'Dimensiones del dataset de validación: {val.shape}')
print(f'Dimensiones del dataset de test: {test.shape}')

# Guardamos
train.to_csv('./train.csv', sep=';', decimal='.', index=True)
val.to_csv('./val.csv', sep=';', decimal='.', index=True)
test.to_csv('./test.csv', sep=';', decimal='.', index=True)
# Out:
# Dimensiones del dataset de training: (8960, 89)
# Dimensiones del dataset de validación: (2240, 89)
# Dimensiones del dataset de test: (2801, 89)

# %%
#cargamos las imágenes desde el directorio de My Drive (ya las habíamos descargado previamente)
images  = np.load('drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning/images.npy')
was_loaded  = np.load('drive/My Drive/BootcampBD&ML/práctica/prácticaDeepLearning/was_loaded.npy')

#cargamos los datos ya divididos en train, val y test
df_train = pd.read_csv('./train.csv', sep=';', decimal='.')
df_val = pd.read_csv('./val.csv', sep=';', decimal='.')
df_test = pd.read_csv('./test.csv', sep=';', decimal='.')

#usando el índice de la división anterior obtenemos los conjuntos de test, val y test en las imágenes
train_imgs = images[df_train['Unnamed: 0']]
val_imgs = images[df_val['Unnamed: 0']]
test_imgs = images[df_test['Unnamed: 0']]

train_was_loaded = was_loaded[df_train['Unnamed: 0']]
val_was_loaded = was_loaded[df_val['Unnamed: 0']]
test_was_loaded = was_loaded[df_test['Unnamed: 0']]

print(f'Dimensiones del dataset de training: {train_imgs.shape}')
print(f'Dimensiones del dataset de validación: {val_imgs.shape}')
print(f'Dimensiones del dataset de test: {test_imgs.shape}')

print(f'Dimensiones del dataset de training: {train_was_loaded.shape}')
print(f'Dimensiones del dataset de validación: {val_was_loaded.shape}')
print(f'Dimensiones del dataset de test: {test_was_loaded.shape}')
# Out:
# Dimensiones del dataset de training: (8960, 224, 224, 3)
# Dimensiones del dataset de validación: (2240, 224, 224, 3)
# Dimensiones del dataset de test: (2801, 224, 224, 3)
# Dimensiones del dataset de training: (8960,)
# Dimensiones del dataset de validación: (2240,)
# Dimensiones del dataset de test: (2801,)

# %%
# nos quedamos con los datos e imágenes para los que hemos podido encontrar imágenes
train_imgs_loaded = train_imgs[train_was_loaded == 1]
val_imgs_loaded = val_imgs[val_was_loaded == 1]
test_imgs_loaded = test_imgs[test_was_loaded == 1]

train_with_imgs = df_train[train_was_loaded == 1]
val_with_imgs = df_val[val_was_loaded == 1]
test_with_imgs = df_test[test_was_loaded == 1]

print(f'Dimensiones del dataset de training: {train_imgs_loaded.shape}')
print(f'Dimensiones del dataset de validación: {val_imgs_loaded.shape}')
print(f'Dimensiones del dataset de test: {test_imgs_loaded.shape}')

print(f'Dimensiones del dataset de training: {train_with_imgs.shape}')
print(f'Dimensiones del dataset de validación: {val_with_imgs.shape}')
print(f'Dimensiones del dataset de test: {test_with_imgs.shape}')
# Out:
# Dimensiones del dataset de training: (7204, 224, 224, 3)
# Dimensiones del dataset de validación: (1790, 224, 224, 3)
# Dimensiones del dataset de test: (2277, 224, 224, 3)
# Dimensiones del dataset de training: (7204, 90)
# Dimensiones del dataset de validación: (1790, 90)
# Dimensiones del dataset de test: (2277, 90)

# %%
#PRICE
#imputamos valores vacíos con la media de train
MeanPriceTrain = train_with_imgs['Price'].mean()
train_with_imgs['Price'].fillna(MeanPriceTrain, inplace=True)
val_with_imgs['Price'].fillna(MeanPriceTrain, inplace=True)
test_with_imgs['Price'].fillna(MeanPriceTrain, inplace=True)
#definimos outlier >400€
#indexTrainFiltered = train_with_imgs[train_with_imgs['Price']>400].index
#train_with_imgs.drop(indexTrainFiltered, inplace=True)
#indexValFiltered = val_with_imgs[val_with_imgs['Price']>400].index
#val_with_imgs.drop(indexValFiltered, inplace=True)
#indexTestFiltered = test_with_imgs[test_with_imgs['Price']>400].index
#test_with_imgs.drop(indexTestFiltered, inplace=True)

#train_imgs_loaded.drop(indexTrainFiltered, inplace=True)
#val_imgs_loaded.drop(indexValFiltered, inplace=True)
#test_imgs_loaded.drop(indexTestFiltered, inplace=True)

#transformamos variable Price a gausiana
train_with_imgs['Price'] = train_with_imgs['Price'].apply(lambda x: np.log10(x))
val_with_imgs['Price'] = val_with_imgs['Price'].apply(lambda x: np.log10(x))
test_with_imgs['Price'] = test_with_imgs['Price'].apply(lambda x: np.log10(x))

print(f'Dimensiones del dataset de training: {train_imgs_loaded.shape}')
print(f'Dimensiones del dataset de validación: {val_imgs_loaded.shape}')
print(f'Dimensiones del dataset de test: {test_imgs_loaded.shape}')

print(f'Dimensiones del dataset de training: {train_with_imgs.shape}')
print(f'Dimensiones del dataset de validación: {val_with_imgs.shape}')
print(f'Dimensiones del dataset de test: {test_with_imgs.shape}')
# Out:
# Dimensiones del dataset de training: (7204, 224, 224, 3)
# Dimensiones del dataset de validación: (1790, 224, 224, 3)
# Dimensiones del dataset de test: (2277, 224, 224, 3)
# Dimensiones del dataset de training: (7204, 90)
# Dimensiones del dataset de validación: (1790, 90)
# Dimensiones del dataset de test: (2277, 90)

# %%
#Redimensionamos las imágenes de entrada. Estoy teniendo problemas de RAM y no puedo ejecutarlo
#con 224x224 no puedo escalar /255. Con 112x112 no puedo ejecutar el modelo
#es necesario asumir esta pérdida de información
train_imgs_loaded = np.resize(train_imgs_loaded, (train_imgs_loaded.shape[0],64, 64, train_imgs_loaded.shape[3]))
val_imgs_loaded = np.resize(val_imgs_loaded, (val_imgs_loaded.shape[0],64, 64, val_imgs_loaded.shape[3]))
test_imgs_loaded = np.resize(test_imgs_loaded, (test_imgs_loaded.shape[0],64, 64, test_imgs_loaded.shape[3]))

print(f'Dimensiones del dataset de training: {train_imgs_loaded.shape}')
print(f'Dimensiones del dataset de training: {val_imgs_loaded.shape}')
print(f'Dimensiones del dataset de training: {test_imgs_loaded.shape}')
# Out:
# Dimensiones del dataset de training: (7204, 64, 64, 3)
# Dimensiones del dataset de training: (1790, 64, 64, 3)
# Dimensiones del dataset de training: (2277, 64, 64, 3)

# %%
#escalamos los datos de entrada. Lo hago en celdas separadas ya que hay algún problema de RAM
#se trata de imágenes así que no hace falta centrar, solo dividimos por el máximo. 
# nos aseguramos de hacerlo como float para no perder la info de los decimales

train_imgs_loaded = train_imgs_loaded.astype('float32') / 255.

# %%
val_imgs_loaded = val_imgs_loaded.astype('float32') / 255.

# %%
test_imgs_loaded = test_imgs_loaded.astype('float32') / 255.

# %%
#extraemos la variable objetivo
Ytrain = train_with_imgs['Price']
Yval = val_with_imgs['Price']
Ytest = test_with_imgs['Price']

# %% [markdown]
# Una vez que ya tenemos los datos de las imágenes y la variable objetivo preparados, definimos los modelos con los que vamos a ir trabajando.
#
# La idea general es usar una red neuronal convolucional (CNN) donde las primeras capas actúan como extractor de características y añadimos un clasificador final.

# %%
# imports necesarios
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.layers import BatchNormalization, Activation
from keras.layers import Dropout
from keras.utils import to_categorical

# Inizializamos el modelo
model = Sequential()

# Definimos una capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(64, 64, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Definimos una segunda capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Definimos una tercera capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Añadimos nuestro clasificador
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation="linear"))

# Compilamos el modelo
model.compile(loss='mse',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Entrenamos el modelo
model.fit(train_imgs_loaded, Ytrain,
          batch_size=128,
          shuffle=True,
          epochs=100,
          validation_data=(val_imgs_loaded, Yval))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 7204 samples, validate on 1790 samples
# Epoch 1/100
# 7204/7204 [==============================] - 10s 1ms/step - loss: 6.5384 - root_mean_squared_error: 3.3127 - val_loss: 2.9495 - val_root_mean_squared_error: 2.4749
# Epoch 2/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 1.4493 - root_mean_squared_error: 2.1627 - val_loss: 2.9437 - val_root_mean_squared_error: 1.9560
# Epoch 3/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.6527 - root_mean_squared_error: 1.8108 - val_loss: 2.9201 - val_root_mean_squared_error: 1.7000
# Epoch 4/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.4295 - root_mean_squared_error: 1.6138 - val_loss: 2.8697 - val_root_mean_squared_error: 1.5446
# Epoch 5/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.3295 - root_mean_squared_error: 1.4863 - val_loss: 2.7747 - val_root_mean_squared_error: 1.4379
# Epoch 6/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.2971 - root_mean_squared_error: 1.3959 - val_loss: 2.6319 - val_root_mean_squared_error: 1.3597
# Epoch 7/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.2449 - root_mean_squared_error: 1.3263 - val_loss: 2.4519 - val_root_mean_squared_error: 1.2972
# Epoch 8/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.2325 - root_mean_squared_error: 1.2701 - val_loss: 2.2275 - val_root_mean_squared_error: 1.2458
# Epoch 9/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.2150 - root_mean_squared_error: 1.2227 - val_loss: 1.9289 - val_root_mean_squared_error: 1.2014
# Epoch 10/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.2036 - root_mean_squared_error: 1.1809 - val_loss: 1.6345 - val_root_mean_squared_error: 1.1618
# Epoch 11/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.1953 - root_mean_squared_error: 1.1433 - val_loss: 1.4281 - val_root_mean_squared_error: 1.1262
# Epoch 12/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1823 - root_mean_squared_error: 1.1094 - val_loss: 1.2690 - val_root_mean_squared_error: 1.0938
# Epoch 13/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1786 - root_mean_squared_error: 1.0787 - val_loss: 1.1896 - val_root_mean_squared_error: 1.0648
# Epoch 14/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1772 - root_mean_squared_error: 1.0512 - val_loss: 1.2091 - val_root_mean_squared_error: 1.0390
# Epoch 15/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.1731 - root_mean_squared_error: 1.0270 - val_loss: 1.1615 - val_root_mean_squared_error: 1.0160
# Epoch 16/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1701 - root_mean_squared_error: 1.0051 - val_loss: 1.1638 - val_root_mean_squared_error: 0.9952
# Epoch 17/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1643 - root_mean_squared_error: 0.9854 - val_loss: 1.2176 - val_root_mean_squared_error: 0.9766
# Epoch 18/100
# 7204/7204 [==============================] - 3s 384us/step - loss: 0.1612 - root_mean_squared_error: 0.9678 - val_loss: 1.2199 - val_root_mean_squared_error: 0.9598
# Epoch 19/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1604 - root_mean_squared_error: 0.9518 - val_loss: 1.1970 - val_root_mean_squared_error: 0.9445
# Epoch 20/100
# 7204/7204 [==============================] - 3s 385us/step - loss: 0.1572 - root_mean_squared_error: 0.9370 - val_loss: 1.2097 - val_root_mean_squared_error: 0.9304
# Epoch 21/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1538 - root_mean_squared_error: 0.9235 - val_loss: 1.1993 - val_root_mean_squared_error: 0.9173
# Epoch 22/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1497 - root_mean_squared_error: 0.9110 - val_loss: 1.2057 - val_root_mean_squared_error: 0.9053
# Epoch 23/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1489 - root_mean_squared_error: 0.8994 - val_loss: 1.2036 - val_root_mean_squared_error: 0.8941
# Epoch 24/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1487 - root_mean_squared_error: 0.8886 - val_loss: 1.1745 - val_root_mean_squared_error: 0.8836
# Epoch 25/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1474 - root_mean_squared_error: 0.8785 - val_loss: 1.1669 - val_root_mean_squared_error: 0.8738
# Epoch 26/100
# 7204/7204 [==============================] - 3s 385us/step - loss: 0.1437 - root_mean_squared_error: 0.8689 - val_loss: 1.1848 - val_root_mean_squared_error: 0.8646
# Epoch 27/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1457 - root_mean_squared_error: 0.8601 - val_loss: 1.2364 - val_root_mean_squared_error: 0.8562
# Epoch 28/100
# 7204/7204 [==============================] - 3s 385us/step - loss: 0.1420 - root_mean_squared_error: 0.8520 - val_loss: 1.1936 - val_root_mean_squared_error: 0.8483
# Epoch 29/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.1414 - root_mean_squared_error: 0.8443 - val_loss: 1.1439 - val_root_mean_squared_error: 0.8406
# Epoch 30/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1447 - root_mean_squared_error: 0.8368 - val_loss: 1.1510 - val_root_mean_squared_error: 0.8334
# Epoch 31/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1404 - root_mean_squared_error: 0.8297 - val_loss: 1.1510 - val_root_mean_squared_error: 0.8265
# Epoch 32/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1387 - root_mean_squared_error: 0.8230 - val_loss: 1.1357 - val_root_mean_squared_error: 0.8199
# Epoch 33/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1387 - root_mean_squared_error: 0.8166 - val_loss: 1.1889 - val_root_mean_squared_error: 0.8138
# Epoch 34/100
# 7204/7204 [==============================] - 3s 385us/step - loss: 0.1385 - root_mean_squared_error: 0.8108 - val_loss: 1.1599 - val_root_mean_squared_error: 0.8080
# Epoch 35/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1344 - root_mean_squared_error: 0.8050 - val_loss: 1.1699 - val_root_mean_squared_error: 0.8025
# Epoch 36/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1344 - root_mean_squared_error: 0.7997 - val_loss: 1.1236 - val_root_mean_squared_error: 0.7971
# Epoch 37/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1347 - root_mean_squared_error: 0.7944 - val_loss: 1.1400 - val_root_mean_squared_error: 0.7919
# Epoch 38/100
# 7204/7204 [==============================] - 3s 388us/step - loss: 0.1347 - root_mean_squared_error: 0.7893 - val_loss: 1.1381 - val_root_mean_squared_error: 0.7871
# Epoch 39/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1332 - root_mean_squared_error: 0.7845 - val_loss: 1.1914 - val_root_mean_squared_error: 0.7825
# Epoch 40/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1301 - root_mean_squared_error: 0.7801 - val_loss: 1.1819 - val_root_mean_squared_error: 0.7781
# Epoch 41/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1331 - root_mean_squared_error: 0.7759 - val_loss: 1.1663 - val_root_mean_squared_error: 0.7739
# Epoch 42/100
# 7204/7204 [==============================] - 3s 390us/step - loss: 0.1354 - root_mean_squared_error: 0.7718 - val_loss: 1.1944 - val_root_mean_squared_error: 0.7700
# Epoch 43/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1298 - root_mean_squared_error: 0.7679 - val_loss: 1.1394 - val_root_mean_squared_error: 0.7661
# Epoch 44/100
# 7204/7204 [==============================] - 3s 386us/step - loss: 0.1306 - root_mean_squared_error: 0.7640 - val_loss: 1.1984 - val_root_mean_squared_error: 0.7624
# Epoch 45/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1301 - root_mean_squared_error: 0.7605 - val_loss: 1.1786 - val_root_mean_squared_error: 0.7588
# Epoch 46/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1276 - root_mean_squared_error: 0.7570 - val_loss: 1.1672 - val_root_mean_squared_error: 0.7554
# Epoch 47/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1270 - root_mean_squared_error: 0.7536 - val_loss: 1.1465 - val_root_mean_squared_error: 0.7520
# Epoch 48/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1266 - root_mean_squared_error: 0.7502 - val_loss: 1.1736 - val_root_mean_squared_error: 0.7488
# Epoch 49/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1239 - root_mean_squared_error: 0.7471 - val_loss: 1.1438 - val_root_mean_squared_error: 0.7456
# Epoch 50/100
# 7204/7204 [==============================] - 3s 395us/step - loss: 0.1275 - root_mean_squared_error: 0.7439 - val_loss: 1.1476 - val_root_mean_squared_error: 0.7426
# Epoch 51/100
# 7204/7204 [==============================] - 3s 395us/step - loss: 0.1249 - root_mean_squared_error: 0.7410 - val_loss: 1.2005 - val_root_mean_squared_error: 0.7397
# Epoch 52/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1246 - root_mean_squared_error: 0.7382 - val_loss: 1.1754 - val_root_mean_squared_error: 0.7369
# Epoch 53/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1258 - root_mean_squared_error: 0.7355 - val_loss: 1.1847 - val_root_mean_squared_error: 0.7343
# Epoch 54/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1232 - root_mean_squared_error: 0.7329 - val_loss: 1.1933 - val_root_mean_squared_error: 0.7317
# Epoch 55/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1258 - root_mean_squared_error: 0.7303 - val_loss: 1.1938 - val_root_mean_squared_error: 0.7292
# Epoch 56/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1276 - root_mean_squared_error: 0.7279 - val_loss: 1.1283 - val_root_mean_squared_error: 0.7268
# Epoch 57/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1251 - root_mean_squared_error: 0.7254 - val_loss: 1.1460 - val_root_mean_squared_error: 0.7243
# Epoch 58/100
# 7204/7204 [==============================] - 3s 390us/step - loss: 0.1247 - root_mean_squared_error: 0.7231 - val_loss: 1.0806 - val_root_mean_squared_error: 0.7219
# Epoch 59/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1226 - root_mean_squared_error: 0.7206 - val_loss: 1.1099 - val_root_mean_squared_error: 0.7195
# Epoch 60/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1214 - root_mean_squared_error: 0.7182 - val_loss: 1.1276 - val_root_mean_squared_error: 0.7172
# Epoch 61/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1239 - root_mean_squared_error: 0.7160 - val_loss: 1.1196 - val_root_mean_squared_error: 0.7150
# Epoch 62/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1206 - root_mean_squared_error: 0.7138 - val_loss: 1.1309 - val_root_mean_squared_error: 0.7129
# Epoch 63/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1196 - root_mean_squared_error: 0.7117 - val_loss: 1.1922 - val_root_mean_squared_error: 0.7108
# Epoch 64/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1199 - root_mean_squared_error: 0.7098 - val_loss: 1.1287 - val_root_mean_squared_error: 0.7089
# Epoch 65/100
# 7204/7204 [==============================] - 3s 395us/step - loss: 0.1196 - root_mean_squared_error: 0.7078 - val_loss: 1.1014 - val_root_mean_squared_error: 0.7069
# Epoch 66/100
# 7204/7204 [==============================] - 3s 395us/step - loss: 0.1192 - root_mean_squared_error: 0.7058 - val_loss: 1.1097 - val_root_mean_squared_error: 0.7049
# Epoch 67/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1202 - root_mean_squared_error: 0.7038 - val_loss: 1.1571 - val_root_mean_squared_error: 0.7030
# Epoch 68/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1217 - root_mean_squared_error: 0.7021 - val_loss: 1.1670 - val_root_mean_squared_error: 0.7013
# Epoch 69/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1209 - root_mean_squared_error: 0.7004 - val_loss: 1.1760 - val_root_mean_squared_error: 0.6996
# Epoch 70/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1194 - root_mean_squared_error: 0.6987 - val_loss: 1.1282 - val_root_mean_squared_error: 0.6979
# Epoch 71/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1182 - root_mean_squared_error: 0.6970 - val_loss: 1.1330 - val_root_mean_squared_error: 0.6962
# Epoch 72/100
# 7204/7204 [==============================] - 3s 397us/step - loss: 0.1148 - root_mean_squared_error: 0.6953 - val_loss: 1.1834 - val_root_mean_squared_error: 0.6946
# Epoch 73/100
# 7204/7204 [==============================] - 3s 396us/step - loss: 0.1181 - root_mean_squared_error: 0.6938 - val_loss: 1.1809 - val_root_mean_squared_error: 0.6931
# Epoch 74/100
# 7204/7204 [==============================] - 3s 396us/step - loss: 0.1189 - root_mean_squared_error: 0.6923 - val_loss: 1.1458 - val_root_mean_squared_error: 0.6916
# Epoch 75/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1187 - root_mean_squared_error: 0.6908 - val_loss: 1.1329 - val_root_mean_squared_error: 0.6901
# Epoch 76/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1142 - root_mean_squared_error: 0.6892 - val_loss: 1.1170 - val_root_mean_squared_error: 0.6885
# Epoch 77/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1157 - root_mean_squared_error: 0.6877 - val_loss: 1.1374 - val_root_mean_squared_error: 0.6871
# Epoch 78/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1147 - root_mean_squared_error: 0.6863 - val_loss: 1.0690 - val_root_mean_squared_error: 0.6856
# Epoch 79/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1187 - root_mean_squared_error: 0.6847 - val_loss: 1.0344 - val_root_mean_squared_error: 0.6840
# Epoch 80/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1181 - root_mean_squared_error: 0.6832 - val_loss: 1.1237 - val_root_mean_squared_error: 0.6826
# Epoch 81/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1168 - root_mean_squared_error: 0.6818 - val_loss: 1.0755 - val_root_mean_squared_error: 0.6812
# Epoch 82/100
# 7204/7204 [==============================] - 3s 390us/step - loss: 0.1156 - root_mean_squared_error: 0.6804 - val_loss: 1.0569 - val_root_mean_squared_error: 0.6797
# Epoch 83/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1145 - root_mean_squared_error: 0.6790 - val_loss: 1.0503 - val_root_mean_squared_error: 0.6783
# Epoch 84/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1145 - root_mean_squared_error: 0.6775 - val_loss: 1.0340 - val_root_mean_squared_error: 0.6769
# Epoch 85/100
# 7204/7204 [==============================] - 3s 393us/step - loss: 0.1160 - root_mean_squared_error: 0.6761 - val_loss: 1.0112 - val_root_mean_squared_error: 0.6755
# Epoch 86/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1181 - root_mean_squared_error: 0.6747 - val_loss: 1.0403 - val_root_mean_squared_error: 0.6741
# Epoch 87/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1135 - root_mean_squared_error: 0.6734 - val_loss: 1.1219 - val_root_mean_squared_error: 0.6729
# Epoch 88/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1156 - root_mean_squared_error: 0.6722 - val_loss: 1.0698 - val_root_mean_squared_error: 0.6717
# Epoch 89/100
# 7204/7204 [==============================] - 3s 393us/step - loss: 0.1157 - root_mean_squared_error: 0.6710 - val_loss: 1.0740 - val_root_mean_squared_error: 0.6705
# Epoch 90/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1136 - root_mean_squared_error: 0.6698 - val_loss: 1.2045 - val_root_mean_squared_error: 0.6694
# Epoch 91/100
# 7204/7204 [==============================] - 3s 390us/step - loss: 0.1121 - root_mean_squared_error: 0.6688 - val_loss: 1.0725 - val_root_mean_squared_error: 0.6683
# Epoch 92/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1125 - root_mean_squared_error: 0.6676 - val_loss: 1.1170 - val_root_mean_squared_error: 0.6672
# Epoch 93/100
# 7204/7204 [==============================] - 3s 392us/step - loss: 0.1105 - root_mean_squared_error: 0.6665 - val_loss: 1.0884 - val_root_mean_squared_error: 0.6660
# Epoch 94/100
# 7204/7204 [==============================] - 3s 394us/step - loss: 0.1149 - root_mean_squared_error: 0.6654 - val_loss: 1.0939 - val_root_mean_squared_error: 0.6650
# Epoch 95/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1119 - root_mean_squared_error: 0.6644 - val_loss: 0.9980 - val_root_mean_squared_error: 0.6638
# Epoch 96/100
# 7204/7204 [==============================] - 3s 389us/step - loss: 0.1148 - root_mean_squared_error: 0.6632 - val_loss: 1.0523 - val_root_mean_squared_error: 0.6627
# Epoch 97/100
# 7204/7204 [==============================] - 3s 387us/step - loss: 0.1100 - root_mean_squared_error: 0.6621 - val_loss: 1.1229 - val_root_mean_squared_error: 0.6616
# Epoch 98/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1090 - root_mean_squared_error: 0.6611 - val_loss: 1.1218 - val_root_mean_squared_error: 0.6607
# Epoch 99/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1121 - root_mean_squared_error: 0.6601 - val_loss: 1.1180 - val_root_mean_squared_error: 0.6597
# Epoch 100/100
# 7204/7204 [==============================] - 3s 391us/step - loss: 0.1120 - root_mean_squared_error: 0.6592 - val_loss: 1.0440 - val_root_mean_squared_error: 0.6587

# %% [markdown]
# Al tratarse de una regresión volvemos a usar el RMSE para comparar los modelos.
#
# Aquí se observa también que a pesar de aumentar el número de épocas el modelo sigue aprendiendo (por falta de tiempo lo dejamos aquí, pero se podría dejar más tiempo hasta que convergiera del todo).

# %%
predTrain = model.predict(train_imgs_loaded)
predVal = model.predict(val_imgs_loaded)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predVal_Eur = pd.DataFrame(predVal).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(Ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(Yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseValModel = mean_squared_error(Yval_Eur,predVal_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (val) : %0.3g' % mseValModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel))
# Out:
# MSE (train): 7.89e+03
# MSE (val) : 6.25e+03
# RMSE (train): 88.8
# RMSE (val) : 79

# %%
#quito el BatchNormalization

# Inizializamos el modelo
model = Sequential()

# Definimos una capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(64, 64, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Definimos una segunda capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Definimos una tercera capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Añadimos nuestro clasificador
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation="linear"))

# Compilamos el modelo
model.compile(loss='mse',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])


# Entrenamos el modelo
model.fit(train_imgs_loaded, Ytrain,
          batch_size=128,
          shuffle=True,
          epochs=100,
          validation_data=(val_imgs_loaded, Yval))
# Out:
# Train on 7204 samples, validate on 1790 samples
# Epoch 1/100
# 7204/7204 [==============================] - 2s 321us/step - loss: 0.3710 - root_mean_squared_error: 0.7828 - val_loss: 1.3954 - val_root_mean_squared_error: 0.6961
# Epoch 2/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.2034 - root_mean_squared_error: 0.6882 - val_loss: 1.4364 - val_root_mean_squared_error: 0.6820
# Epoch 3/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1759 - root_mean_squared_error: 0.6761 - val_loss: 1.5538 - val_root_mean_squared_error: 0.6756
# Epoch 4/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1473 - root_mean_squared_error: 0.6720 - val_loss: 1.3771 - val_root_mean_squared_error: 0.6667
# Epoch 5/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1265 - root_mean_squared_error: 0.6600 - val_loss: 1.0654 - val_root_mean_squared_error: 0.6510
# Epoch 6/100
# 7204/7204 [==============================] - 2s 266us/step - loss: 0.1164 - root_mean_squared_error: 0.6420 - val_loss: 0.8705 - val_root_mean_squared_error: 0.6327
# Epoch 7/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.1133 - root_mean_squared_error: 0.6238 - val_loss: 0.7520 - val_root_mean_squared_error: 0.6154
# Epoch 8/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1132 - root_mean_squared_error: 0.6074 - val_loss: 0.7918 - val_root_mean_squared_error: 0.6015
# Epoch 9/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1057 - root_mean_squared_error: 0.5951 - val_loss: 0.8332 - val_root_mean_squared_error: 0.5906
# Epoch 10/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.1047 - root_mean_squared_error: 0.5857 - val_loss: 0.7663 - val_root_mean_squared_error: 0.5815
# Epoch 11/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.1085 - root_mean_squared_error: 0.5770 - val_loss: 0.7586 - val_root_mean_squared_error: 0.5736
# Epoch 12/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1068 - root_mean_squared_error: 0.5697 - val_loss: 0.6965 - val_root_mean_squared_error: 0.5663
# Epoch 13/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1042 - root_mean_squared_error: 0.5625 - val_loss: 0.7203 - val_root_mean_squared_error: 0.5597
# Epoch 14/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1020 - root_mean_squared_error: 0.5565 - val_loss: 0.6501 - val_root_mean_squared_error: 0.5535
# Epoch 15/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.1020 - root_mean_squared_error: 0.5503 - val_loss: 0.6580 - val_root_mean_squared_error: 0.5477
# Epoch 16/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1026 - root_mean_squared_error: 0.5449 - val_loss: 0.6583 - val_root_mean_squared_error: 0.5427
# Epoch 17/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1032 - root_mean_squared_error: 0.5403 - val_loss: 0.6221 - val_root_mean_squared_error: 0.5381
# Epoch 18/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1038 - root_mean_squared_error: 0.5357 - val_loss: 0.6488 - val_root_mean_squared_error: 0.5339
# Epoch 19/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1016 - root_mean_squared_error: 0.5318 - val_loss: 0.5751 - val_root_mean_squared_error: 0.5298
# Epoch 20/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1003 - root_mean_squared_error: 0.5276 - val_loss: 0.5563 - val_root_mean_squared_error: 0.5257
# Epoch 21/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1021 - root_mean_squared_error: 0.5235 - val_loss: 0.5684 - val_root_mean_squared_error: 0.5219
# Epoch 22/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1014 - root_mean_squared_error: 0.5200 - val_loss: 0.4988 - val_root_mean_squared_error: 0.5181
# Epoch 23/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.1017 - root_mean_squared_error: 0.5161 - val_loss: 0.5278 - val_root_mean_squared_error: 0.5146
# Epoch 24/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.1013 - root_mean_squared_error: 0.5128 - val_loss: 0.4451 - val_root_mean_squared_error: 0.5110
# Epoch 25/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1005 - root_mean_squared_error: 0.5091 - val_loss: 0.4161 - val_root_mean_squared_error: 0.5072
# Epoch 26/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0993 - root_mean_squared_error: 0.5053 - val_loss: 0.4050 - val_root_mean_squared_error: 0.5036
# Epoch 27/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1017 - root_mean_squared_error: 0.5018 - val_loss: 0.4043 - val_root_mean_squared_error: 0.5002
# Epoch 28/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1007 - root_mean_squared_error: 0.4985 - val_loss: 0.3476 - val_root_mean_squared_error: 0.4968
# Epoch 29/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0994 - root_mean_squared_error: 0.4950 - val_loss: 0.3422 - val_root_mean_squared_error: 0.4933
# Epoch 30/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0990 - root_mean_squared_error: 0.4916 - val_loss: 0.2911 - val_root_mean_squared_error: 0.4899
# Epoch 31/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0996 - root_mean_squared_error: 0.4881 - val_loss: 0.2849 - val_root_mean_squared_error: 0.4865
# Epoch 32/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0990 - root_mean_squared_error: 0.4848 - val_loss: 0.2493 - val_root_mean_squared_error: 0.4831
# Epoch 33/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0990 - root_mean_squared_error: 0.4814 - val_loss: 0.2429 - val_root_mean_squared_error: 0.4798
# Epoch 34/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0988 - root_mean_squared_error: 0.4781 - val_loss: 0.2068 - val_root_mean_squared_error: 0.4765
# Epoch 35/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.1000 - root_mean_squared_error: 0.4748 - val_loss: 0.2299 - val_root_mean_squared_error: 0.4734
# Epoch 36/100
# 7204/7204 [==============================] - 2s 258us/step - loss: 0.0992 - root_mean_squared_error: 0.4718 - val_loss: 0.1879 - val_root_mean_squared_error: 0.4703
# Epoch 37/100
# 7204/7204 [==============================] - 2s 258us/step - loss: 0.0991 - root_mean_squared_error: 0.4688 - val_loss: 0.1719 - val_root_mean_squared_error: 0.4673
# Epoch 38/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0984 - root_mean_squared_error: 0.4657 - val_loss: 0.1725 - val_root_mean_squared_error: 0.4643
# Epoch 39/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0983 - root_mean_squared_error: 0.4628 - val_loss: 0.1569 - val_root_mean_squared_error: 0.4614
# Epoch 40/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0993 - root_mean_squared_error: 0.4600 - val_loss: 0.1670 - val_root_mean_squared_error: 0.4586
# Epoch 41/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0974 - root_mean_squared_error: 0.4573 - val_loss: 0.1634 - val_root_mean_squared_error: 0.4560
# Epoch 42/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0978 - root_mean_squared_error: 0.4547 - val_loss: 0.1441 - val_root_mean_squared_error: 0.4534
# Epoch 43/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0968 - root_mean_squared_error: 0.4521 - val_loss: 0.1505 - val_root_mean_squared_error: 0.4508
# Epoch 44/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0970 - root_mean_squared_error: 0.4496 - val_loss: 0.1458 - val_root_mean_squared_error: 0.4484
# Epoch 45/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0982 - root_mean_squared_error: 0.4472 - val_loss: 0.1591 - val_root_mean_squared_error: 0.4461
# Epoch 46/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0975 - root_mean_squared_error: 0.4450 - val_loss: 0.1487 - val_root_mean_squared_error: 0.4439
# Epoch 47/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0971 - root_mean_squared_error: 0.4428 - val_loss: 0.1473 - val_root_mean_squared_error: 0.4417
# Epoch 48/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0988 - root_mean_squared_error: 0.4407 - val_loss: 0.1309 - val_root_mean_squared_error: 0.4396
# Epoch 49/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0968 - root_mean_squared_error: 0.4386 - val_loss: 0.1402 - val_root_mean_squared_error: 0.4376
# Epoch 50/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0979 - root_mean_squared_error: 0.4366 - val_loss: 0.1435 - val_root_mean_squared_error: 0.4356
# Epoch 51/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0972 - root_mean_squared_error: 0.4347 - val_loss: 0.1467 - val_root_mean_squared_error: 0.4337
# Epoch 52/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0983 - root_mean_squared_error: 0.4328 - val_loss: 0.1308 - val_root_mean_squared_error: 0.4319
# Epoch 53/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0991 - root_mean_squared_error: 0.4310 - val_loss: 0.1374 - val_root_mean_squared_error: 0.4302
# Epoch 54/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0969 - root_mean_squared_error: 0.4293 - val_loss: 0.1280 - val_root_mean_squared_error: 0.4284
# Epoch 55/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0970 - root_mean_squared_error: 0.4275 - val_loss: 0.1224 - val_root_mean_squared_error: 0.4267
# Epoch 56/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0971 - root_mean_squared_error: 0.4258 - val_loss: 0.1206 - val_root_mean_squared_error: 0.4250
# Epoch 57/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0975 - root_mean_squared_error: 0.4242 - val_loss: 0.1363 - val_root_mean_squared_error: 0.4234
# Epoch 58/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0978 - root_mean_squared_error: 0.4227 - val_loss: 0.1218 - val_root_mean_squared_error: 0.4219
# Epoch 59/100
# 7204/7204 [==============================] - 2s 266us/step - loss: 0.0970 - root_mean_squared_error: 0.4211 - val_loss: 0.1164 - val_root_mean_squared_error: 0.4203
# Epoch 60/100
# 7204/7204 [==============================] - 2s 266us/step - loss: 0.0968 - root_mean_squared_error: 0.4196 - val_loss: 0.1158 - val_root_mean_squared_error: 0.4188
# Epoch 61/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0964 - root_mean_squared_error: 0.4181 - val_loss: 0.1150 - val_root_mean_squared_error: 0.4173
# Epoch 62/100
# 7204/7204 [==============================] - 2s 267us/step - loss: 0.0968 - root_mean_squared_error: 0.4166 - val_loss: 0.1281 - val_root_mean_squared_error: 0.4159
# Epoch 63/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0963 - root_mean_squared_error: 0.4152 - val_loss: 0.1065 - val_root_mean_squared_error: 0.4145
# Epoch 64/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0967 - root_mean_squared_error: 0.4139 - val_loss: 0.1226 - val_root_mean_squared_error: 0.4132
# Epoch 65/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0966 - root_mean_squared_error: 0.4125 - val_loss: 0.1101 - val_root_mean_squared_error: 0.4119
# Epoch 66/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0972 - root_mean_squared_error: 0.4112 - val_loss: 0.1232 - val_root_mean_squared_error: 0.4106
# Epoch 67/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0978 - root_mean_squared_error: 0.4100 - val_loss: 0.1176 - val_root_mean_squared_error: 0.4094
# Epoch 68/100
# 7204/7204 [==============================] - 2s 258us/step - loss: 0.0983 - root_mean_squared_error: 0.4088 - val_loss: 0.1142 - val_root_mean_squared_error: 0.4082
# Epoch 69/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0964 - root_mean_squared_error: 0.4076 - val_loss: 0.1180 - val_root_mean_squared_error: 0.4070
# Epoch 70/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0957 - root_mean_squared_error: 0.4065 - val_loss: 0.1135 - val_root_mean_squared_error: 0.4059
# Epoch 71/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0957 - root_mean_squared_error: 0.4053 - val_loss: 0.1133 - val_root_mean_squared_error: 0.4047
# Epoch 72/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0959 - root_mean_squared_error: 0.4042 - val_loss: 0.1082 - val_root_mean_squared_error: 0.4036
# Epoch 73/100
# 7204/7204 [==============================] - 2s 258us/step - loss: 0.0968 - root_mean_squared_error: 0.4031 - val_loss: 0.1127 - val_root_mean_squared_error: 0.4025
# Epoch 74/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0957 - root_mean_squared_error: 0.4020 - val_loss: 0.1104 - val_root_mean_squared_error: 0.4015
# Epoch 75/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0961 - root_mean_squared_error: 0.4010 - val_loss: 0.1132 - val_root_mean_squared_error: 0.4004
# Epoch 76/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0958 - root_mean_squared_error: 0.3999 - val_loss: 0.1043 - val_root_mean_squared_error: 0.3994
# Epoch 77/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0961 - root_mean_squared_error: 0.3989 - val_loss: 0.1115 - val_root_mean_squared_error: 0.3984
# Epoch 78/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0951 - root_mean_squared_error: 0.3979 - val_loss: 0.1030 - val_root_mean_squared_error: 0.3974
# Epoch 79/100
# 7204/7204 [==============================] - 2s 258us/step - loss: 0.0952 - root_mean_squared_error: 0.3969 - val_loss: 0.1093 - val_root_mean_squared_error: 0.3965
# Epoch 80/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0965 - root_mean_squared_error: 0.3960 - val_loss: 0.1020 - val_root_mean_squared_error: 0.3955
# Epoch 81/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0962 - root_mean_squared_error: 0.3951 - val_loss: 0.0977 - val_root_mean_squared_error: 0.3946
# Epoch 82/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0942 - root_mean_squared_error: 0.3941 - val_loss: 0.1183 - val_root_mean_squared_error: 0.3937
# Epoch 83/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0945 - root_mean_squared_error: 0.3933 - val_loss: 0.1129 - val_root_mean_squared_error: 0.3928
# Epoch 84/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0956 - root_mean_squared_error: 0.3924 - val_loss: 0.0999 - val_root_mean_squared_error: 0.3920
# Epoch 85/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0961 - root_mean_squared_error: 0.3916 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3911
# Epoch 86/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0946 - root_mean_squared_error: 0.3907 - val_loss: 0.1051 - val_root_mean_squared_error: 0.3903
# Epoch 87/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0943 - root_mean_squared_error: 0.3899 - val_loss: 0.1075 - val_root_mean_squared_error: 0.3895
# Epoch 88/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0946 - root_mean_squared_error: 0.3891 - val_loss: 0.1016 - val_root_mean_squared_error: 0.3887
# Epoch 89/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0972 - root_mean_squared_error: 0.3883 - val_loss: 0.1099 - val_root_mean_squared_error: 0.3879
# Epoch 90/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0939 - root_mean_squared_error: 0.3875 - val_loss: 0.0992 - val_root_mean_squared_error: 0.3871
# Epoch 91/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0939 - root_mean_squared_error: 0.3867 - val_loss: 0.1127 - val_root_mean_squared_error: 0.3864
# Epoch 92/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0940 - root_mean_squared_error: 0.3860 - val_loss: 0.1010 - val_root_mean_squared_error: 0.3856
# Epoch 93/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0940 - root_mean_squared_error: 0.3852 - val_loss: 0.1010 - val_root_mean_squared_error: 0.3849
# Epoch 94/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0928 - root_mean_squared_error: 0.3845 - val_loss: 0.1018 - val_root_mean_squared_error: 0.3841
# Epoch 95/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0944 - root_mean_squared_error: 0.3838 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3834
# Epoch 96/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0926 - root_mean_squared_error: 0.3831 - val_loss: 0.0971 - val_root_mean_squared_error: 0.3827
# Epoch 97/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0921 - root_mean_squared_error: 0.3823 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3820
# Epoch 98/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0929 - root_mean_squared_error: 0.3817 - val_loss: 0.1033 - val_root_mean_squared_error: 0.3813
# Epoch 99/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0926 - root_mean_squared_error: 0.3810 - val_loss: 0.0964 - val_root_mean_squared_error: 0.3806
# Epoch 100/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0922 - root_mean_squared_error: 0.3803 - val_loss: 0.1164 - val_root_mean_squared_error: 0.3800

# %%
predTrain = model.predict(train_imgs_loaded)
predVal = model.predict(val_imgs_loaded)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predVal_Eur = pd.DataFrame(predVal).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(Ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(Yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseValModel = mean_squared_error(Yval_Eur,predVal_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (val) : %0.3g' % mseValModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel))
# Out:
# MSE (train): 5.01e+03
# MSE (val) : 3.71e+03
# RMSE (train): 70.8
# RMSE (val) : 60.9

# %%
#ahora añadimos MaxNormalization en el clasificador

from keras.constraints import max_norm

# Inizializamos el modelo
model = Sequential()

# Definimos una capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), input_shape=(64, 64, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Definimos una segunda capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Definimos una tercera capa convolucional
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Añadimos nuestro clasificador
model.add(Flatten())
model.add(Dense(1024, activation='relu', kernel_constraint=max_norm(3.)))
model.add(Dropout(0.5))
model.add(Dense(1, activation="linear"))

# Compilamos el modelo
model.compile(loss='mse',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Entrenamos el modelo
model.fit(train_imgs_loaded, Ytrain,
          batch_size=128,
          shuffle=True,
          epochs=100,
          validation_data=(val_imgs_loaded, Yval))
# Out:
# Train on 7204 samples, validate on 1790 samples
# Epoch 1/100
# 7204/7204 [==============================] - 2s 314us/step - loss: 0.3987 - root_mean_squared_error: 0.8235 - val_loss: 1.3591 - val_root_mean_squared_error: 0.7108
# Epoch 2/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.2015 - root_mean_squared_error: 0.6965 - val_loss: 1.5191 - val_root_mean_squared_error: 0.6904
# Epoch 3/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1732 - root_mean_squared_error: 0.6853 - val_loss: 1.3467 - val_root_mean_squared_error: 0.6772
# Epoch 4/100
# 7204/7204 [==============================] - 2s 268us/step - loss: 0.1418 - root_mean_squared_error: 0.6684 - val_loss: 1.4694 - val_root_mean_squared_error: 0.6651
# Epoch 5/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.1222 - root_mean_squared_error: 0.6596 - val_loss: 1.2784 - val_root_mean_squared_error: 0.6540
# Epoch 6/100
# 7204/7204 [==============================] - 2s 265us/step - loss: 0.1159 - root_mean_squared_error: 0.6475 - val_loss: 1.0183 - val_root_mean_squared_error: 0.6399
# Epoch 7/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1219 - root_mean_squared_error: 0.6327 - val_loss: 0.9647 - val_root_mean_squared_error: 0.6268
# Epoch 8/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1094 - root_mean_squared_error: 0.6202 - val_loss: 0.8984 - val_root_mean_squared_error: 0.6145
# Epoch 9/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1143 - root_mean_squared_error: 0.6089 - val_loss: 1.0021 - val_root_mean_squared_error: 0.6057
# Epoch 10/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.1066 - root_mean_squared_error: 0.6016 - val_loss: 0.9766 - val_root_mean_squared_error: 0.5986
# Epoch 11/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1068 - root_mean_squared_error: 0.5949 - val_loss: 0.8981 - val_root_mean_squared_error: 0.5919
# Epoch 12/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1059 - root_mean_squared_error: 0.5883 - val_loss: 0.9391 - val_root_mean_squared_error: 0.5860
# Epoch 13/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1071 - root_mean_squared_error: 0.5832 - val_loss: 0.8271 - val_root_mean_squared_error: 0.5805
# Epoch 14/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1054 - root_mean_squared_error: 0.5774 - val_loss: 0.8654 - val_root_mean_squared_error: 0.5753
# Epoch 15/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1090 - root_mean_squared_error: 0.5729 - val_loss: 0.9148 - val_root_mean_squared_error: 0.5715
# Epoch 16/100
# 7204/7204 [==============================] - 2s 265us/step - loss: 0.1048 - root_mean_squared_error: 0.5694 - val_loss: 0.8255 - val_root_mean_squared_error: 0.5676
# Epoch 17/100
# 7204/7204 [==============================] - 2s 265us/step - loss: 0.1034 - root_mean_squared_error: 0.5653 - val_loss: 0.8524 - val_root_mean_squared_error: 0.5638
# Epoch 18/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1048 - root_mean_squared_error: 0.5619 - val_loss: 0.8572 - val_root_mean_squared_error: 0.5606
# Epoch 19/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1029 - root_mean_squared_error: 0.5589 - val_loss: 0.7595 - val_root_mean_squared_error: 0.5573
# Epoch 20/100
# 7204/7204 [==============================] - 2s 265us/step - loss: 0.1019 - root_mean_squared_error: 0.5552 - val_loss: 0.7691 - val_root_mean_squared_error: 0.5538
# Epoch 21/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.1015 - root_mean_squared_error: 0.5520 - val_loss: 0.6970 - val_root_mean_squared_error: 0.5503
# Epoch 22/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.1034 - root_mean_squared_error: 0.5484 - val_loss: 0.7124 - val_root_mean_squared_error: 0.5470
# Epoch 23/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1025 - root_mean_squared_error: 0.5453 - val_loss: 0.6800 - val_root_mean_squared_error: 0.5439
# Epoch 24/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.1009 - root_mean_squared_error: 0.5421 - val_loss: 0.6767 - val_root_mean_squared_error: 0.5408
# Epoch 25/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.1036 - root_mean_squared_error: 0.5392 - val_loss: 0.6487 - val_root_mean_squared_error: 0.5379
# Epoch 26/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.1024 - root_mean_squared_error: 0.5363 - val_loss: 0.6633 - val_root_mean_squared_error: 0.5351
# Epoch 27/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1005 - root_mean_squared_error: 0.5337 - val_loss: 0.6136 - val_root_mean_squared_error: 0.5324
# Epoch 28/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1029 - root_mean_squared_error: 0.5309 - val_loss: 0.5669 - val_root_mean_squared_error: 0.5295
# Epoch 29/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1025 - root_mean_squared_error: 0.5280 - val_loss: 0.5674 - val_root_mean_squared_error: 0.5267
# Epoch 30/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0997 - root_mean_squared_error: 0.5253 - val_loss: 0.4990 - val_root_mean_squared_error: 0.5238
# Epoch 31/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0983 - root_mean_squared_error: 0.5222 - val_loss: 0.4467 - val_root_mean_squared_error: 0.5206
# Epoch 32/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.1009 - root_mean_squared_error: 0.5190 - val_loss: 0.4568 - val_root_mean_squared_error: 0.5176
# Epoch 33/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0998 - root_mean_squared_error: 0.5161 - val_loss: 0.4012 - val_root_mean_squared_error: 0.5146
# Epoch 34/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1001 - root_mean_squared_error: 0.5130 - val_loss: 0.3588 - val_root_mean_squared_error: 0.5114
# Epoch 35/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0988 - root_mean_squared_error: 0.5098 - val_loss: 0.3651 - val_root_mean_squared_error: 0.5083
# Epoch 36/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.1009 - root_mean_squared_error: 0.5068 - val_loss: 0.3800 - val_root_mean_squared_error: 0.5055
# Epoch 37/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0989 - root_mean_squared_error: 0.5041 - val_loss: 0.3013 - val_root_mean_squared_error: 0.5026
# Epoch 38/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0997 - root_mean_squared_error: 0.5010 - val_loss: 0.2746 - val_root_mean_squared_error: 0.4995
# Epoch 39/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.1008 - root_mean_squared_error: 0.4980 - val_loss: 0.2676 - val_root_mean_squared_error: 0.4966
# Epoch 40/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0979 - root_mean_squared_error: 0.4951 - val_loss: 0.2810 - val_root_mean_squared_error: 0.4937
# Epoch 41/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0995 - root_mean_squared_error: 0.4923 - val_loss: 0.2640 - val_root_mean_squared_error: 0.4910
# Epoch 42/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0986 - root_mean_squared_error: 0.4896 - val_loss: 0.2395 - val_root_mean_squared_error: 0.4882
# Epoch 43/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0969 - root_mean_squared_error: 0.4868 - val_loss: 0.2496 - val_root_mean_squared_error: 0.4856
# Epoch 44/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0976 - root_mean_squared_error: 0.4842 - val_loss: 0.1920 - val_root_mean_squared_error: 0.4829
# Epoch 45/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.1004 - root_mean_squared_error: 0.4815 - val_loss: 0.2187 - val_root_mean_squared_error: 0.4803
# Epoch 46/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0975 - root_mean_squared_error: 0.4790 - val_loss: 0.1873 - val_root_mean_squared_error: 0.4777
# Epoch 47/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0992 - root_mean_squared_error: 0.4765 - val_loss: 0.1905 - val_root_mean_squared_error: 0.4753
# Epoch 48/100
# 7204/7204 [==============================] - 2s 265us/step - loss: 0.0983 - root_mean_squared_error: 0.4740 - val_loss: 0.1751 - val_root_mean_squared_error: 0.4728
# Epoch 49/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0975 - root_mean_squared_error: 0.4716 - val_loss: 0.1729 - val_root_mean_squared_error: 0.4704
# Epoch 50/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0975 - root_mean_squared_error: 0.4692 - val_loss: 0.1622 - val_root_mean_squared_error: 0.4681
# Epoch 51/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0966 - root_mean_squared_error: 0.4669 - val_loss: 0.1731 - val_root_mean_squared_error: 0.4658
# Epoch 52/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0966 - root_mean_squared_error: 0.4647 - val_loss: 0.1610 - val_root_mean_squared_error: 0.4636
# Epoch 53/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0974 - root_mean_squared_error: 0.4625 - val_loss: 0.1562 - val_root_mean_squared_error: 0.4614
# Epoch 54/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0971 - root_mean_squared_error: 0.4604 - val_loss: 0.1537 - val_root_mean_squared_error: 0.4593
# Epoch 55/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0986 - root_mean_squared_error: 0.4583 - val_loss: 0.1493 - val_root_mean_squared_error: 0.4573
# Epoch 56/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0967 - root_mean_squared_error: 0.4563 - val_loss: 0.1677 - val_root_mean_squared_error: 0.4553
# Epoch 57/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0974 - root_mean_squared_error: 0.4544 - val_loss: 0.1570 - val_root_mean_squared_error: 0.4535
# Epoch 58/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0972 - root_mean_squared_error: 0.4525 - val_loss: 0.1495 - val_root_mean_squared_error: 0.4516
# Epoch 59/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0984 - root_mean_squared_error: 0.4507 - val_loss: 0.1411 - val_root_mean_squared_error: 0.4498
# Epoch 60/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0978 - root_mean_squared_error: 0.4489 - val_loss: 0.1238 - val_root_mean_squared_error: 0.4480
# Epoch 61/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0981 - root_mean_squared_error: 0.4471 - val_loss: 0.1387 - val_root_mean_squared_error: 0.4462
# Epoch 62/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0954 - root_mean_squared_error: 0.4453 - val_loss: 0.1459 - val_root_mean_squared_error: 0.4445
# Epoch 63/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0961 - root_mean_squared_error: 0.4437 - val_loss: 0.1392 - val_root_mean_squared_error: 0.4429
# Epoch 64/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0968 - root_mean_squared_error: 0.4420 - val_loss: 0.1341 - val_root_mean_squared_error: 0.4412
# Epoch 65/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0979 - root_mean_squared_error: 0.4404 - val_loss: 0.1369 - val_root_mean_squared_error: 0.4397
# Epoch 66/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0960 - root_mean_squared_error: 0.4389 - val_loss: 0.1223 - val_root_mean_squared_error: 0.4381
# Epoch 67/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0958 - root_mean_squared_error: 0.4373 - val_loss: 0.1283 - val_root_mean_squared_error: 0.4366
# Epoch 68/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0963 - root_mean_squared_error: 0.4358 - val_loss: 0.1391 - val_root_mean_squared_error: 0.4351
# Epoch 69/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0961 - root_mean_squared_error: 0.4344 - val_loss: 0.1343 - val_root_mean_squared_error: 0.4337
# Epoch 70/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0963 - root_mean_squared_error: 0.4330 - val_loss: 0.1372 - val_root_mean_squared_error: 0.4323
# Epoch 71/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0952 - root_mean_squared_error: 0.4316 - val_loss: 0.1554 - val_root_mean_squared_error: 0.4310
# Epoch 72/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0982 - root_mean_squared_error: 0.4303 - val_loss: 0.1295 - val_root_mean_squared_error: 0.4297
# Epoch 73/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0971 - root_mean_squared_error: 0.4290 - val_loss: 0.1288 - val_root_mean_squared_error: 0.4284
# Epoch 74/100
# 7204/7204 [==============================] - 2s 266us/step - loss: 0.0964 - root_mean_squared_error: 0.4277 - val_loss: 0.1137 - val_root_mean_squared_error: 0.4271
# Epoch 75/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0975 - root_mean_squared_error: 0.4265 - val_loss: 0.1090 - val_root_mean_squared_error: 0.4258
# Epoch 76/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0959 - root_mean_squared_error: 0.4251 - val_loss: 0.1129 - val_root_mean_squared_error: 0.4245
# Epoch 77/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0963 - root_mean_squared_error: 0.4239 - val_loss: 0.1307 - val_root_mean_squared_error: 0.4233
# Epoch 78/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0951 - root_mean_squared_error: 0.4227 - val_loss: 0.1153 - val_root_mean_squared_error: 0.4221
# Epoch 79/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0948 - root_mean_squared_error: 0.4215 - val_loss: 0.1259 - val_root_mean_squared_error: 0.4209
# Epoch 80/100
# 7204/7204 [==============================] - 2s 266us/step - loss: 0.0952 - root_mean_squared_error: 0.4204 - val_loss: 0.1139 - val_root_mean_squared_error: 0.4198
# Epoch 81/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0956 - root_mean_squared_error: 0.4192 - val_loss: 0.1284 - val_root_mean_squared_error: 0.4187
# Epoch 82/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0946 - root_mean_squared_error: 0.4182 - val_loss: 0.1135 - val_root_mean_squared_error: 0.4176
# Epoch 83/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0931 - root_mean_squared_error: 0.4170 - val_loss: 0.1224 - val_root_mean_squared_error: 0.4165
# Epoch 84/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0948 - root_mean_squared_error: 0.4160 - val_loss: 0.1150 - val_root_mean_squared_error: 0.4154
# Epoch 85/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0940 - root_mean_squared_error: 0.4149 - val_loss: 0.1061 - val_root_mean_squared_error: 0.4144
# Epoch 86/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0941 - root_mean_squared_error: 0.4138 - val_loss: 0.1160 - val_root_mean_squared_error: 0.4133
# Epoch 87/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0948 - root_mean_squared_error: 0.4128 - val_loss: 0.1273 - val_root_mean_squared_error: 0.4123
# Epoch 88/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0937 - root_mean_squared_error: 0.4119 - val_loss: 0.1256 - val_root_mean_squared_error: 0.4114
# Epoch 89/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0934 - root_mean_squared_error: 0.4109 - val_loss: 0.1263 - val_root_mean_squared_error: 0.4104
# Epoch 90/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0932 - root_mean_squared_error: 0.4099 - val_loss: 0.1002 - val_root_mean_squared_error: 0.4094
# Epoch 91/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0937 - root_mean_squared_error: 0.4090 - val_loss: 0.1286 - val_root_mean_squared_error: 0.4085
# Epoch 92/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0929 - root_mean_squared_error: 0.4081 - val_loss: 0.1154 - val_root_mean_squared_error: 0.4076
# Epoch 93/100
# 7204/7204 [==============================] - 2s 260us/step - loss: 0.0923 - root_mean_squared_error: 0.4071 - val_loss: 0.1243 - val_root_mean_squared_error: 0.4067
# Epoch 94/100
# 7204/7204 [==============================] - 2s 264us/step - loss: 0.0934 - root_mean_squared_error: 0.4063 - val_loss: 0.1204 - val_root_mean_squared_error: 0.4058
# Epoch 95/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0923 - root_mean_squared_error: 0.4054 - val_loss: 0.1196 - val_root_mean_squared_error: 0.4050
# Epoch 96/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0921 - root_mean_squared_error: 0.4045 - val_loss: 0.1240 - val_root_mean_squared_error: 0.4041
# Epoch 97/100
# 7204/7204 [==============================] - 2s 259us/step - loss: 0.0921 - root_mean_squared_error: 0.4037 - val_loss: 0.1219 - val_root_mean_squared_error: 0.4033
# Epoch 98/100
# 7204/7204 [==============================] - 2s 261us/step - loss: 0.0896 - root_mean_squared_error: 0.4029 - val_loss: 0.1162 - val_root_mean_squared_error: 0.4024
# Epoch 99/100
# 7204/7204 [==============================] - 2s 263us/step - loss: 0.0929 - root_mean_squared_error: 0.4020 - val_loss: 0.1228 - val_root_mean_squared_error: 0.4016
# Epoch 100/100
# 7204/7204 [==============================] - 2s 262us/step - loss: 0.0925 - root_mean_squared_error: 0.4012 - val_loss: 0.1167 - val_root_mean_squared_error: 0.4008

# %%
predTrain = model.predict(train_imgs_loaded)
predVal = model.predict(val_imgs_loaded)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predVal_Eur = pd.DataFrame(predVal).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(Ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(Yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseValModel = mean_squared_error(Yval_Eur,predVal_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (val) : %0.3g' % mseValModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel))
# Out:
# MSE (train): 4.92e+03
# MSE (val) : 3.72e+03
# RMSE (train): 70.1
# RMSE (val) : 61

# %% [markdown]
# Observamos cómo en los casos anteriores obtenemos mejores resultados en el conjunto de validación que en el de train. No es algo muy habitual, pero se puede dar.
#
# Cogemos el modelo con batchNoramlization y MaxNorm como referencia y usamos Hyper-opt para optimizar nuestros resultados y encontrar las características del modelo que mejor prestaciones nos de.
#
# Vamos a trabajar con las mismas variables que en el notebook de clasificación:
#
# - el número de filtros en las capas convolucionales
# - el porcentaje de dropout
# - el número de neuronas en la capa densa
# - el tamaño del kernel en las capas convolucionales

# %%
# instalamos los paquetes necesarios
# !pip install networkx==1.11 # para instala hyperopt correctamente, si no, da errores
# !pip install hyperopt
# Out:
# Requirement already satisfied: networkx==1.11 in /usr/local/lib/python3.6/dist-packages (1.11)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from networkx==1.11) (4.4.2)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
# imports necesarios
import sys
import time
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from keras.callbacks import EarlyStopping


# definimos nuestro espacio de búsqueda
# vamos a variar:
# - el número de filtros en nuestras capas conv
# - el porcentaje de dropout
# - el número de neuronas en la capa dense
# - el tamaño del kernel en las capas conv
space = {
    'n_filters_conv': hp.choice('n_filters_conv', [32, 64, 128]),
    'dropout': hp.uniform('dropout', 0.0, 0.5),
    'neurons_dense': hp.choice('neurons_dense', [256, 512, 1024]), 
    'kernel_size' : hp.choice('kernel_size', [3, 5])
}

def	get_callbacks(pars):
  callbacks	= [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0, mode='auto')]
  return callbacks

def mi_cnn(pars):
  print ('Parameters: ', pars)
  # Inizializamos el modelo
  model = Sequential()

  # Definimos una capa convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(pars['kernel_size']), input_shape=(64, 64, 3)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Definimos una segunda capa convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(pars['kernel_size']), activation='relu'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Definimos una tercera capa convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(pars['kernel_size']), activation='relu'))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Añadimos nuestro clasificador
  model.add(Flatten())
  model.add(Dense(pars['neurons_dense'], activation='relu', kernel_constraint=max_norm(3.)))
  model.add(Dropout(pars['dropout']))
  model.add(Dense(1, activation="linear"))

  # Compilamos el modelo
  model.compile(loss='mse',
                optimizer=Adam(lr=0.0001, decay=1e-6),
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  # Entrenamos el modelo
  history = model.fit(train_imgs_loaded, Ytrain,
            batch_size=128,
            shuffle=True,
            epochs=50,
            validation_data=(val_imgs_loaded, Yval),
            verbose = 0,
            callbacks = get_callbacks(pars)) 
  

  best_epoch_loss = np.argmin(history.history['val_loss'])
  best_val_loss = np.min(history.history['val_loss'])
  best_val_rmse = np.max(history.history['val_root_mean_squared_error'])
  
  print('Epoch {} - val rmse: {} - val loss: {}'.format(best_epoch_loss, best_val_rmse, best_val_loss))
  sys.stdout.flush()
  
  return {'loss': best_val_loss, 'best_epoch': best_epoch_loss, 'eval_time': time.time(), 'status': STATUS_OK, 'model': model, 'history': history}


trials = Trials()
best = fmin(mi_cnn, space, algo=tpe.suggest, max_evals=10, trials=trials)
print(best)
# Out:
# Parameters:
# {'dropout': 0.4188545551927214, 'kernel_size': 3, 'n_filters_conv': 64, 'neurons_dense': 512}
# Epoch 24 - val rmse: 2.460111141204834 - val loss: 2.1366975331439653
# Parameters:
# {'dropout': 0.32696596154925855, 'kernel_size': 3, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 15 - val rmse: 2.6364800930023193 - val loss: 1.7661804998387172
# Parameters:
# {'dropout': 0.1503921765380709, 'kernel_size': 3, 'n_filters_conv': 128, 'neurons_dense': 512}
# Epoch 13 - val rmse: 1.7771660089492798 - val loss: 0.6980511625385817
# Parameters:
# {'dropout': 0.056083081143413094, 'kernel_size': 3, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 14 - val rmse: 1.4797413349151611 - val loss: 0.248314151384311
# Parameters:
# {'dropout': 0.21145965248878568, 'kernel_size': 5, 'n_filters_conv': 64, 'neurons_dense': 1024}
# Epoch 11 - val rmse: 1.4202003479003906 - val loss: 0.950022894909928
# Parameters:
# {'dropout': 0.28530178143648355, 'kernel_size': 3, 'n_filters_conv': 32, 'neurons_dense': 1024}
# Epoch 21 - val rmse: 2.0445265769958496 - val loss: 1.3872719258569473
# Parameters:
# {'dropout': 0.025691654638946293, 'kernel_size': 5, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 11 - val rmse: 1.073818325996399 - val loss: 0.16717064477211938
# Parameters:
# {'dropout': 0.07409136720243242, 'kernel_size': 3, 'n_filters_conv': 128, 'neurons_dense': 256}
# Epoch 14 - val rmse: 1.274753212928772 - val loss: 0.3050396300227948
# Parameters:
# {'dropout': 0.17961792214259903, 'kernel_size': 5, 'n_filters_conv': 32, 'neurons_dense': 512}
# Epoch 20 - val rmse: 1.383915662765503 - val loss: 0.7266728090840345
# Parameters:
# {'dropout': 0.33577254235802534, 'kernel_size': 5, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 19 - val rmse: 2.4970080852508545 - val loss: 1.9987423265446498
# 100%|██████████| 10/10 [06:30<00:00, 39.07s/it, best loss: 0.16717064477211938]
# {'dropout': 0.025691654638946293, 'kernel_size': 1, 'n_filters_conv': 1, 'neurons_dense': 0}

# %% [markdown]
# Viendo los resultados estos son los mejores parámetros que entrenan nuestro modelo:
#
# {'dropout': 0.025691654638946293, 'kernel_size': 1, 'n_filters_conv': 1, 'neurons_dense': 0}
#
# Parameters:
# {'dropout': 0.025691654638946293, 'kernel_size': 5, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 11 - val rmse: 1.073818325996399 - val loss: 0.16717064477211938
#
# 64 filtros, 256 neuronas y 5x5 el kernel.

# %%
# Inizializamos el modelo definitivo con los parámetros optimizados
modelDef = Sequential()

# Definimos una capa convolucional
modelDef.add(Conv2D(64, kernel_size=(5,5), input_shape=(64, 64, 3)))
modelDef.add(BatchNormalization())
modelDef.add(Activation('relu'))
modelDef.add(MaxPooling2D(pool_size=(2, 2)))
modelDef.add(Dropout(0.02569))

# Definimos una segunda capa convolucional
modelDef.add(Conv2D(64, kernel_size=(5,5), activation='relu'))
modelDef.add(BatchNormalization())
modelDef.add(Activation('relu'))
modelDef.add(MaxPooling2D(pool_size=(2, 2)))
modelDef.add(Dropout(0.02569))

# Definimos una tercera capa convolucional
modelDef.add(Conv2D(64, kernel_size=(5,5), activation='relu'))
modelDef.add(BatchNormalization())
modelDef.add(Activation('relu'))
modelDef.add(MaxPooling2D(pool_size=(2, 2)))
modelDef.add(Dropout(0.02569))

# Añadimos nuestro clasificador
modelDef.add(Flatten())
modelDef.add(Dense(256, activation='relu', kernel_constraint=max_norm(3.)))
modelDef.add(Dropout(0.02569))
modelDef.add(Dense(1, activation="linear"))


# Compilamos el modelo
modelDef.compile(loss='mse',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Entrenamos el modelo
modelDef.fit(train_imgs_loaded, Ytrain,
          batch_size=128,
          shuffle=True,
          epochs=100,
          validation_data=(val_imgs_loaded, Yval))
# Out:
# Train on 7204 samples, validate on 1790 samples
# Epoch 1/100
# 7204/7204 [==============================] - 4s 509us/step - loss: 1.0659 - root_mean_squared_error: 1.2719 - val_loss: 2.8887 - val_root_mean_squared_error: 1.1266
# Epoch 2/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.4172 - root_mean_squared_error: 1.0747 - val_loss: 2.8282 - val_root_mean_squared_error: 1.0387
# Epoch 3/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.3055 - root_mean_squared_error: 1.0120 - val_loss: 2.7598 - val_root_mean_squared_error: 0.9918
# Epoch 4/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.2476 - root_mean_squared_error: 0.9733 - val_loss: 2.5835 - val_root_mean_squared_error: 0.9585
# Epoch 5/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.2176 - root_mean_squared_error: 0.9438 - val_loss: 2.1331 - val_root_mean_squared_error: 0.9287
# Epoch 6/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.1974 - root_mean_squared_error: 0.9137 - val_loss: 1.4310 - val_root_mean_squared_error: 0.8960
# Epoch 7/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1860 - root_mean_squared_error: 0.8791 - val_loss: 0.8577 - val_root_mean_squared_error: 0.8605
# Epoch 8/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1664 - root_mean_squared_error: 0.8428 - val_loss: 0.5335 - val_root_mean_squared_error: 0.8251
# Epoch 9/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1596 - root_mean_squared_error: 0.8087 - val_loss: 0.2890 - val_root_mean_squared_error: 0.7923
# Epoch 10/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.1445 - root_mean_squared_error: 0.7768 - val_loss: 0.2370 - val_root_mean_squared_error: 0.7624
# Epoch 11/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1449 - root_mean_squared_error: 0.7491 - val_loss: 0.2222 - val_root_mean_squared_error: 0.7368
# Epoch 12/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1315 - root_mean_squared_error: 0.7249 - val_loss: 0.2134 - val_root_mean_squared_error: 0.7139
# Epoch 13/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1290 - root_mean_squared_error: 0.7036 - val_loss: 0.1896 - val_root_mean_squared_error: 0.6938
# Epoch 14/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1238 - root_mean_squared_error: 0.6844 - val_loss: 0.1768 - val_root_mean_squared_error: 0.6756
# Epoch 15/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1219 - root_mean_squared_error: 0.6672 - val_loss: 0.1640 - val_root_mean_squared_error: 0.6593
# Epoch 16/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.1162 - root_mean_squared_error: 0.6515 - val_loss: 0.1590 - val_root_mean_squared_error: 0.6444
# Epoch 17/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.1152 - root_mean_squared_error: 0.6374 - val_loss: 0.1392 - val_root_mean_squared_error: 0.6308
# Epoch 18/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1088 - root_mean_squared_error: 0.6243 - val_loss: 0.1372 - val_root_mean_squared_error: 0.6181
# Epoch 19/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.1102 - root_mean_squared_error: 0.6122 - val_loss: 0.1627 - val_root_mean_squared_error: 0.6067
# Epoch 20/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.1055 - root_mean_squared_error: 0.6013 - val_loss: 0.1820 - val_root_mean_squared_error: 0.5963
# Epoch 21/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0997 - root_mean_squared_error: 0.5913 - val_loss: 0.1669 - val_root_mean_squared_error: 0.5865
# Epoch 22/100
# 7204/7204 [==============================] - 2s 240us/step - loss: 0.1012 - root_mean_squared_error: 0.5819 - val_loss: 0.1388 - val_root_mean_squared_error: 0.5774
# Epoch 23/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0980 - root_mean_squared_error: 0.5730 - val_loss: 0.1565 - val_root_mean_squared_error: 0.5688
# Epoch 24/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0943 - root_mean_squared_error: 0.5647 - val_loss: 0.1368 - val_root_mean_squared_error: 0.5607
# Epoch 25/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0952 - root_mean_squared_error: 0.5568 - val_loss: 0.1423 - val_root_mean_squared_error: 0.5531
# Epoch 26/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0943 - root_mean_squared_error: 0.5495 - val_loss: 0.1632 - val_root_mean_squared_error: 0.5461
# Epoch 27/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0916 - root_mean_squared_error: 0.5428 - val_loss: 0.1284 - val_root_mean_squared_error: 0.5394
# Epoch 28/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0921 - root_mean_squared_error: 0.5362 - val_loss: 0.1256 - val_root_mean_squared_error: 0.5330
# Epoch 29/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0878 - root_mean_squared_error: 0.5298 - val_loss: 0.1694 - val_root_mean_squared_error: 0.5270
# Epoch 30/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0867 - root_mean_squared_error: 0.5241 - val_loss: 0.1250 - val_root_mean_squared_error: 0.5213
# Epoch 31/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0834 - root_mean_squared_error: 0.5184 - val_loss: 0.1506 - val_root_mean_squared_error: 0.5157
# Epoch 32/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0826 - root_mean_squared_error: 0.5131 - val_loss: 0.1590 - val_root_mean_squared_error: 0.5106
# Epoch 33/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0827 - root_mean_squared_error: 0.5081 - val_loss: 0.1746 - val_root_mean_squared_error: 0.5058
# Epoch 34/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0825 - root_mean_squared_error: 0.5034 - val_loss: 0.1570 - val_root_mean_squared_error: 0.5012
# Epoch 35/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0806 - root_mean_squared_error: 0.4989 - val_loss: 0.1468 - val_root_mean_squared_error: 0.4967
# Epoch 36/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0776 - root_mean_squared_error: 0.4944 - val_loss: 0.1311 - val_root_mean_squared_error: 0.4923
# Epoch 37/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0767 - root_mean_squared_error: 0.4901 - val_loss: 0.1396 - val_root_mean_squared_error: 0.4880
# Epoch 38/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0780 - root_mean_squared_error: 0.4859 - val_loss: 0.1596 - val_root_mean_squared_error: 0.4840
# Epoch 39/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0789 - root_mean_squared_error: 0.4822 - val_loss: 0.1340 - val_root_mean_squared_error: 0.4803
# Epoch 40/100
# 7204/7204 [==============================] - 2s 241us/step - loss: 0.0743 - root_mean_squared_error: 0.4783 - val_loss: 0.1350 - val_root_mean_squared_error: 0.4765
# Epoch 41/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0741 - root_mean_squared_error: 0.4746 - val_loss: 0.1307 - val_root_mean_squared_error: 0.4728
# Epoch 42/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0722 - root_mean_squared_error: 0.4710 - val_loss: 0.1338 - val_root_mean_squared_error: 0.4693
# Epoch 43/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0716 - root_mean_squared_error: 0.4676 - val_loss: 0.1385 - val_root_mean_squared_error: 0.4659
# Epoch 44/100
# 7204/7204 [==============================] - 2s 241us/step - loss: 0.0718 - root_mean_squared_error: 0.4643 - val_loss: 0.1541 - val_root_mean_squared_error: 0.4627
# Epoch 45/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0687 - root_mean_squared_error: 0.4611 - val_loss: 0.1659 - val_root_mean_squared_error: 0.4597
# Epoch 46/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0685 - root_mean_squared_error: 0.4582 - val_loss: 0.1437 - val_root_mean_squared_error: 0.4567
# Epoch 47/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0691 - root_mean_squared_error: 0.4552 - val_loss: 0.1355 - val_root_mean_squared_error: 0.4537
# Epoch 48/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0655 - root_mean_squared_error: 0.4522 - val_loss: 0.1547 - val_root_mean_squared_error: 0.4509
# Epoch 49/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0645 - root_mean_squared_error: 0.4495 - val_loss: 0.1310 - val_root_mean_squared_error: 0.4481
# Epoch 50/100
# 7204/7204 [==============================] - 2s 241us/step - loss: 0.0636 - root_mean_squared_error: 0.4466 - val_loss: 0.1369 - val_root_mean_squared_error: 0.4453
# Epoch 51/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0644 - root_mean_squared_error: 0.4439 - val_loss: 0.1554 - val_root_mean_squared_error: 0.4427
# Epoch 52/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0602 - root_mean_squared_error: 0.4414 - val_loss: 0.1440 - val_root_mean_squared_error: 0.4401
# Epoch 53/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0623 - root_mean_squared_error: 0.4388 - val_loss: 0.1472 - val_root_mean_squared_error: 0.4376
# Epoch 54/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0604 - root_mean_squared_error: 0.4364 - val_loss: 0.1266 - val_root_mean_squared_error: 0.4352
# Epoch 55/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0583 - root_mean_squared_error: 0.4339 - val_loss: 0.1448 - val_root_mean_squared_error: 0.4328
# Epoch 56/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0588 - root_mean_squared_error: 0.4316 - val_loss: 0.1383 - val_root_mean_squared_error: 0.4304
# Epoch 57/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0592 - root_mean_squared_error: 0.4293 - val_loss: 0.1325 - val_root_mean_squared_error: 0.4282
# Epoch 58/100
# 7204/7204 [==============================] - 2s 240us/step - loss: 0.0571 - root_mean_squared_error: 0.4270 - val_loss: 0.1261 - val_root_mean_squared_error: 0.4259
# Epoch 59/100
# 7204/7204 [==============================] - 2s 241us/step - loss: 0.0546 - root_mean_squared_error: 0.4248 - val_loss: 0.1330 - val_root_mean_squared_error: 0.4237
# Epoch 60/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0574 - root_mean_squared_error: 0.4226 - val_loss: 0.1243 - val_root_mean_squared_error: 0.4215
# Epoch 61/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0547 - root_mean_squared_error: 0.4205 - val_loss: 0.1530 - val_root_mean_squared_error: 0.4195
# Epoch 62/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0554 - root_mean_squared_error: 0.4185 - val_loss: 0.1608 - val_root_mean_squared_error: 0.4175
# Epoch 63/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0502 - root_mean_squared_error: 0.4165 - val_loss: 0.1442 - val_root_mean_squared_error: 0.4155
# Epoch 64/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0522 - root_mean_squared_error: 0.4145 - val_loss: 0.1409 - val_root_mean_squared_error: 0.4136
# Epoch 65/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0504 - root_mean_squared_error: 0.4126 - val_loss: 0.1380 - val_root_mean_squared_error: 0.4117
# Epoch 66/100
# 7204/7204 [==============================] - 2s 240us/step - loss: 0.0510 - root_mean_squared_error: 0.4107 - val_loss: 0.1297 - val_root_mean_squared_error: 0.4098
# Epoch 67/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0504 - root_mean_squared_error: 0.4088 - val_loss: 0.1303 - val_root_mean_squared_error: 0.4079
# Epoch 68/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0512 - root_mean_squared_error: 0.4070 - val_loss: 0.1396 - val_root_mean_squared_error: 0.4062
# Epoch 69/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0494 - root_mean_squared_error: 0.4053 - val_loss: 0.1457 - val_root_mean_squared_error: 0.4044
# Epoch 70/100
# 7204/7204 [==============================] - 2s 251us/step - loss: 0.0480 - root_mean_squared_error: 0.4035 - val_loss: 0.1299 - val_root_mean_squared_error: 0.4027
# Epoch 71/100
# 7204/7204 [==============================] - 2s 257us/step - loss: 0.0490 - root_mean_squared_error: 0.4018 - val_loss: 0.1318 - val_root_mean_squared_error: 0.4010
# Epoch 72/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0465 - root_mean_squared_error: 0.4001 - val_loss: 0.1234 - val_root_mean_squared_error: 0.3993
# Epoch 73/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0478 - root_mean_squared_error: 0.3984 - val_loss: 0.1342 - val_root_mean_squared_error: 0.3976
# Epoch 74/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0447 - root_mean_squared_error: 0.3968 - val_loss: 0.1401 - val_root_mean_squared_error: 0.3960
# Epoch 75/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0453 - root_mean_squared_error: 0.3952 - val_loss: 0.1436 - val_root_mean_squared_error: 0.3945
# Epoch 76/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0461 - root_mean_squared_error: 0.3937 - val_loss: 0.1259 - val_root_mean_squared_error: 0.3929
# Epoch 77/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0436 - root_mean_squared_error: 0.3921 - val_loss: 0.1299 - val_root_mean_squared_error: 0.3914
# Epoch 78/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0456 - root_mean_squared_error: 0.3906 - val_loss: 0.1263 - val_root_mean_squared_error: 0.3899
# Epoch 79/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0454 - root_mean_squared_error: 0.3891 - val_loss: 0.1392 - val_root_mean_squared_error: 0.3884
# Epoch 80/100
# 7204/7204 [==============================] - 2s 241us/step - loss: 0.0412 - root_mean_squared_error: 0.3877 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3870
# Epoch 81/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0412 - root_mean_squared_error: 0.3862 - val_loss: 0.1291 - val_root_mean_squared_error: 0.3855
# Epoch 82/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0435 - root_mean_squared_error: 0.3848 - val_loss: 0.1297 - val_root_mean_squared_error: 0.3841
# Epoch 83/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0418 - root_mean_squared_error: 0.3834 - val_loss: 0.1470 - val_root_mean_squared_error: 0.3827
# Epoch 84/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0405 - root_mean_squared_error: 0.3821 - val_loss: 0.1323 - val_root_mean_squared_error: 0.3814
# Epoch 85/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0389 - root_mean_squared_error: 0.3807 - val_loss: 0.1320 - val_root_mean_squared_error: 0.3800
# Epoch 86/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0391 - root_mean_squared_error: 0.3794 - val_loss: 0.1336 - val_root_mean_squared_error: 0.3787
# Epoch 87/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0387 - root_mean_squared_error: 0.3780 - val_loss: 0.1273 - val_root_mean_squared_error: 0.3774
# Epoch 88/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0382 - root_mean_squared_error: 0.3767 - val_loss: 0.1308 - val_root_mean_squared_error: 0.3761
# Epoch 89/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0371 - root_mean_squared_error: 0.3754 - val_loss: 0.1454 - val_root_mean_squared_error: 0.3748
# Epoch 90/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.0377 - root_mean_squared_error: 0.3742 - val_loss: 0.1351 - val_root_mean_squared_error: 0.3736
# Epoch 91/100
# 7204/7204 [==============================] - 2s 241us/step - loss: 0.0369 - root_mean_squared_error: 0.3730 - val_loss: 0.1379 - val_root_mean_squared_error: 0.3724
# Epoch 92/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0355 - root_mean_squared_error: 0.3718 - val_loss: 0.1297 - val_root_mean_squared_error: 0.3712
# Epoch 93/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0354 - root_mean_squared_error: 0.3705 - val_loss: 0.1290 - val_root_mean_squared_error: 0.3700
# Epoch 94/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0350 - root_mean_squared_error: 0.3693 - val_loss: 0.1306 - val_root_mean_squared_error: 0.3688
# Epoch 95/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0345 - root_mean_squared_error: 0.3681 - val_loss: 0.1449 - val_root_mean_squared_error: 0.3676
# Epoch 96/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.0334 - root_mean_squared_error: 0.3670 - val_loss: 0.1308 - val_root_mean_squared_error: 0.3664
# Epoch 97/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0345 - root_mean_squared_error: 0.3659 - val_loss: 0.1248 - val_root_mean_squared_error: 0.3653
# Epoch 98/100
# 7204/7204 [==============================] - 2s 240us/step - loss: 0.0340 - root_mean_squared_error: 0.3647 - val_loss: 0.1256 - val_root_mean_squared_error: 0.3642
# Epoch 99/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.0339 - root_mean_squared_error: 0.3636 - val_loss: 0.1291 - val_root_mean_squared_error: 0.3630
# Epoch 100/100
# 7204/7204 [==============================] - 2s 240us/step - loss: 0.0323 - root_mean_squared_error: 0.3625 - val_loss: 0.1341 - val_root_mean_squared_error: 0.3619

# %%
predTrain = modelDef.predict(train_imgs_loaded)
predVal = modelDef.predict(val_imgs_loaded)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predVal_Eur = pd.DataFrame(predVal).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(Ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(Yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseValModel = mean_squared_error(Yval_Eur,predVal_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (val) : %0.3g' % mseValModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel))
# Out:
# MSE (train): 1.47e+03
# MSE (val) : 3.82e+03
# RMSE (train): 38.3
# RMSE (val) : 61.8

# %% [markdown]
# Vemos en el resultado que existe un claro overfitting. El RMSE en el conjunto de train es mucho menor que en el de validación, y eso quiere decir que el modelo aprende muy bien los datos de train pero luego generaliza mal.
#
# A pesar de obtener unos parámetros optimizados con Hyper-opt vemos que la complejidad del modelo es muy alta.
#
# En este caso vamos a aumentar un poco el dropout con la intención de aumentar la regulariación, a ver si así disminuimos el overfitting.
#
# Pasamos de 0.02569 a 0.09569

# %%
# Inizializamos el modelo definitivo con los parámetros optimizados
# y con BatchNormalization
modelDef = Sequential()

# Definimos una capa convolucional
modelDef.add(Conv2D(64, kernel_size=(5,5), input_shape=(64, 64, 3)))
modelDef.add(BatchNormalization())
modelDef.add(Activation('relu'))
modelDef.add(MaxPooling2D(pool_size=(2, 2)))
modelDef.add(Dropout(0.09569))

# Definimos una segunda capa convolucional
modelDef.add(Conv2D(64, kernel_size=(5,5), activation='relu'))
modelDef.add(BatchNormalization())
modelDef.add(Activation('relu'))
modelDef.add(MaxPooling2D(pool_size=(2, 2)))
modelDef.add(Dropout(0.09569))

# Definimos una tercera capa convolucional
modelDef.add(Conv2D(64, kernel_size=(5,5), activation='relu'))
modelDef.add(BatchNormalization())
modelDef.add(Activation('relu'))
modelDef.add(MaxPooling2D(pool_size=(2, 2)))
modelDef.add(Dropout(0.09569))

# Añadimos nuestro clasificador
modelDef.add(Flatten())
modelDef.add(Dense(256, activation='relu', kernel_constraint=max_norm(3.)))
modelDef.add(Dropout(0.09569))
modelDef.add(Dense(1, activation="linear"))

# Compilamos el modelo
modelDef.compile(loss='mse',
              optimizer=Adam(lr=0.0001, decay=1e-6),
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Entrenamos el modelo
modelDef.fit(train_imgs_loaded, Ytrain,
          batch_size=128,
          shuffle=True,
          epochs=100,
          validation_data=(val_imgs_loaded, Yval))
# Out:
# Train on 7204 samples, validate on 1790 samples
# Epoch 1/100
# 7204/7204 [==============================] - 4s 526us/step - loss: 1.4530 - root_mean_squared_error: 1.4736 - val_loss: 2.8732 - val_root_mean_squared_error: 1.2695
# Epoch 2/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.6312 - root_mean_squared_error: 1.2021 - val_loss: 2.8347 - val_root_mean_squared_error: 1.1535
# Epoch 3/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.4267 - root_mean_squared_error: 1.1163 - val_loss: 2.7282 - val_root_mean_squared_error: 1.0867
# Epoch 4/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.3134 - root_mean_squared_error: 1.0600 - val_loss: 2.5866 - val_root_mean_squared_error: 1.0384
# Epoch 5/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.2654 - root_mean_squared_error: 1.0184 - val_loss: 2.2168 - val_root_mean_squared_error: 0.9995
# Epoch 6/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.2338 - root_mean_squared_error: 0.9813 - val_loss: 1.6904 - val_root_mean_squared_error: 0.9628
# Epoch 7/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.2117 - root_mean_squared_error: 0.9451 - val_loss: 1.2865 - val_root_mean_squared_error: 0.9273
# Epoch 8/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1934 - root_mean_squared_error: 0.9104 - val_loss: 0.9786 - val_root_mean_squared_error: 0.8939
# Epoch 9/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.1792 - root_mean_squared_error: 0.8780 - val_loss: 0.7307 - val_root_mean_squared_error: 0.8628
# Epoch 10/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1703 - root_mean_squared_error: 0.8481 - val_loss: 0.5845 - val_root_mean_squared_error: 0.8343
# Epoch 11/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1645 - root_mean_squared_error: 0.8211 - val_loss: 0.4844 - val_root_mean_squared_error: 0.8087
# Epoch 12/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.1529 - root_mean_squared_error: 0.7966 - val_loss: 0.4176 - val_root_mean_squared_error: 0.7854
# Epoch 13/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1499 - root_mean_squared_error: 0.7746 - val_loss: 0.4432 - val_root_mean_squared_error: 0.7648
# Epoch 14/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1444 - root_mean_squared_error: 0.7554 - val_loss: 0.4769 - val_root_mean_squared_error: 0.7469
# Epoch 15/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.1441 - root_mean_squared_error: 0.7387 - val_loss: 0.3877 - val_root_mean_squared_error: 0.7307
# Epoch 16/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1417 - root_mean_squared_error: 0.7230 - val_loss: 0.3699 - val_root_mean_squared_error: 0.7157
# Epoch 17/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.1364 - root_mean_squared_error: 0.7086 - val_loss: 0.3974 - val_root_mean_squared_error: 0.7021
# Epoch 18/100
# 7204/7204 [==============================] - 2s 239us/step - loss: 0.1366 - root_mean_squared_error: 0.6957 - val_loss: 0.4245 - val_root_mean_squared_error: 0.6900
# Epoch 19/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.1327 - root_mean_squared_error: 0.6842 - val_loss: 0.3705 - val_root_mean_squared_error: 0.6787
# Epoch 20/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.1292 - root_mean_squared_error: 0.6733 - val_loss: 0.3493 - val_root_mean_squared_error: 0.6681
# Epoch 21/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.1285 - root_mean_squared_error: 0.6629 - val_loss: 0.4468 - val_root_mean_squared_error: 0.6586
# Epoch 22/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.1267 - root_mean_squared_error: 0.6541 - val_loss: 0.4374 - val_root_mean_squared_error: 0.6500
# Epoch 23/100
# 7204/7204 [==============================] - 2s 243us/step - loss: 0.1271 - root_mean_squared_error: 0.6460 - val_loss: 0.3958 - val_root_mean_squared_error: 0.6420
# Epoch 24/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1269 - root_mean_squared_error: 0.6380 - val_loss: 0.4261 - val_root_mean_squared_error: 0.6345
# Epoch 25/100
# 7204/7204 [==============================] - 2s 242us/step - loss: 0.1231 - root_mean_squared_error: 0.6309 - val_loss: 0.3954 - val_root_mean_squared_error: 0.6274
# Epoch 26/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1193 - root_mean_squared_error: 0.6239 - val_loss: 0.3727 - val_root_mean_squared_error: 0.6206
# Epoch 27/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1195 - root_mean_squared_error: 0.6172 - val_loss: 0.3733 - val_root_mean_squared_error: 0.6141
# Epoch 28/100
# 7204/7204 [==============================] - 2s 244us/step - loss: 0.1195 - root_mean_squared_error: 0.6109 - val_loss: 0.3819 - val_root_mean_squared_error: 0.6080
# Epoch 29/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.1164 - root_mean_squared_error: 0.6051 - val_loss: 0.4081 - val_root_mean_squared_error: 0.6024
# Epoch 30/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.1179 - root_mean_squared_error: 0.5997 - val_loss: 0.3445 - val_root_mean_squared_error: 0.5970
# Epoch 31/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.1166 - root_mean_squared_error: 0.5943 - val_loss: 0.4092 - val_root_mean_squared_error: 0.5919
# Epoch 32/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.1146 - root_mean_squared_error: 0.5894 - val_loss: 0.4069 - val_root_mean_squared_error: 0.5872
# Epoch 33/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1138 - root_mean_squared_error: 0.5848 - val_loss: 0.3746 - val_root_mean_squared_error: 0.5826
# Epoch 34/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.1107 - root_mean_squared_error: 0.5803 - val_loss: 0.3455 - val_root_mean_squared_error: 0.5780
# Epoch 35/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1107 - root_mean_squared_error: 0.5758 - val_loss: 0.3492 - val_root_mean_squared_error: 0.5736
# Epoch 36/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.1115 - root_mean_squared_error: 0.5715 - val_loss: 0.3253 - val_root_mean_squared_error: 0.5694
# Epoch 37/100
# 7204/7204 [==============================] - 2s 252us/step - loss: 0.1081 - root_mean_squared_error: 0.5673 - val_loss: 0.4088 - val_root_mean_squared_error: 0.5655
# Epoch 38/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1092 - root_mean_squared_error: 0.5637 - val_loss: 0.3900 - val_root_mean_squared_error: 0.5619
# Epoch 39/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.1101 - root_mean_squared_error: 0.5602 - val_loss: 0.3656 - val_root_mean_squared_error: 0.5584
# Epoch 40/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1087 - root_mean_squared_error: 0.5567 - val_loss: 0.3019 - val_root_mean_squared_error: 0.5549
# Epoch 41/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.1077 - root_mean_squared_error: 0.5530 - val_loss: 0.3863 - val_root_mean_squared_error: 0.5515
# Epoch 42/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.1057 - root_mean_squared_error: 0.5499 - val_loss: 0.3435 - val_root_mean_squared_error: 0.5483
# Epoch 43/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1034 - root_mean_squared_error: 0.5467 - val_loss: 0.3118 - val_root_mean_squared_error: 0.5450
# Epoch 44/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.1033 - root_mean_squared_error: 0.5434 - val_loss: 0.3511 - val_root_mean_squared_error: 0.5420
# Epoch 45/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.1041 - root_mean_squared_error: 0.5405 - val_loss: 0.3545 - val_root_mean_squared_error: 0.5391
# Epoch 46/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.1010 - root_mean_squared_error: 0.5376 - val_loss: 0.3123 - val_root_mean_squared_error: 0.5361
# Epoch 47/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.1040 - root_mean_squared_error: 0.5347 - val_loss: 0.3758 - val_root_mean_squared_error: 0.5334
# Epoch 48/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.1061 - root_mean_squared_error: 0.5322 - val_loss: 0.3617 - val_root_mean_squared_error: 0.5310
# Epoch 49/100
# 7204/7204 [==============================] - 2s 252us/step - loss: 0.1028 - root_mean_squared_error: 0.5297 - val_loss: 0.2960 - val_root_mean_squared_error: 0.5284
# Epoch 50/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1042 - root_mean_squared_error: 0.5270 - val_loss: 0.3315 - val_root_mean_squared_error: 0.5258
# Epoch 51/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0988 - root_mean_squared_error: 0.5246 - val_loss: 0.3632 - val_root_mean_squared_error: 0.5234
# Epoch 52/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0997 - root_mean_squared_error: 0.5223 - val_loss: 0.3615 - val_root_mean_squared_error: 0.5212
# Epoch 53/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.1002 - root_mean_squared_error: 0.5201 - val_loss: 0.3846 - val_root_mean_squared_error: 0.5191
# Epoch 54/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0994 - root_mean_squared_error: 0.5180 - val_loss: 0.3553 - val_root_mean_squared_error: 0.5170
# Epoch 55/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.1007 - root_mean_squared_error: 0.5159 - val_loss: 0.3238 - val_root_mean_squared_error: 0.5149
# Epoch 56/100
# 7204/7204 [==============================] - 2s 252us/step - loss: 0.0969 - root_mean_squared_error: 0.5138 - val_loss: 0.2439 - val_root_mean_squared_error: 0.5126
# Epoch 57/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0982 - root_mean_squared_error: 0.5114 - val_loss: 0.3176 - val_root_mean_squared_error: 0.5104
# Epoch 58/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0996 - root_mean_squared_error: 0.5094 - val_loss: 0.2947 - val_root_mean_squared_error: 0.5084
# Epoch 59/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0977 - root_mean_squared_error: 0.5073 - val_loss: 0.3433 - val_root_mean_squared_error: 0.5064
# Epoch 60/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0970 - root_mean_squared_error: 0.5055 - val_loss: 0.3171 - val_root_mean_squared_error: 0.5046
# Epoch 61/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0969 - root_mean_squared_error: 0.5036 - val_loss: 0.3407 - val_root_mean_squared_error: 0.5027
# Epoch 62/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0955 - root_mean_squared_error: 0.5018 - val_loss: 0.2944 - val_root_mean_squared_error: 0.5009
# Epoch 63/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0966 - root_mean_squared_error: 0.5000 - val_loss: 0.3342 - val_root_mean_squared_error: 0.4992
# Epoch 64/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0942 - root_mean_squared_error: 0.4983 - val_loss: 0.2875 - val_root_mean_squared_error: 0.4974
# Epoch 65/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0963 - root_mean_squared_error: 0.4965 - val_loss: 0.3067 - val_root_mean_squared_error: 0.4957
# Epoch 66/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0942 - root_mean_squared_error: 0.4948 - val_loss: 0.2584 - val_root_mean_squared_error: 0.4939
# Epoch 67/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0951 - root_mean_squared_error: 0.4930 - val_loss: 0.2879 - val_root_mean_squared_error: 0.4922
# Epoch 68/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0926 - root_mean_squared_error: 0.4914 - val_loss: 0.2778 - val_root_mean_squared_error: 0.4905
# Epoch 69/100
# 7204/7204 [==============================] - 2s 245us/step - loss: 0.0913 - root_mean_squared_error: 0.4897 - val_loss: 0.2806 - val_root_mean_squared_error: 0.4889
# Epoch 70/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0917 - root_mean_squared_error: 0.4880 - val_loss: 0.2426 - val_root_mean_squared_error: 0.4872
# Epoch 71/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0908 - root_mean_squared_error: 0.4863 - val_loss: 0.3143 - val_root_mean_squared_error: 0.4856
# Epoch 72/100
# 7204/7204 [==============================] - 2s 252us/step - loss: 0.0921 - root_mean_squared_error: 0.4849 - val_loss: 0.2801 - val_root_mean_squared_error: 0.4841
# Epoch 73/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0906 - root_mean_squared_error: 0.4834 - val_loss: 0.2463 - val_root_mean_squared_error: 0.4826
# Epoch 74/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0887 - root_mean_squared_error: 0.4818 - val_loss: 0.2743 - val_root_mean_squared_error: 0.4811
# Epoch 75/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0910 - root_mean_squared_error: 0.4803 - val_loss: 0.3156 - val_root_mean_squared_error: 0.4797
# Epoch 76/100
# 7204/7204 [==============================] - 2s 248us/step - loss: 0.0896 - root_mean_squared_error: 0.4790 - val_loss: 0.2698 - val_root_mean_squared_error: 0.4783
# Epoch 77/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0871 - root_mean_squared_error: 0.4775 - val_loss: 0.2093 - val_root_mean_squared_error: 0.4768
# Epoch 78/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0878 - root_mean_squared_error: 0.4760 - val_loss: 0.3277 - val_root_mean_squared_error: 0.4754
# Epoch 79/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0865 - root_mean_squared_error: 0.4747 - val_loss: 0.3111 - val_root_mean_squared_error: 0.4741
# Epoch 80/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0872 - root_mean_squared_error: 0.4735 - val_loss: 0.2882 - val_root_mean_squared_error: 0.4729
# Epoch 81/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0892 - root_mean_squared_error: 0.4722 - val_loss: 0.2973 - val_root_mean_squared_error: 0.4716
# Epoch 82/100
# 7204/7204 [==============================] - 2s 254us/step - loss: 0.0854 - root_mean_squared_error: 0.4710 - val_loss: 0.3685 - val_root_mean_squared_error: 0.4705
# Epoch 83/100
# 7204/7204 [==============================] - 2s 253us/step - loss: 0.0857 - root_mean_squared_error: 0.4700 - val_loss: 0.2726 - val_root_mean_squared_error: 0.4694
# Epoch 84/100
# 7204/7204 [==============================] - 2s 252us/step - loss: 0.0857 - root_mean_squared_error: 0.4687 - val_loss: 0.2322 - val_root_mean_squared_error: 0.4681
# Epoch 85/100
# 7204/7204 [==============================] - 2s 255us/step - loss: 0.0852 - root_mean_squared_error: 0.4674 - val_loss: 0.2442 - val_root_mean_squared_error: 0.4668
# Epoch 86/100
# 7204/7204 [==============================] - 2s 256us/step - loss: 0.0850 - root_mean_squared_error: 0.4661 - val_loss: 0.2430 - val_root_mean_squared_error: 0.4655
# Epoch 87/100
# 7204/7204 [==============================] - 2s 254us/step - loss: 0.0842 - root_mean_squared_error: 0.4649 - val_loss: 0.2407 - val_root_mean_squared_error: 0.4643
# Epoch 88/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0828 - root_mean_squared_error: 0.4636 - val_loss: 0.2455 - val_root_mean_squared_error: 0.4630
# Epoch 89/100
# 7204/7204 [==============================] - 2s 251us/step - loss: 0.0824 - root_mean_squared_error: 0.4624 - val_loss: 0.2307 - val_root_mean_squared_error: 0.4618
# Epoch 90/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0801 - root_mean_squared_error: 0.4611 - val_loss: 0.2609 - val_root_mean_squared_error: 0.4606
# Epoch 91/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0813 - root_mean_squared_error: 0.4600 - val_loss: 0.2422 - val_root_mean_squared_error: 0.4594
# Epoch 92/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0827 - root_mean_squared_error: 0.4588 - val_loss: 0.2424 - val_root_mean_squared_error: 0.4583
# Epoch 93/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0834 - root_mean_squared_error: 0.4577 - val_loss: 0.2574 - val_root_mean_squared_error: 0.4572
# Epoch 94/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0812 - root_mean_squared_error: 0.4566 - val_loss: 0.2637 - val_root_mean_squared_error: 0.4561
# Epoch 95/100
# 7204/7204 [==============================] - 2s 250us/step - loss: 0.0792 - root_mean_squared_error: 0.4555 - val_loss: 0.3342 - val_root_mean_squared_error: 0.4551
# Epoch 96/100
# 7204/7204 [==============================] - 2s 247us/step - loss: 0.0781 - root_mean_squared_error: 0.4547 - val_loss: 0.2040 - val_root_mean_squared_error: 0.4541
# Epoch 97/100
# 7204/7204 [==============================] - 2s 249us/step - loss: 0.0770 - root_mean_squared_error: 0.4535 - val_loss: 0.2271 - val_root_mean_squared_error: 0.4529
# Epoch 98/100
# 7204/7204 [==============================] - 2s 246us/step - loss: 0.0775 - root_mean_squared_error: 0.4523 - val_loss: 0.2829 - val_root_mean_squared_error: 0.4519
# Epoch 99/100
# 7204/7204 [==============================] - 2s 251us/step - loss: 0.0766 - root_mean_squared_error: 0.4514 - val_loss: 0.2596 - val_root_mean_squared_error: 0.4509
# Epoch 100/100
# 7204/7204 [==============================] - 2s 252us/step - loss: 0.0783 - root_mean_squared_error: 0.4504 - val_loss: 0.2193 - val_root_mean_squared_error: 0.4499

# %%
predTrain = modelDef.predict(train_imgs_loaded)
predVal = modelDef.predict(val_imgs_loaded)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predVal_Eur = pd.DataFrame(predVal).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(Ytrain).apply(lambda x: 10**(x))
Yval_Eur = pd.DataFrame(Yval).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseValModel = mean_squared_error(Yval_Eur,predVal_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (val) : %0.3g' % mseValModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (val) : %0.3g' % np.sqrt(mseValModel))
# Out:
# MSE (train): 5.21e+03
# MSE (val) : 4.53e+03
# RMSE (train): 72.2
# RMSE (val) : 67.3

# %% [markdown]
# Podemos ver que se reduce el overfitting. No obstante los resultados obtenidos no son ninguna maravilla.

# %% [markdown]
# Por último evaluamos el modelo con el conjunto de test.

# %%
# Evaluamos el modelo
scores = modelDef.evaluate(test_imgs_loaded, Ytest)

print('Loss: %.3f' % scores[0])
print('RMSE: %.3f' % scores[1])
# Out:
# 2277/2277 [==============================] - 0s 197us/step
# Loss: 0.249
# RMSE: 0.450

# %%
predTrain = modelDef.predict(train_imgs_loaded)
predTest = modelDef.predict(test_imgs_loaded)

#deshacemos la transformación logarítmica
predTrain_Eur = pd.DataFrame(predTrain).apply(lambda x: 10**(x))
predTest_Eur = pd.DataFrame(predTest).apply(lambda x: 10**(x))
Ytrain_Eur = pd.DataFrame(Ytrain).apply(lambda x: 10**(x))
Ytest_Eur = pd.DataFrame(Ytest).apply(lambda x: 10**(x))

#calculamos el MSE y el RMSE para train y test
mseTrainModel = mean_squared_error(Ytrain_Eur,predTrain_Eur)
mseTestModel = mean_squared_error(Ytest_Eur,predTest_Eur)

print('MSE (train): %0.3g' % mseTrainModel)
print('MSE (test) : %0.3g' % mseTestModel)

print('RMSE (train): %0.3g' % np.sqrt(mseTrainModel))
print('RMSE (test) : %0.3g' % np.sqrt(mseTestModel))
# Out:
# MSE (train): 5.21e+03
# MSE (test) : 6.03e+03
# RMSE (train): 72.2
# RMSE (test) : 77.6

# %% [markdown]
# Como podemos ver los resultados son francamente malos. Nos está dando un error de más de 70€ y hay que tener en cuenta que el precio medio de los apartamentos (en train) es de 66€.
#
# La principal razón es que por problemas de memoria RAM no podemos ejecutar el modelo introduciendo las imágenes en su tamaño original (224x224) y hemos tenido que reducirlo a 64x64.
