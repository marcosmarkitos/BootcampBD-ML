# %% [markdown]
# # Importamos las librerías

# %%
import numpy as np
from sklearn.manifold import TSNE

from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

# %% [markdown]
# # Cargamos un modelo

# %%
w2v_sg = Word2Vec.load('../../data/w2v_sg_d300_mc5_w5.pkl')

# %%
w2v_sg.wv.most_similar('brexit')
# Out:
# [('duro', 0.6139558553695679),
#  ('comunes', 0.5841501951217651),
#  ('incertidumbre', 0.5307192802429199),
#  ('tensiones', 0.5284384489059448),
#  ('reino', 0.527982771396637),
#  ('esperanza', 0.5233896970748901),
#  ('bolsas', 0.5199801921844482),
#  ('acerca', 0.5006659030914307),
#  ('johnson', 0.4975699782371521),
#  ('ue', 0.4950684905052185)]

# %% [markdown]
# # Creamos _clusters_ de palabras con las más similares a unas dadas

# %%
keys = ['comida', 'comer', 'agua', 'elecciones', 'brexit']

embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in w2v_sg.wv.most_similar(word, topn=100):
        words.append(similar_word)
        embeddings.append(w2v_sg.wv[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)

# %%
print(word_clusters)
# Out:
# [['comer', 'masticar', 'calorías', 'dientes', 'boca', 'cuándo', 'digestión', 'higiene', 'difícil', 'piezas', 'saliva', 'sufrir', 'pequeña', 'bucal', 'dieta', 'edad', 'digestivo', 'persona', 'hacerlo', 'mesa', 'combatir', 'construir', 'corrección', 'estamos', 'restos', 'pequeños', 'sarcopenia', 'desarrollar', 'consciente', 'velocidad', 'ocasiones', 'encías', 'alimentos', 'obesidad', 'provocar', 'error', 'bacterias', 'espacio', 'dando', 'creo', 'completamente', 'estoy', 'rápido', 'pasión', 'piernas', 'oportunidad', 'eres', 'idea', 'cambiará', 'gestionar', 'infantil', 'meta', 'vaya', 'deben', 'alcanzar', 'etc', 'vender', 'intensidad', 'probablemente', 'consecuencias', 'conocimiento', 'adaptarse', 'pendiente', 'apenas', 'michelin', 'herramienta', 'adecuada', 'déficit', 'futuras', 'pequeño', 'estómago', 'quién', 'pensar', 'totalmente', 'aumenta', 'recordar', 'sea', 'baintex', 'quieres', 'problemas', 'tu', 'requieren', 'tocar', 'llaves', 'flexibilidad', 'decía', 'nuestro', 'pasando', 'periodontitis', 'preservar', 'muscular', 'importante', 'he', 'te', 'normal', 'pregunta', 'representa', 'mal', 'beneficios', 'fácil'], ['comida', 'combatir', 'calorías', 'masticar', 'sarcopenia', 'digestión', 'edad', 'masa', 'apenas', 'muscular', 'sufrir', 'seis', 'normal', 'preparado', 'digestivo', 'visión', 'opción', 'higiene', 'garaje', 'boca', 'infantil', 'quedarse', 'empieza', 'herramienta', 'ayuda', 'aumenta', 'vaya', 'dientes', 'requieren', 'vehículo', 'estoy', 'cambiará', 'pérdida', 'piezas', 'energías', 'hará', 'dieta', 'obesidad', 'cuándo', 'superficie', 'rápido', 'teléfono', 'nuestras', 'vender', 'kilos', 'exceso', 'qué', 'desarrollar', 'crece', 'competir', 'flexibilidad', 'consciente', 'gestionar', 'futuras', 'velocidad', 'bitcoin', 'cambiado', 'quién', 'puerta', 'bucal', 'carne', 'enfermedad', 'michelin', 'mueven', 'añadir', 'now', 'carga', 'creo', 'alimentación', 'llaves', 'inteligencia', 'oportunidad', 'músculo', 'buena', 'creciendo', 'suministro', 'circulación', 'golpe', 'construir', 'común', 'fácil', 'completamente', 'dispositivo', '32', 'pasa', 'carbono', 'spotify', 'accesos', 'promover', 'mesa', 'hacerlo', 'soltura', 'taxi', 'idea', 'blanca', 'pasión', 'hora', 'entendemos', 'supondría', 'mí'], ['acondicionado', 'calefacción', 'gas', 'laguna', 'aire', 'agricultura', 'ganadería', 'tradicionales', 'dispositivo', 'murcia', 'proporcionar', 'ambiente', 'producido', 'incrementa', 'aumenta', 'asegura', 'aerotermia', 'utilizar', 'superficie', 'carbono', 'tratar', 'seguros', 'carne', 'alimentos', 'garaje', 'requieren', 'digestivo', 'lleva', 'permite', 'sucede', 'consejero', 'sanidad', 'seat', 'cliente', 'eficientes', 'energías', 'hubiera', 'blanco', 'fuera', 'recuerda', 'convierte', 'kilos', 'restaurante', 'usuario', 'tratamiento', 'norte', 'hacen', 'puerta', 'combatir', 'indra', 'incremento', 'tráfico', 'masa', 'determinar', 'sarcopenia', 'bitcoin', 'panasonic', 'división', 'visión', 'bienestar', 'deberían', 'permitirá', 'sacyr', 'supremo', 'asociados', 'cocina', '300', 'civil', 'alimentación', 'consumidor', 'refuerza', 'temas', 'eficiente', 'viajeros', 'nunca', 'larga', 'declarado', 'uso', 'supera', 'presión', 'rango', 'free', 'obras', 'explicó', 'seguro', 'infraestructuras', 'fuente', 'prácticas', 'socimi', 'agrícola', 'vamos', 'física', 'contrario', 'continuación', 'enfermedad', 'energético', 'usar', '80', 'encuentra', 'helio'], ['generales', 'forzar', 'cs', 'moción', 'johnson', 'próximas', 'apoyos', 'derecho', 'investidura', 'sumar', 'pedir', 'mariano', 'rechaza', 'convocatoria', 'sánchez', 'parlamento', 'delegaciones', 'piernas', 'oposición', 'afrontar', 'unidas', 'juntos', 'catalanas', 'recordar', 'comicios', 'rivera', 'boris', 'presentar', 'inste', 'critica', 'electoral', 'documentación', 'electorales', 'populares', 'cuestión', 'govern', 'vuelto', 'voto', 'naranja', 'legislatura', 'senado', 'correos', 'supremo', 'asuntos', 'torra', 'candidato', 'quim', 'parlament', 'brexit', 'exige', 'hacerlo', 'confianza', 'fecha', 'toledo', 'comunes', ...

# %%
len(embedding_clusters[0][0])
# Out:
# 300

# %% [markdown]
# # Reducimos dimensionalidad a 2D para poder representar

# %%
tsne_model_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)

# %%
embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape

# %%
embeddings_2d = np.array(tsne_model_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

# %% [markdown]
# # Visualización

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
# %matplotlib inline


def tsne_plot_similar_words(labels, embedding_clusters, word_clusters, a=0.7):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:,0]
        y = embeddings[:,1]
        plt.scatter(x, y, c=[color], alpha=a, label=label)
        for i, word in enumerate(words):
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2), 
                         textcoords='offset points', ha='right', va='bottom', size=8)
    plt.legend(loc=4)
    plt.grid(True)
    plt.title('Representación en 2D de los embeddings de algunos clusters de palabras')
    # plt.savefig("f/г.png", format='png', dpi=150, bbox_inches='tight')
    plt.show()


tsne_plot_similar_words(keys, embeddings_2d, word_clusters)

# %% [markdown]
# ## Embedding projector online
#
# Permite cargar un fichero TSV con los word embeddings pre-calculados y representarlos en una representación interactiva en 3D.
#
# La reducción de dimensionalidad puede realizarse mediante UMAP, t-SNE o PCA.
#
# Además, permite cargar los vectores con metadata como, por ejemplo, variables categóricas, que permitirán visualizar los topics / clusters en el espacio de 3D.
#
# https://projector.tensorflow.org
#
# <img src=https://i.ytimg.com/vi/y2rEqxzqOkM/maxresdefault.jpg>
